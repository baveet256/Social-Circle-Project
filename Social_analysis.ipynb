# %%
from igraph import *
g = Graph()

# %%
def addVertex(g,name_str):
    try:
        if(name_str not in g.vs['name']):
            print('Inserted node ',name_str)
            g.add_vertex(name=name_str)
        else:
            print ('Node ',name_str,' already present')
            print(g.vs.find(name_str).index)   
    except KeyError:
        g.add_vertex(name=name_str)
    return g

# %%
def load_dataset(fileName,g):
    fileNums=[0]
    for i,eachNum in enumerate(fileNums):
        print(eachNum)
        fileName="C:\\Users\\admin\\Desktop\\Baveet\\Social_Datasets\\facebook\\edges\\"+str(eachNum)+".edges"
        print('fileName=',fileName)
        f=open(fileName)
        line=f.readline()
        while(line!=''):
            c=(line.split())
            g=addVertex(g,c[0])
            g=addVertex(g,c[1])
            print('Adding ',c[0],'-->',c[1])
            g.add_edge(c[0],c[1]) 
            line=f.readline()
    g.simplify()    
    return

# %%
load_dataset('as',g)
# Out:
# 0
# fileName= C:\Users\admin\Desktop\Baveet\Social_Datasets\facebook\edges\0.edges
# Inserted node  186
# Adding  236 --> 186
# Inserted node  122
# Inserted node  285
# Adding  122 --> 285
# Inserted node  24
# Inserted node  346
# Adding  24 --> 346
# Inserted node  271
# Inserted node  304
# Adding  271 --> 304
# Inserted node  176
# Inserted node  9
# Adding  176 --> 9
# Inserted node  130
# Inserted node  329
# Adding  130 --> 329
# Inserted node  204
# Inserted node  213
# Adding  204 --> 213
# Inserted node  252
# Inserted node  332
# Adding  252 --> 332
# Inserted node  82
# Inserted node  65
# Adding  82 --> 65
# Inserted node  276
# Inserted node  26
# Adding  276 --> 26
# Inserted node  280
# Inserted node  272
# Adding  280 --> 272
# Inserted node  211
# Inserted node  199
# Adding  211 --> 199
# Inserted node  84
# Node  236  already present
# 0
# Adding  84 --> 236
# Inserted node  133
# Inserted node  62
# Adding  133 --> 62
# Inserted node  239
# Inserted node  172
# Adding  239 --> 172
# Inserted node  322
# Inserted node  53
# Adding  322 --> 53
# Inserted node  3
# Inserted node  170
# Adding  3 --> 170
# Inserted node  175
# Inserted node  46
# Adding  175 --> 46
# Node  170  already present
# 32
# Node  176  already present
# 8
# Adding  170 --> 176
# Node  170  already present
# 32
# Inserted node  56
# Adding  170 --> 56
# Inserted node  254
# Inserted node  194
# Adding  254 --> 194
# Inserted node  231
# Inserted node  117
# Adding  231 --> 117
# Inserted node  127
# Inserted node  135
# Adding  127 --> 135
# Node  285  already present
# 3
# Inserted node  103
# Adding  285 --> 103
# Inserted node  188
# Node  133  already present
# 25
# Adding  188 --> 133
# Inserted node  23
# Inserted node  116
# Adding  23 --> 116
# Inserted node  73
# Inserted node  299
# Adding  73 --> 299
# Inserted node  288
# Inserted node  315
# Adding  288 --> 315
# Inserted node  119
# Inserted node  323
# Adding  119 --> 323
# Inserted node  48
# Inserted node  57
# Adding  48 --> 57
# Inserted node  200
# Inserted node  98
# Adding  200 --> 98
# Inserted node  313
# Inserted node  63
# Adding  313 --> 63
# Node  199  already present
# 23
# Node  304  already present
# 7
# Adding  199 --> 304
# Node  53  already present
# 30
# Node  346  already present
# 5
# Adding  53 --> 346
# Inserted node  344
# Node  239  already present
# 27
# Adding  344 --> 239
# Node  56  already present
# 35
# Inserted node  67
# Adding  56 --> 67
# Inserted node  118
# Inserted node  325
# Adding  118 --> 325
# Node  188  already present
# 43
# Node  119  already present
# 50
# Adding  188 --> 119
# Node  26  already present
# 19
# Inserted node  277
# Adding  26 --> 277
# Inserted node  134
# Node  56  already present
# 35
# Adding  134 --> 56
# Inserted node  270
# Inserted node  76
# Adding  270 --> 76
# Node  135  already present
# 41
# Inserted node  36
# Adding  135 --> 36
# Inserted node  223
# Node  170  already present
# 32
# Adding  223 --> 170
# Node  170  already present
# 32
# Inserted node  274
# Adding  170 --> 274
# Inserted node  88
# Inserted node  21
# Adding  88 --> 21
# Inserted node  339
# Node  119  already present
# 50
# Adding  339 --> 119
# Inserted node  108
# Inserted node  197
# Adding  108 --> 197
# Inserted node  169
# Node  271  already present
# 6
# Adding  169 --> 271
# Node  62  already present
# 26
# Node  236  already present
# 0
# Adding  62 --> 236
# Inserted node  275
# Inserted node  273
# Adding  275 --> 273
# Node  88  already present
# 69
# Node  186  already present
# 1
# Adding  88 --> 186
# Node  213  already present
# 13
# Node  186  already present
# 1
# Adding  213 --> 186
# Inserted node  83
# Node  23  already present
# 44
# Adding  83 --> 23
# Inserted node  28
# Inserted node  312
# Adding  28 --> 312
# Inserted node  242
# Node  57  already present
# 53
# Adding  242 --> 57
# Inserted node  214
# Inserted node  20
# Adding  214 --> 20
# Inserted node  307
# Inserted node  71
# Adding  307 --> 71
# Node  20  already present
# 82
# Inserted node  333
# Adding  20 --> 333
# Inserted node  207
# Node  322  already present
# 29
# Adding  207 --> 322
# Node  339  already present
# 71
# Inserted node  168
# Adding  339 --> 168
# Inserted node  308
# Node  277  already present
# 62
# Adding  308 --> 277
# Node  186  already present
# 1
# Inserted node  341
# Adding  186 --> 341
# Node  322  already present
# 29
# Node  122  already present
# 2
# Adding  322 --> 122
# Inserted node  128
# Node  9  already present
# 9
# Adding  128 --> 9
# Inserted node  334
# Node  252  already present
# 14
# Adding  334 --> 252
# Inserted node  238
# Inserted node  265
# Adding  238 --> 265
# Node  67  already present
# 59
# Inserted node  141
# Adding  67 --> 141
# Inserted node  78
# Node  273  already present
# 76
# Adding  78 --> 273
# Inserted node  345
# Node  122  already present
# 2
# Adding  345 --> 122
# Node  315  already present
# 49
# Node  345  already present
# 96
# Adding  315 --> 345
# Inserted node  317
# Inserted node  158
# Adding  317 --> 158
# Node  98  already present
# 55
# Node  21  already present
# 70
# Adding  98 --> 21
# Node  339  already present
# 71
# Inserted node  38
# Adding  339 --> 38
# Node  24  already present
# 4
# Inserted node  302
# Adding  24 --> 302
# Inserted node  27
# Inserted node  54
# Adding  27 --> 54
# Node  197  already present
# 73
# Inserted node  139
# Adding  197 --> 139
# Inserted node  109
# Node  118  already present
# 60
# Adding  109 --> 118
# Node  252  already present
# 14
# Inserted node  291
# Adding  252 --> 291
# Node  170  already present
# 32
# Inserted node  142
# Adding  170 --> 142
# Node  82  already present
# 16
# Node  271  already present
# 6
# Adding  82 --> 271
# Inserted node  203
# Node  332  already present
# 15
# Adding  203 --> 332
# Inserted node  105
# Node  9  already present
# 9
# Adding  105 --> 9
# Inserted node  232
# Node  285  already present
# 3
# Adding  232 --> 285
# Inserted node  64
# Inserted node  217
# Adding  64 --> 217
# Node  239  already present
# 27
# Node  62  already present
# 26
# Adding  239 --> 62
# Inserted node  248
# Node  332  already present
# 15
# Adding  248 --> 332
# Node  73  already present
# 46
# Inserted node  126
# Adding  73 --> 126
# Inserted node  224
# Inserted node  261
# Adding  224 --> 261
# Inserted node  283
# Node  3  already present
# 31
# Adding  283 --> 3
# Inserted node  144
# Inserted node  226
# Adding  144 --> 226
# Node  119  already present
# 50
# Node  48  already present
# 52
# Adding  119 --> 48
# Inserted node  290
# Inserted node  25
# Adding  290 --> 25
# Node  172  already present
# 28
# Inserted node  342
# Adding  172 --> 342
# Node  119  already present
# 50
# Node  170  already present
# 32
# Adding  119 --> 170
# Node  285  already present
# 3
# Inserted node  146
# Adding  285 --> 146
# Inserted node  300
# Inserted node  94
# Adding  300 --> 94
# Node  236  already present
# 0
# Node  142  already present
# 106
# Adding  236 --> 142
# Node  346  already present
# 5
# Inserted node  1
# Adding  346 --> 1
# Inserted node  184
# Inserted node  159
# Adding  184 --> 159
# Node  159  already present
# 127
# Node  139  already present
# 103
# Adding  159 --> 139
# Node  53  already present
# 30
# Node  299  already present
# 47
# Adding  53 --> 299
# Inserted node  149
# Node  20  already present
# 82
# Adding  149 --> 20
# Node  83  already present
# 77
# Node  25  already present
# 120
# Adding  83 --> 25
# Node  332  already present
# 15
# Inserted node  13
# Adding  332 --> 13
# Node  25  already present
# 120
# Node  94  already present
# 124
# Adding  25 --> 94
# Node  342  already present
# 121
# Inserted node  59
# Adding  342 --> 59
# Node  238  already present
# 92
# Node  239  already present
# 27
# Adding  238 --> 239
# Inserted node  17
# Inserted node  326
# Adding  17 --> 326
# Inserted node  80
# Inserted node  187
# Adding  80 --> 187
# Node  325  already present
# 61
# Node  109  already present
# 104
# Adding  325 --> 109
# Node  224  already present
# 114
# Node  84  already present
# 24
# Adding  224 --> 84
# Inserted node  161
# Node  142  already present
# 106
# Adding  161 --> 142
# Node  122  already present
# 2
# Node  323  already present
# 51
# Adding  122 --> 323
# Node  161  already present
# 135
# Node  308  already present
# 88
# Adding  161 --> 308
# Node  142  already present
# 106
# Inserted node  66
# Adding  142 --> 66
# Node  308  already present
# 88
# Inserted node  31
# Adding  308 --> 31
# Inserted node  136
# Inserted node  7
# Adding  136 --> 7
# Node  271  already present
# 6
# Node  252  already present
# 14
# Adding  271 --> 252
# Inserted node  255
# Inserted node  49
# Adding  255 --> 49
# Node  48  already present
# 52
# Inserted node  320
# Adding  48 --> 320
# Node  3  already present
# 31
# Inserted node  85
# Adding  3 --> 85
# Inserted node  246
# Node  7  already present
# 139
# Adding  246 --> 7
# Node  109  already present
# 104
# Node  56  already present
# 35
# Adding  109 --> 56
# Node  109  already present
# 104
# Node  119  already present
# 50
# Adding  109 --> 119
# Node  239  already present
# 27
# Node  238  already present
# 92
# Adding  239 --> 238
# Node  272  already present
# 21
# Node  186  already present
# 1
# Adding  272 --> 186
# Node  200  already present
# 54
# Inserted node  123
# Adding  200 --> 123
# Node  285  already present
# 3
# Node  246  already present
# 144
# Adding  285 --> 246
# Node  271  already present
# 6
# Node  188  already present
# 43
# Adding  271 --> 188
# Node  31  already present
# 137
# Node  277  already present
# 62
# Adding  31 --> 277
# Node  326  already present
# 132
# Node  17  already present
# 131
# Adding  326 --> 17
# Inserted node  284
# Node  108  already present
# 72
# Adding  284 --> 108
# Inserted node  140
# Inserted node  137
# Adding  140 --> 137
# Node  56  already present
# 35
# Node  26  already present
# 19
# Adding  56 --> 26
# Inserted node  343
# Inserted node  115
# Adding  343 --> 115
# Node  25  already present
# 120
# Node  323  already present
# 51
# Adding  25 --> 323
# Node  345  already present
# 96
# Node  159  already present
# 127
# Adding  345 --> 159
# Inserted node  297
# Node  26  already present
# 19
# Adding  297 --> 26
# Node  343  already present
# 149
# Node  149  already present
# 128
# Adding  343 --> 149
# Node  320  already present
# 142
# Node  48  already present
# 52
# Adding  320 --> 48
# Node  200  already present
# 54
# Node  109  already present
# 104
# Adding  200 --> 109
# Inserted node  185
# Node  271  already present
# 6
# Adding  185 --> 271
# Node  7  already present
# 139
# Node  136  already present
# 138
# Adding  7 --> 136
# Node  326  already present
# 132
# Node  149  already present
# 128
# Adding  326 --> 149
# Inserted node  104
# Node  56  already present
# 35
# Adding  104 --> 56
# Node  339  already present
# 71
# Node  136  already present
# 138
# Adding  339 --> 136
# Node  308  already present
# 88
# Node  142  already present
# 106
# Adding  308 --> 142
# Inserted node  324
# Node  329  already present
# 11
# Adding  324 --> 329
# Node  9  already present
# 9
# Node  252  already present
# 14
# Adding  9 --> 252
# Node  1  already present
# 125
# Node  315  already present
# 49
# Adding  1 --> 315
# Node  21  already present
# 70
# Node  274  already present
# 68
# Adding  21 --> 274
# Node  119  already present
# 50
# Inserted node  171
# Adding  119 --> 171
# Node  345  already present
# 96
# Node  67  already present
# 59
# Adding  345 --> 67
# Node  280  already present
# 20
# Node  1  already present
# 125
# Adding  280 --> 1
# Node  313  already present
# 56
# Node  265  already present
# 93
# Adding  313 --> 265
# Node  277  already present
# 62
# Node  271  already present
# 6
# Adding  277 --> 271
# Node  56  already present
# 35
# Node  88  already present
# 69
# Adding  56 --> 88
# Node  9  already present
# 9
# Node  203  already present
# 107
# Adding  9 --> 203
# Node  85  already present
# 143
# Node  176  already present
# 8
# Adding  85 --> 176
# Inserted node  111
# Node  343  already present
# 149
# Adding  111 --> 343
# Inserted node  14
# Node  20  already present
# 82
# Adding  14 --> 20
# Inserted node  310
# Inserted node  32
# Adding  310 --> 32
# Node  304  already present
# 7
# Inserted node  30
# Adding  304 --> 30
# Node  199  already present
# 23
# Inserted node  222
# Adding  199 --> 222
# Inserted node  92
# Node  346  already present
# 5
# Adding  92 --> 346
# Inserted node  72
# Inserted node  40
# Adding  72 --> 40
# Node  284  already present
# 146
# Node  184  already present
# 126
# Adding  284 --> 184
# Inserted node  125
# Node  136  already present
# 138
# Adding  125 --> 136
# Node  134  already present
# 63
# Node  118  already present
# 60
# Adding  134 --> 118
# Node  9  already present
# 9
# Node  322  already present
# 29
# Adding  9 --> 322
# Node  302  already present
# 100
# Inserted node  266
# Adding  302 --> 266
# Node  332  already present
# 15
# Node  104  already present
# 153
# Adding  332 --> 104
# Node  40  already present
# 164
# Node  199  already present
# 23
# Adding  40 --> 199
# Inserted node  212
# Node  67  already present
# 59
# Adding  212 --> 67
# Node  200  already present
# 54
# Node  277  already present
# 62
# Adding  200 --> 277
# Node  82  already present
# 16
# Node  169  already present
# 74
# Adding  82 --> 169
# Node  270  already present
# 64
# Node  203  already present
# 107
# Adding  270 --> 203
# Node  308  already present
# 88
# Node  172  already present
# 28
# Adding  308 --> 172
# Node  261  already present
# 115
# Node  63  already present
# 57
# Adding  261 --> 63
# Node  146  already present
# 122
# Node  313  already present
# 56
# Adding  146 --> 313
# Node  188  already present
# 43
# Node  285  already present
# 3
# Adding  188 --> 285
# Node  57  already present
# 53
# Node  92  already present
# 162
# Adding  57 --> 92
# Node  168  already present
# 87
# Node  304  already present
# 7
# Adding  168 --> 304
# Node  199  already present
# 23
# Node  265  already present
# 93
# Adding  199 --> 265
# Node  332  already present
# 15
# Node  98  already present
# 55
# Adding  332 --> 98
# Node  169  already present
# 74
# Node  136  already present
# 138
# Adding  169 --> 136
# Node  213  already present
# 13
# Node  57  already present
# 53
# Adding  213 --> 57
# Node  248  already present
# 112
# Node  277  already present
# 62
# Adding  248 --> 277
# Node  98  already present
# 55
# Node  271  already present
# 6
# Adding  98 --> 271
# Node  56  already present
# 35
# Node  141  already present
# 94
# Adding  56 --> 141
# Node  310  already present
# 158
# Node  17  already present
# 131
# Adding  310 --> 17
# Node  199  already present
# 23
# Node  118  already present
# 60
# Adding  199 --> 118
# Node  239  already present
# 27
# Node  141  already present
# 94
# Adding  239 --> 141
# Node  21  already present
# 70
# Node  212  already present
# 167
# Adding  21 --> 212
# Node  176  already present
# 8
# Node  128  already present
# 90
# Adding  176 --> 128
# Node  175  already present
# 33
# Inserted node  278
# Adding  175 --> 278
# Node  203  already present
# 107
# Node  25  already present
# 120
# Adding  203 --> 25
# Node  265  already present
# 93
# Node  40  already present
# 164
# Adding  265 --> 40
# Node  26  already present
# 19
# Node  252  already present
# 14
# Adding  26 --> 252
# Node  339  already present
# 71
# Inserted node  340
# Adding  339 --> 340
# Node  172  already present
# 28
# Node  232  already present
# 109
# Adding  172 --> 232
# Node  31  already present
# 137
# Inserted node  237
# Adding  31 --> 237
# Inserted node  311
# Node  265  already present
# 93
# Adding  311 --> 265
# Inserted node  309
# Node  135  already present
# 41
# Adding  309 --> 135
# Inserted node  330
# Node  80  already present
# 133
# Adding  330 --> 80
# Inserted node  230
# Inserted node  70
# Adding  230 --> 70
# Node  272  already present
# 21
# Node  159  already present
# 127
# Adding  272 --> 159
# Node  21  already present
# 70
# Node  134  already present
# 63
# Adding  21 --> 134
# Node  24  already present
# 4
# Node  53  already present
# 30
# Adding  24 --> 53
# Node  40  already present
# 164
# Node  332  already present
# 15
# Adding  40 --> 332
# Node  261  already present
# 115
# Inserted node  16
# Adding  261 --> 16
# Node  239  already present
# 27
# Node  223  already present
# 67
# Adding  239 --> 223
# Node  304  already present
# 7
# Inserted node  249
# Adding  304 --> 249
# Node  277  already present
# 62
# Inserted node  39
# Adding  277 --> 39
# Node  224  already present
# 114
# Node  141  already present
# 94
# Adding  224 --> 141
# Node  142  already present
# 106
# Node  345  already present
# 96
# Adding  142 --> 345
# Node  72  already present
# 163
# Node  141  already present
# 94
# Adding  72 --> 141
# Node  313  already present
# 56
# Node  21  already present
# 70
# Adding  313 --> 21
# Node  261  already present
# 115
# Node  271  already present
# 6
# Adding  261 --> 271
# Node  276  already present
# 18
# Node  25  already present
# 120
# Adding  276 --> 25
# Node  109  already present
# 104
# Node  200  already present
# 54
# Adding  109 --> 200
# Node  288  already present
# 48
# Node  25  already present
# 120
# Adding  288 --> 25
# Node  329  already present
# 11
# Node  291  already present
# 105
# Adding  329 --> 291
# Node  194  already present
# 37
# Node  242  already present
# 80
# Adding  194 --> 242
# Node  223  already present
# 67
# Node  203  already present
# 107
# Adding  223 --> 203
# Node  290  already present
# 119
# Node  170  already present
# 32
# Adding  290 --> 170
# Node  261  already present
# 115
# Node  325  already present
# 61
# Adding  261 --> 325
# Node  36  already present
# 66
# Inserted node  251
# Adding  36 --> 251
# Node  291  already present
# 105
# Inserted node  10
# Adding  291 --> 10
# Node  342  already present
# 121
# Node  67  already present
# 59
# Adding  342 --> 67
# Node  21  already present
# 70
# Inserted node  55
# Adding  21 --> 55
# Node  108  already present
# 72
# Node  284  already present
# 146
# Adding  108 --> 284
# Node  3  already present
# 31
# Inserted node  228
# Adding  3 --> 228
# Node  168  already present
# 87
# Node  31  already present
# 137
# Adding  168 --> 31
# Node  67  already present
# 59
# Inserted node  69
# Adding  67 --> 69
# Node  323  already present
# 51
# Node  142  already present
# 106
# Adding  323 --> 142
# Node  261  already present
# 115
# Inserted node  113
# Adding  261 --> 113
# Node  55  already present
# 181
# Node  200  already present
# 54
# Adding  55 --> 200
# Node  13  already present
# 129
# Node  277  already present
# 62
# Adding  13 --> 277
# Node  322  already present
# 29
# Node  25  already present
# 120
# Adding  322 --> 25
# Inserted node  258
# Inserted node  257
# Adding  258 --> 257
# Node  285  already present
# 3
# Node  136  already present
# 138
# Adding  285 --> 136
# Node  80  already present
# 133
# Node  320  already present
# 142
# Adding  80 --> 320
# Node  265  already present
# 93
# Node  98  already present
# 55
# Adding  265 --> 98
# Node  252  already present
# 14
# Node  248  already present
# 112
# Adding  252 --> 248
# Node  62  already present
# 26
# Node  200  already present
# 54
# Adding  62 --> 200
# Node  313  already present
# 56
# Node  54  already present
# 102
# Adding  313 --> 54
# Inserted node  196
# Node  249  already present
# 177
# Adding  196 --> 249
# Node  323  already present
# 51
# Node  85  already present
# 143
# Adding  323 --> 85
# Node  82  already present
# 16
# Node  231  already present
# 38
# Adding  82 --> 231
# Node  141  already present
# 94
# Node  224  already present
# 114
# Adding  141 --> 224
# Node  342  already present
# 121
# Node  119  already present
# 50
# Adding  342 --> 119
# Node  304  already present
# 7
# Node  325  already present
# 61
# Adding  304 --> 325
# Node  136  already present
# 138
# Inserted node  156
# Adding  136 --> 156
# Node  325  already present
# 61
# Node  104  already present
# 153
# Adding  325 --> 104
# Node  211  already present
# 22
# Node  325  already present
# 61
# Adding  211 --> 325
# Node  304  already present
# 7
# Node  158  already present
# 98
# Adding  304 --> 158
# Node  254  already present
# 36
# Node  302  already present
# 100
# Adding  254 --> 302
# Node  92  already present
# 162
# Node  242  already present
# 80
# Adding  92 --> 242
# Node  30  already present
# 160
# Inserted node  303
# Adding  30 --> 303
# Node  274  already present
# 68
# Node  188  already present
# 43
# Adding  274 --> 188
# Node  28  already present
# 78
# Node  310  already present
# 158
# Adding  28 --> 310
# Node  271  already present
# 6
# Node  30  already present
# 160
# Adding  271 --> 30
# Inserted node  286
# Inserted node  81
# Adding  286 --> 81
# Node  144  already present
# 117
# Node  326  already present
# 132
# Adding  144 --> 326
# Node  265  already present
# 93
# Node  56  already present
# 35
# Adding  265 --> 56
# Node  249  already present
# 177
# Node  57  already present
# 53
# Adding  249 --> 57
# Node  341  already present
# 89
# Node  186  already present
# 1
# Adding  341 --> 186
# Inserted node  174
# Inserted node  293
# Adding  174 --> 293
# Inserted node  33
# Inserted node  42
# Adding  33 --> 42
# Node  312  already present
# 79
# Node  28  already present
# 78
# Adding  312 --> 28
# Node  199  already present
# 23
# Node  212  already present
# 167
# Adding  199 --> 212
# Node  9  already present
# 9
# Node  323  already present
# 51
# Adding  9 --> 323
# Node  168  already present
# 87
# Inserted node  347
# Adding  168 --> 347
# Node  67  already present
# 59
# Node  142  already present
# 106
# Adding  67 --> 142
# Node  1  already present
# 125
# Node  53  already present
# 30
# Adding  1 --> 53
# Node  115  already present
# 150
# Inserted node  2
# Adding  115 --> 2
# Node  333  already present
# 85
# Node  2  already present
# 197
# Adding  333 --> 2
# Node  332  already present
# 15
# Node  38  already present
# 99
# Adding  332 --> 38
# Node  291  already present
# 105
# Node  280  already present
# 20
# Adding  291 --> 280
# Node  119  already present
# 50
# Node  54  already present
# 102
# Adding  119 --> 54
# Node  271  already present
# 6
# Node  232  already present
# 109
# Adding  271 --> 232
# Node  135  already present
# 41
# Inserted node  281
# Adding  135 --> 281
# Node  258  already present
# 185
# Node  9  already present
# 9
# Adding  258 --> 9
# Node  285  already present
# 3
# Node  200  already present
# 54
# Adding  285 --> 200
# Node  330  already present
# 173
# Node  94  already present
# 124
# Adding  330 --> 94
# Inserted node  263
# Node  175  already present
# 33
# Adding  263 --> 175
# Node  212  already present
# 167
# Node  304  already present
# 7
# Adding  212 --> 304
# Node  238  already present
# 92
# Node  342  already present
# 121
# Adding  238 --> 342
# Node  284  already present
# 146
# Node  159  already present
# 127
# Adding  284 --> 159
# Node  111  already present
# 156
# Inserted node  279
# Adding  111 --> 279
# Node  141  already present
# 94
# Node  172  already present
# 28
# Adding  141 --> 172
# Node  66  already present
# 136
# Node  21  already present
# 70
# Adding  66 --> 21
# Node  313  already present
# 56
# Node  203  already present
# 107
# Adding  313 --> 203
# Node  84  already present
# 24
# Inserted node  51
# Adding  84 --> 51
# Node  139  already present
# 103
# Node  320  already present
# 142
# Adding  139 --> 320
# Node  25  already present
# 120
# Node  186  already present
# 1
# Adding  25 --> 186
# Node  252  already present
# 14
# Inserted node  338
# Adding  252 --> 338
# Node  200  already present
# 54
# Node  188  already present
# 43
# Adding  200 --> 188
# Node  59  already present
# 130
# Node  342  already present
# 121
# Adding  59 --> 342
# Inserted node  162
# Node  149  already present
# 128
# Adding  162 --> 149
# Node  304  already present
# 7
# Node  322  already present
# 29
# Adding  304 --> 322
# Node  185  already present
# 152
# Node  169  already present
# 74
# Adding  185 --> 169
# Node  252  already present
# 14
# Node  236  already present
# 0
# Adding  252 --> 236
# Node  25  already present
# 120
# Node  290  already present
# 119
# Adding  25 --> 290
# Node  56  already present
# 35
# Node  185  already present
# 152
# Adding  56 --> 185
# Node  158  already present
# 98
# Node  40  already present
# 164
# Adding  158 --> 40
# Node  238  already present
# 92
# Node  222  already present
# 161
# Adding  238 --> 222
# Node  56  already present
# 35
# Node  128  already present
# 90
# Adding  56 --> 128
# Node  199  already present
# 23
# Node  261  already present
# 115
# Adding  199 --> 261
# Node  271  already present
# 6
# Node  203  already present
# 107
# Adding  271 --> 203
# Node  63  already present
# 57
# Node  313  already present
# 56
# Adding  63 --> 313
# Node  62  already present
# 26
# Node  161  already present
# 135
# Adding  62 --> 161
# Node  302  already present
# 100
# Node  57  already present
# 53
# Adding  302 --> 57
# Inserted node  19
# Node  175  already present
# 33
# Adding  19 --> 175
# Node  98  already present
# 55
# Node  172  already present
# 28
# Adding  98 --> 172
# Node  28  already present
# 78
# Node  144  already present
# 117
# Adding  28 --> 144
# Node  249  already present
# 177
# Node  213  already present
# 13
# Adding  249 --> 213
# Node  239  already present
# 27
# Node  252  already present
# 14
# Adding  239 --> 252
# Node  332  already present
# 15
# Node  25  already present
# 120
# Adding  332 --> 25
# Node  265  already present
# 93
# Node  203  already present
# 107
# Adding  265 --> 203
# Node  303  already present
# 189
# Node  104  already present
# 153
# Adding  303 --> 104
# Node  339  already present
# 71
# Node  161  already present
# 135
# Adding  339 --> 161
# Node  119  already present
# 50
# Node  39  already present
# 178
# Adding  119 --> 39
# Node  239  already present
# 27
# Node  211  already present
# 22
# Adding  239 --> 211
# Node  313  already present
# 56
# Node  172  already present
# 28
# Adding  313 --> 172
# Node  200  already present
# 54
# Node  122  already present
# 2
# Adding  200 --> 122
# Node  104  already present
# 153
# Node  303  already present
# 189
# Adding  104 --> 303
# Inserted node  75
# Node  9  already present
# 9
# Adding  75 --> 9
# Node  137  already present
# 148
# Node  312  already present
# 79
# Adding  137 --> 312
# Node  272  already present
# 21
# Node  203  already present
# 107
# Adding  272 --> 203
# Inserted node  218
# Node  78  already present
# 95
# Adding  218 --> 78
# Node  261  already present
# 115
# Inserted node  268
# Adding  261 --> 268
# Inserted node  314
# Node  65  already present
# 17
# Adding  314 --> 65
# Node  57  already present
# 53
# Node  213  already present
# 13
# Adding  57 --> 213
# Node  21  already present
# 70
# Node  56  already present
# 35
# Adding  21 --> 56
# Node  7  already present
# 139
# Node  213  already present
# 13
# Adding  7 --> 213
# Node  139  already present
# 103
# Node  281  already present
# 198
# Adding  139 --> 281
# Inserted node  5
# Node  122  already present
# 2
# Adding  5 --> 122
# Node  55  already present
# 181
# Node  21  already present
# 70
# Adding  55 --> 21
# Node  80  already present
# 133
# Node  24  already present
# 4
# Adding  80 --> 24
# Inserted node  178
# Node  38  already present
# 99
# Adding  178 --> 38
# Node  186  already present
# 1
# Node  109  already present
# 104
# Adding  186 --> 109
# Node  304  already present
# 7
# Node  21  already present
# 70
# Adding  304 --> 21
# Inserted node  192
# Node  49  already present
# 141
# Adding  192 --> 49
# Node  203  already present
# 107
# Node  21  already present
# 70
# Adding  203 --> 21
# Node  285  already present
# 3
# Node  271  already present
# 6
# Adding  285 --> 271
# Node  122  already present
# 2
# Node  248  already present
# 112
# Adding  122 --> 248
# Node  104  already present
# 153
# Node  322  already present
# 29
# Adding  104 --> 322
# Node  312  already present
# 79
# Inserted node  243
# Adding  312 --> 243
# Node  302  already present
# 100
# Node  254  already present
# 36
# Adding  302 --> 254
# Node  236  already present
# 0
# Node  169  already present
# 74
# Adding  236 --> 169
# Node  304  already present
# 7
# Node  324  already present
# 154
# Adding  304 --> 324
# Node  266  already present
# 166
# Node  249  already present
# 177
# Adding  266 --> 249
# Node  3  already present
# 31
# Node  280  already present
# 20
# Adding  3 --> 280
# Node  243  already present
# 212
# Node  312  already present
# 79
# Adding  243 --> 312
# Node  211  already present
# 22
# Node  98  already present
# 55
# Adding  211 --> 98
# Inserted node  195
# Inserted node  181
# Adding  195 --> 181
# Inserted node  8
# Inserted node  245
# Adding  8 --> 245
# Node  297  already present
# 151
# Node  185  already present
# 152
# Adding  297 --> 185
# Node  113  already present
# 184
# Node  104  already present
# 153
# Adding  113 --> 104
# Node  10  already present
# 180
# Node  142  already present
# 106
# Adding  10 --> 142
# Inserted node  129
# Node  7  already present
# 139
# Adding  129 --> 7
# Node  56  already present
# 35
# Node  297  already present
# 151
# Adding  56 --> 297
# Node  248  already present
# 112
# Node  323  already present
# 51
# Adding  248 --> 323
# Node  273  already present
# 76
# Inserted node  328
# Adding  273 --> 328
# Node  115  already present
# 150
# Node  19  already present
# 204
# Adding  115 --> 19
# Node  36  already present
# 66
# Node  309  already present
# 172
# Adding  36 --> 309
# Node  129  already present
# 217
# Node  168  already present
# 87
# Adding  129 --> 168
# Node  242  already present
# 80
# Node  194  already present
# 37
# Adding  242 --> 194
# Node  343  already present
# 149
# Node  2  already present
# 197
# Adding  343 --> 2
# Node  21  already present
# 70
# Node  169  already present
# 74
# Adding  21 --> 169
# Node  226  already present
# 118
# Node  343  already present
# 149
# Adding  226 --> 343
# Node  40  already present
# 164
# Node  200  already present
# 54
# Adding  40 --> 200
# Node  172  already present
# 28
# Inserted node  331
# Adding  172 --> 331
# Node  326  already present
# 132
# Node  343  already present
# 149
# Adding  326 --> 343
# Node  134  already present
# 63
# Node  26  already present
# 19
# Adding  134 --> 26
# Node  332  already present
# 15
# Node  329  already present
# 11
# Adding  332 --> 329
# Node  3  already present
# 31
# Node  200  already present
# 54
# Adding  3 --> 200
# Node  331  already present
# 219
# Node  109  already present
# 104
# Adding  331 --> 109
# Inserted node  150
# Node  128  already present
# 90
# Adding  150 --> 128
# Inserted node  101
# Node  299  already present
# 47
# Adding  101 --> 299
# Node  203  already present
# 107
# Node  59  already present
# 130
# Adding  203 --> 59
# Node  231  already present
# 38
# Node  315  already present
# 49
# Adding  231 --> 315
# Node  265  already present
# 93
# Node  199  already present
# 23
# Adding  265 --> 199
# Inserted node  99
# Inserted node  296
# Adding  99 --> 296
# Node  322  already present
# 29
# Node  290  already present
# 119
# Adding  322 --> 290
# Node  296  already present
# 223
# Inserted node  102
# Adding  296 --> 102
# Node  118  already present
# 60
# Node  261  already present
# 115
# Adding  118 --> 261
# Node  238  already present
# 92
# Node  56  already present
# 35
# Adding  238 --> 56
# Node  117  already present
# 39
# Node  231  already present
# 38
# Adding  117 --> 231
# Node  312  already present
# 79
# Node  149  already present
# 128
# Adding  312 --> 149
# Node  304  already present
# 7
# Node  308  already present
# 88
# Adding  304 --> 308
# Node  105  already present
# 108
# Node  277  already present
# 62
# Adding  105 --> 277
# Node  204  already present
# 12
# Node  196  already present
# 187
# Adding  204 --> 196
# Node  315  already present
# 49
# Node  303  already present
# 189
# Adding  315 --> 303
# Node  284  already present
# 146
# Node  21  already present
# 70
# Adding  284 --> 21
# Node  239  already present
# 27
# Node  21  already present
# 70
# Adding  239 --> 21
# Node  312  already present
# 79
# Node  326  already present
# 132
# Adding  312 --> 326
# Node  277  already present
# 62
# Node  161  already present
# 135
# Adding  277 --> 161
# Node  340  already present
# 169
# Node  213  already present
# 13
# Adding  340 --> 213
# Node  98  already present
# 55
# Node  223  already present
# 67
# Adding  98 --> 223
# Node  172  already present
# 28
# Node  277  already present
# 62
# Adding  172 --> 277
# Node  128  already present
# 90
# Node  104  already present
# 153
# Adding  128 --> 104
# Node  313  already present
# 56
# Node  222  already present
# 161
# Adding  313 --> 222
# Node  98  already present
# 55
# Node  331  already present
# 219
# Adding  98 --> 331
# Node  299  already present
# 47
# Node  194  already present
# 37
# Adding  299 --> 194
# Node  122  already present
# 2
# Node  141  already present
# 94
# Adding  122 --> 141
# Node  324  already present
# 154
# Node  217  already present
# 111
# Adding  324 --> 217
# Node  291  already present
# 105
# Node  25  already present
# 120
# Adding  291 --> 25
# Node  13  already present
# 129
# Node  188  already present
# 43
# Adding  13 --> 188
# Node  104  already present
# 153
# Inserted node  318
# Adding  104 --> 318
# Node  261  already present
# 115
# Node  65  already present
# 17
# Adding  261 --> 65
# Node  265  already present
# 93
# Node  128  already present
# 90
# Adding  265 --> 128
# Inserted node  163
# Inserted node  173
# Adding  163 --> 173
# Node  116  already present
# 45
# Node  14  already present
# 157
# Adding  116 --> 14
# Node  92  already present
# 162
# Node  1  already present
# 125
# Adding  92 --> 1
# Node  26  already present
# 19
# Node  3  already present
# 31
# Adding  26 --> 3
# Inserted node  165
# Inserted node  121
# Adding  165 --> 121
# Node  3  already present
# 31
# Node  25  already present
# 120
# Adding  3 --> 25
# Node  149  already present
# 128
# Node  226  already present
# 118
# Adding  149 --> 226
# Node  328  already present
# 218
# Inserted node  306
# Adding  328 --> 306
# Node  172  already present
# 28
# Node  141  already present
# 94
# Adding  172 --> 141
# Node  303  already present
# 189
# Node  315  already present
# 49
# Adding  303 --> 315
# Node  56  already present
# 35
# Node  239  already present
# 27
# Adding  56 --> 239
# Node  122  already present
# 2
# Node  274  already present
# 68
# Adding  122 --> 274
# Node  46  already present
# 34
# Inserted node  177
# Adding  46 --> 177
# Node  249  already present
# 177
# Inserted node  180
# Adding  249 --> 180
# Node  73  already present
# 46
# Node  1  already present
# 125
# Adding  73 --> 1
# Node  272  already present
# 21
# Node  346  already present
# 5
# Adding  272 --> 346
# Node  53  already present
# 30
# Node  48  already present
# 52
# Adding  53 --> 48
# Node  199  already present
# 23
# Node  119  already present
# 50
# Adding  199 --> 119
# Node  248  already present
# 112
# Node  38  already present
# 99
# Adding  248 --> 38
# Node  24  already present
# 4
# Node  187  already present
# 134
# Adding  24 --> 187
# Node  196  already present
# 187
# Node  67  already present
# 59
# Adding  196 --> 67
# Node  304  already present
# 7
# Node  172  already present
# 28
# Adding  304 --> 172
# Inserted node  87
# Node  136  already present
# 138
# Adding  87 --> 136
# Node  323  already present
# 51
# Node  141  already present
# 94
# Adding  323 --> 141
# Node  323  already present
# 51
# Node  62  already present
# 26
# Adding  323 --> 62
# Inserted node  189
# Node  217  already present
# 111
# Adding  189 --> 217
# Node  280  already present
# 20
# Node  236  already present
# 0
# Adding  280 --> 236
# Node  115  already present
# 150
# Node  137  already present
# 148
# Adding  115 --> 137
# Node  25  already present
# 120
# Node  276  already present
# 18
# Adding  25 --> 276
# Node  186  already present
# 1
# Node  55  already present
# 181
# Adding  186 --> 55
# Node  30  already present
# 160
# Node  56  already present
# 35
# Adding  30 --> 56
# Inserted node  60
# Node  285  already present
# 3
# Adding  60 --> 285
# Node  197  already present
# 73
# Node  127  already present
# 40
# Adding  197 --> 127
# Node  334  already present
# 91
# Node  26  already present
# 19
# Adding  334 --> 26
# Node  304  already present
# 7
# Node  170  already present
# 32
# Adding  304 --> 170
# Inserted node  259
# Node  8  already present
# 215
# Adding  259 --> 8
# Node  346  already present
# 5
# Node  184  already present
# 126
# Adding  346 --> 184
# Node  186  already present
# 1
# Node  199  already present
# 23
# Adding  186 --> 199
# Node  200  already present
# 54
# Node  39  already present
# 178
# Adding  200 --> 39
# Node  185  already present
# 152
# Node  344  already present
# 58
# Adding  185 --> 344
# Node  184  already present
# 126
# Node  329  already present
# 11
# Adding  184 --> 329
# Node  149  already present
# 128
# Node  162  already present
# 203
# Adding  149 --> 162
# Node  285  already present
# 3
# Node  213  already present
# 13
# Adding  285 --> 213
# Node  185  already present
# 152
# Node  290  already present
# 119
# Adding  185 --> 290
# Node  13  already present
# 129
# Node  261  already present
# 115
# Adding  13 --> 261
# Node  204  already present
# 12
# Node  5  already present
# 209
# Adding  204 --> 5
# Node  109  already present
# 104
# Node  26  already present
# 19
# Adding  109 --> 26
# Node  169  already present
# 74
# Node  40  already present
# 164
# Adding  169 --> 40
# Node  194  already present
# 37
# Node  196  already present
# 187
# Adding  194 --> 196
# Node  85  already present
# 143
# Node  156  already present
# 188
# Adding  85 --> 156
# Node  67  already present
# 59
# Node  55  already present
# 181
# Adding  67 --> 55
# Node  98  already present
# 55
# Node  285  already present
# 3
# Adding  98 --> 285
# Node  123  already present
# 145
# Node  342  already present
# 121
# Adding  123 --> 342
# Node  118  already present
# 60
# Node  283  already present
# 116
# Adding  118 --> 283
# Inserted node  45
# Node  67  already present
# 59
# Adding  45 --> 67
# Node  80  already present
# 133
# Node  48  already present
# 52
# Adding  80 --> 48
# Node  162  already present
# 203
# Node  343  already present
# 149
# Adding  162 --> 343
# Node  272  already present
# 21
# Node  21  already present
# 70
# Adding  272 --> 21
# Node  271  already present
# 6
# Node  133  already present
# 25
# Adding  271 --> 133
# Node  67  already present
# 59
# Node  297  already present
# 151
# Adding  67 --> 297
# Node  13  already present
# 129
# Node  118  already present
# 60
# Adding  13 --> 118
# Node  115  already present
# 150
# Node  28  already present
# 78
# Adding  115 --> 28
# Node  230  already present
# 174
# Node  23  already present
# 44
# Adding  230 --> 23
# Inserted node  58
# Inserted node  269
# Adding  58 --> 269
# Node  46  already present
# 34
# Node  175  already present
# 33
# Adding  46 --> 175
# Node  25  already present
# 120
# Node  169  already present
# 74
# Adding  25 --> 169
# Node  80  already present
# 133
# Node  57  already present
# 53
# Adding  80 --> 57
# Node  135  already present
# 41
# Node  197  already present
# 73
# Adding  135 --> 197
# Node  203  already present
# 107
# Node  161  already present
# 135
# Adding  203 --> 161
# Node  113  already present
# 184
# Node  261  already present
# 115
# Adding  113 --> 261
# Node  116  already present
# 45
# Node  23  already present
# 44
# Adding  116 --> 23
# Node  275  already present
# 75
# Node  218  already present
# 206
# Adding  275 --> 218
# Node  285  already present
# 3
# Node  170  already present
# 32
# Adding  285 --> 170
# Node  314  already present
# 208
# Node  199  already present
# 23
# Adding  314 --> 199
# Node  279  already present
# 200
# Node  111  already present
# 156
# Adding  279 --> 111
# Node  126  already present
# 113
# Node  48  already present
# 52
# Adding  126 --> 48
# Node  36  already present
# 66
# Node  320  already present
# 142
# Adding  36 --> 320
# Node  137  already present
# 148
# Inserted node  167
# Adding  137 --> 167
# Node  140  already present
# 147
# Node  326  already present
# 132
# Adding  140 --> 326
# Node  130  already present
# 10
# Node  48  already present
# 52
# Adding  130 --> 48
# Node  302  already present
# 100
# Node  94  already present
# 124
# Adding  302 --> 94
# Node  315  already present
# 49
# Node  80  already present
# 133
# Adding  315 --> 80
# Node  101  already present
# 221
# Node  80  already present
# 133
# Adding  101 --> 80
# Node  23  already present
# 44
# Inserted node  227
# Adding  23 --> 227
# Node  92  already present
# 162
# Node  194  already present
# 37
# Adding  92 --> 194
# Node  2  already present
# 197
# Node  20  already present
# 82
# Adding  2 --> 20
# Node  72  already present
# 163
# Node  252  already present
# 14
# Adding  72 --> 252
# Node  323  already present
# 51
# Inserted node  96
# Adding  323 --> 96
# Inserted node  91
# Node  8  already present
# 215
# Adding  91 --> 8
# Inserted node  143
# Node  177  already present
# 231
# Adding  143 --> 177
# Node  200  already present
# 54
# Node  30  already present
# 160
# Adding  200 --> 30
# Node  257  already present
# 186
# Node  26  already present
# 19
# Adding  257 --> 26
# Node  331  already present
# 219
# Node  324  already present
# 154
# Adding  331 --> 324
# Node  142  already present
# 106
# Node  322  already present
# 29
# Adding  142 --> 322
# Node  188  already present
# 43
# Node  104  already present
# 153
# Adding  188 --> 104
# Node  239  already present
# 27
# Node  276  already present
# 18
# Adding  239 --> 276
# Node  23  already present
# 44
# Inserted node  61
# Adding  23 --> 61
# Node  325  already present
# 61
# Node  21  already present
# 70
# Adding  325 --> 21
# Node  204  already present
# 12
# Node  94  already present
# 124
# Adding  204 --> 94
# Node  346  already present
# 5
# Node  194  already present
# 37
# Adding  346 --> 194
# Node  223  already present
# 67
# Node  186  already present
# 1
# Adding  223 --> 186
# Node  56  already present
# 35
# Node  252  already present
# 14
# Adding  56 --> 252
# Node  113  already present
# 184
# Node  142  already present
# 106
# Adding  113 --> 142
# Node  26  already present
# 19
# Node  21  already present
# 70
# Adding  26 --> 21
# Node  285  already present
# 3
# Node  323  already present
# 51
# Adding  285 --> 323
# Node  290  already present
# 119
# Node  176  already present
# 8
# Adding  290 --> 176
# Inserted node  93
# Node  167  already present
# 240
# Adding  93 --> 167
# Node  276  already present
# 18
# Node  122  already present
# 2
# Adding  276 --> 122
# Node  96  already present
# 242
# Node  133  already present
# 25
# Adding  96 --> 133
# Inserted node  41
# Node  243  already present
# 212
# Adding  41 --> 243
# Node  188  already present
# 43
# Node  304  already present
# 7
# Adding  188 --> 304
# Node  203  already present
# 107
# Node  313  already present
# 56
# Adding  203 --> 313
# Node  200  already present
# 54
# Node  170  already present
# 32
# Adding  200 --> 170
# Node  232  already present
# 109
# Node  200  already present
# 54
# Adding  232 --> 200
# Inserted node  235
# Node  5  already present
# 209
# Adding  235 --> 5
# Inserted node  6
# Inserted node  89
# Adding  6 --> 89
# Node  171  already present
# 155
# Inserted node  107
# Adding  171 --> 107
# Node  257  already present
# 186
# Node  169  already present
# 74
# Adding  257 --> 169
# Node  224  already present
# 114
# Node  232  already present
# 109
# Adding  224 --> 232
# Node  271  already present
# 6
# Inserted node  79
# Adding  271 --> 79
# Node  187  already present
# 134
# Node  24  already present
# 4
# Adding  187 --> 24
# Node  141  already present
# 94
# Node  67  already present
# 59
# Adding  141 --> 67
# Node  113  already present
# 184
# Node  66  already present
# 136
# Adding  113 --> 66
# Node  56  already present
# 35
# Node  103  already present
# 42
# Adding  56 --> 103
# Node  59  already present
# 130
# Node  271  already present
# 6
# Adding  59 --> 271
# Node  40  already present
# 164
# Node  213  already present
# 13
# Adding  40 --> 213
# Node  158  already present
# 98
# Node  26  already present
# 19
# Adding  158 --> 26
# Node  211  already present
# 22
# Node  82  already present
# 16
# Adding  211 --> 82
# Node  285  already present
# 3
# Inserted node  208
# Adding  285 --> 208
# Node  119  already present
# 50
# Node  285  already present
# 3
# Adding  119 --> 285
# Node  26  already present
# 19
# Node  9  already present
# 9
# Adding  26 --> 9
# Node  40  already present
# 164
# Node  133  already present
# 25
# Adding  40 --> 133
# Node  143  already present
# 244
# Node  175  already present
# 33
# Adding  143 --> 175
# Node  56  already present
# 35
# Inserted node  132
# Adding  56 --> 132
# Node  45  already present
# 237
# Inserted node  221
# Adding  45 --> 221
# Node  212  already present
# 167
# Node  344  already present
# 58
# Adding  212 --> 344
# Node  285  already present
# 3
# Node  315  already present
# 49
# Adding  285 --> 315
# Inserted node  301
# Node  324  already present
# 154
# Adding  301 --> 324
# Node  21  already present
# 70
# Node  170  already present
# 32
# Adding  21 --> 170
# Node  326  already present
# 132
# Node  214  already present
# 81
# Adding  326 --> 214
# Node  281  already present
# 198
# Node  159  already present
# 127
# Adding  281 --> 159
# Node  281  already present
# 198
# Node  251  already present
# 179
# Adding  281 --> 251
# Node  109  already present
# 104
# Node  67  already present
# 59
# Adding  109 --> 67
# Node  25  already present
# 120
# Node  232  already present
# 109
# Adding  25 --> 232
# Node  59  already present
# 130
# Node  56  already present
# 35
# Adding  59 --> 56
# Node  92  already present
# 162
# Node  180  already present
# 232
# Adding  92 --> 180
# Node  122  already present
# 2
# Node  284  already present
# 146
# Adding  122 --> 284
# Node  322  already present
# 29
# Node  48  already present
# 52
# Adding  322 --> 48
# Node  277  already present
# 62
# Node  308  already present
# 88
# Adding  277 --> 308
# Node  290  already present
# 119
# Node  323  already present
# 51
# Adding  290 --> 323
# Node  167  already present
# 240
# Node  93  already present
# 246
# Adding  167 --> 93
# Inserted node  250
# Node  59  already present
# 130
# Adding  250 --> 59
# Inserted node  106
# Inserted node  29
# Adding  106 --> 29
# Node  274  already present
# 68
# Node  341  already present
# 89
# Adding  274 --> 341
# Node  249  already present
# 177
# Node  302  already present
# 100
# Adding  249 --> 302
# Node  118  already present
# 60
# Node  239  already present
# 27
# Adding  118 --> 239
# Node  111  already present
# 156
# Inserted node  337
# Adding  111 --> 337
# Node  252  already present
# 14
# Node  109  already present
# 104
# Adding  252 --> 109
# Node  56  already present
# 35
# Node  55  already present
# 181
# Adding  56 --> 55
# Node  80  already present
# 133
# Node  266  already present
# 166
# Adding  80 --> 266
# Node  252  already present
# 14
# Node  134  already present
# 63
# Adding  252 --> 134
# Node  104  already present
# 153
# Node  67  already present
# 59
# Adding  104 --> 67
# Node  94  already present
# 124
# Node  346  already present
# 5
# Adding  94 --> 346
# Node  141  already present
# 94
# Node  280  already present
# 20
# Adding  141 --> 280
# Node  325  already present
# 61
# Node  161  already present
# 135
# Adding  325 --> 161
# Node  322  already present
# 29
# Node  203  already present
# 107
# Adding  322 --> 203
# Node  96  already present
# 242
# Node  274  already present
# 68
# Adding  96 --> 274
# Node  158  already present
# 98
# Node  315  already present
# 49
# Adding  158 --> 315
# Node  199  already present
# 23
# Node  98  already present
# 55
# Adding  199 --> 98
# Node  134  already present
# 63
# Node  132  already present
# 254
# Adding  134 --> 132
# Node  280  already present
# 20
# Node  98  already present
# 55
# Adding  280 --> 98
# Node  254  already present
# 36
# Node  187  already present
# 134
# Adding  254 --> 187
# Node  329  already present
# 11
# Node  269  already present
# 239
# Adding  329 --> 269
# Node  297  already present
# 151
# Node  21  already present
# 70
# Adding  297 --> 21
# Inserted node  100
# Node  150  already present
# 220
# Adding  100 --> 150
# Inserted node  110
# Inserted node  264
# Adding  110 --> 264
# Node  266  already present
# 166
# Node  330  already present
# 173
# Adding  266 --> 330
# Node  171  already present
# 155
# Node  150  already present
# 220
# Adding  171 --> 150
# Node  322  already present
# 29
# Node  45  already present
# 237
# Adding  322 --> 45
# Node  72  already present
# 163
# Node  165  already present
# 228
# Adding  72 --> 165
# Node  344  already present
# 58
# Node  257  already present
# 186
# Adding  344 --> 257
# Node  184  already present
# 126
# Node  21  already present
# 70
# Adding  184 --> 21
# Node  119  already present
# 50
# Node  332  already present
# 15
# Adding  119 --> 332
# Node  257  already present
# 186
# Node  236  already present
# 0
# Adding  257 --> 236
# Node  277  already present
# 62
# Node  324  already present
# 154
# Adding  277 --> 324
# Node  332  already present
# 15
# Node  248  already present
# 112
# Adding  332 --> 248
# Node  329  already present
# 11
# Node  119  already present
# 50
# Adding  329 --> 119
# Inserted node  225
# Inserted node  86
# Adding  225 --> 86
# Node  232  already present
# 109
# Node  56  already present
# 35
# Adding  232 --> 56
# Node  291  already present
# 105
# Node  224  already present
# 114
# Adding  291 --> 224
# Node  53  already present
# 30
# Node  196  already present
# 187
# Adding  53 --> 196
# Node  315  already present
# 49
# Node  213  already present
# 13
# Adding  315 --> 213
# Node  322  already present
# 29
# Node  136  already present
# 138
# Adding  322 --> 136
# Node  181  already present
# 214
# Inserted node  152
# Adding  181 --> 152
# Node  141  already present
# 94
# Node  257  already present
# 186
# Adding  141 --> 257
# Node  180  already present
# 232
# Node  80  already present
# 133
# Adding  180 --> 80
# Node  26  already present
# 19
# Node  199  already present
# 23
# Adding  26 --> 199
# Node  45  already present
# 237
# Node  104  already present
# 153
# Adding  45 --> 104
# Node  332  already present
# 15
# Node  67  already present
# 59
# Adding  332 --> 67
# Node  303  already present
# 189
# Node  45  already present
# 237
# Adding  303 --> 45
# Node  250  already present
# 257
# Node  252  already present
# 14
# Adding  250 --> 252
# Node  3  already present
# 31
# Node  26  already present
# 19
# Adding  3 --> 26
# Node  98  already present
# 55
# Inserted node  148
# Adding  98 --> 148
# Node  185  already present
# 152
# Node  55  already present
# 181
# Adding  185 --> 55
# Node  172  already present
# 28
# Node  239  already present
# 27
# Adding  172 --> 239
# Inserted node  295
# Node  239  already present
# 27
# Adding  295 --> 239
# Node  325  already present
# 61
# Node  98  already present
# 55
# Adding  325 --> 98
# Node  252  already present
# 14
# Node  113  already present
# 184
# Adding  252 --> 113
# Node  323  already present
# 51
# Node  119  already present
# 50
# Adding  323 --> 119
# Node  188  already present
# 43
# Node  315  already present
# 49
# Adding  188 --> 315
# Node  55  already present
# 181
# Node  203  already present
# 107
# Adding  55 --> 203
# Node  137  already present
# 148
# Node  111  already present
# 156
# Adding  137 --> 111
# Node  224  already present
# 114
# Node  200  already present
# 54
# Adding  224 --> 200
# Node  194  already present
# 37
# Node  80  already present
# 133
# Adding  194 --> 80
# Node  295  already present
# 268
# Node  104  already present
# 153
# Adding  295 --> 104
# Node  17  already present
# 131
# Node  140  already present
# 147
# Adding  17 --> 140
# Node  266  already present
# 166
# Node  302  already present
# 100
# Adding  266 --> 302
# Node  232  already present
# 109
# Node  212  already present
# 167
# Adding  232 --> 212
# Node  249  already present
# 177
# Node  24  already present
# 4
# Adding  249 --> 24
# Node  200  already present
# 54
# Node  323  already present
# 51
# Adding  200 --> 323
# Node  323  already present
# 51
# Node  122  already present
# 2
# Adding  323 --> 122
# Node  203  already present
# 107
# Node  65  already present
# 17
# Adding  203 --> 65
# Node  259  already present
# 236
# Inserted node  201
# Adding  259 --> 201
# Node  161  already present
# 135
# Node  56  already present
# 35
# Adding  161 --> 56
# Node  119  already present
# 50
# Node  252  already present
# 14
# Adding  119 --> 252
# Node  238  already present
# 92
# Node  82  already present
# 16
# Adding  238 --> 82
# Node  197  already present
# 73
# Node  251  already present
# 179
# Adding  197 --> 251
# Node  105  already present
# 108
# Node  272  already present
# 21
# Adding  105 --> 272
# Node  291  already present
# 105
# ...
# Node  312  already present
# 79
# Node  144  already present
# 117
# Adding  312 --> 144
# Node  164  already present
# 312
# Node  285  already present
# 3
# Adding  164 --> 285
# Node  39  already present
# 178
# Node  257  already present
# 186
# Adding  39 --> 257
# Node  132  already present
# 254
# Node  242  already present
# 80
# Adding  132 --> 242
# Node  239  already present
# 27
# Node  40  already present
# 164
# Adding  239 --> 40
# Node  230  already present
# 174
# Node  214  already present
# 81
# Adding  230 --> 214
# Node  80  already present
# 133
# Node  330  already present
# 173
# Adding  80 --> 330
# Node  149  already present
# 128
# Node  14  already present
# 157
# Adding  149 --> 14
# Node  126  already present
# 113
# Node  1  already present
# 125
# Adding  126 --> 1
# Node  21  already present
# 70
# Node  313  already present
# 56
# Adding  21 --> 313
# Node  113  already present
# 184
# Node  199  already present
# 23
# Adding  113 --> 199
# Node  272  already present
# 21
# Node  85  already present
# 143
# Adding  272 --> 85
# Node  257  already present
# 186
# Node  105  already present
# 108
# Adding  257 --> 105
# Node  66  already present
# 136
# Node  134  already present
# 63
# Adding  66 --> 134
# Node  271  already present
# 6
# Node  63  already present
# 57
# Adding  271 --> 63
# Node  274  already present
# 68
# Node  185  already present
# 152
# Adding  274 --> 185
# Node  172  already present
# 28
# Node  203  already present
# 107
# Adding  172 --> 203
# Node  313  already present
# 56
# Node  119  already present
# 50
# Adding  313 --> 119
# Node  119  already present
# 50
# Node  1  already present
# 125
# Adding  119 --> 1
# Node  203  already present
# 107
# Node  341  already present
# 89
# Adding  203 --> 341
# Node  119  already present
# 50
# Node  248  already present
# 112
# Adding  119 --> 248
# Node  8  already present
# 215
# Node  110  already present
# 262
# Adding  8 --> 110
# Node  324  already present
# 154
# Node  27  already present
# 101
# Adding  324 --> 27
# Node  98  already present
# 55
# Node  200  already present
# 54
# Adding  98 --> 200
# Node  323  already present
# 51
# Node  188  already present
# 43
# Adding  323 --> 188
# Node  232  already present
# 109
# Node  271  already present
# 6
# Adding  232 --> 271
# Node  4  already present
# 293
# Node  181  already present
# 214
# Adding  4 --> 181
# Node  21  already present
# 70
# Node  127  already present
# 40
# Adding  21 --> 127
# Node  304  already present
# 7
# Node  285  already present
# 3
# Adding  304 --> 285
# Node  158  already present
# 98
# Node  232  already present
# 109
# Adding  158 --> 232
# Node  211  already present
# 22
# Node  172  already present
# 28
# Adding  211 --> 172
# Node  204  already present
# 12
# Node  180  already present
# 232
# Adding  204 --> 180
# Node  45  already present
# 237
# Node  132  already present
# 254
# Adding  45 --> 132
# Node  98  already present
# 55
# Node  13  already present
# 129
# Adding  98 --> 13
# Node  142  already present
# 106
# Node  203  already present
# 107
# Adding  142 --> 203
# Node  304  already present
# 7
# Node  246  already present
# 144
# Adding  304 --> 246
# Node  269  already present
# 239
# Node  100  already present
# 261
# Adding  269 --> 100
# Node  25  already present
# 120
# Node  65  already present
# 17
# Adding  25 --> 65
# Node  55  already present
# 181
# Node  185  already present
# 152
# Adding  55 --> 185
# Node  213  already present
# 13
# Node  56  already present
# 35
# Adding  213 --> 56
# Node  332  already present
# 15
# Node  213  already present
# 13
# Adding  332 --> 213
# Node  285  already present
# 3
# Node  332  already present
# 15
# Adding  285 --> 332
# Node  142  already present
# 106
# Node  188  already present
# 43
# Adding  142 --> 188
# Node  324  already present
# 154
# Node  224  already present
# 114
# Adding  324 --> 224
# Node  202  already present
# 305
# Node  173  already present
# 227
# Adding  202 --> 173
# Node  48  already present
# 52
# Node  126  already present
# 113
# Adding  48 --> 126
# Node  187  already present
# 134
# Node  266  already present
# 166
# Adding  187 --> 266
# Node  9  already present
# 9
# Node  3  already present
# 31
# Adding  9 --> 3
# Node  113  already present
# 184
# Node  169  already present
# 74
# Adding  113 --> 169
# Node  246  already present
# 144
# Node  285  already present
# 3
# Adding  246 --> 285
# Node  303  already present
# 189
# Node  213  already present
# 13
# Adding  303 --> 213
# Node  142  already present
# 106
# Node  239  already present
# 27
# Adding  142 --> 239
# Node  251  already present
# 179
# Node  184  already present
# 126
# Adding  251 --> 184
# Node  53  already present
# 30
# Node  242  already present
# 80
# Adding  53 --> 242
# Node  172  already present
# 28
# Node  231  already present
# 38
# Adding  172 --> 231
# Node  188  already present
# 43
# Node  13  already present
# 129
# Adding  188 --> 13
# Node  203  already present
# 107
# Node  338  already present
# 202
# Adding  203 --> 338
# Node  111  already present
# 156
# Node  137  already present
# 148
# Adding  111 --> 137
# Node  214  already present
# 81
# Node  19  already present
# 204
# Adding  214 --> 19
# Node  41  already present
# 247
# Node  326  already present
# 132
# Adding  41 --> 326
# Node  113  already present
# 184
# Node  134  already present
# 63
# Adding  113 --> 134
# Node  98  already present
# 55
# Node  304  already present
# 7
# Adding  98 --> 304
# Node  10  already present
# 180
# Node  332  already present
# 15
# Adding  10 --> 332
# Node  184  already present
# 126
# Node  108  already present
# 72
# Adding  184 --> 108
# Node  343  already present
# 149
# Node  20  already present
# 82
# Adding  343 --> 20
# Node  170  already present
# 32
# Node  239  already present
# 27
# Adding  170 --> 239
# Node  147  already present
# 308
# Node  89  already present
# 250
# Adding  147 --> 89
# Node  141  already present
# 94
# Node  25  already present
# 120
# Adding  141 --> 25
# Node  236  already present
# 0
# Node  84  already present
# 24
# Adding  236 --> 84
# Node  34  already present
# 331
# Node  173  already present
# 227
# Adding  34 --> 173
# Node  9  already present
# 9
# Node  231  already present
# 38
# Adding  9 --> 231
# Node  67  already present
# 59
# Node  82  already present
# 16
# Adding  67 --> 82
# Node  148  already present
# 267
# Node  224  already present
# 114
# Adding  148 --> 224
# Node  320  already present
# 142
# Node  197  already present
# 73
# Adding  320 --> 197
# Node  26  already present
# 19
# Node  142  already present
# 106
# Adding  26 --> 142
# Node  241  already present
# 322
# Node  49  already present
# 141
# Adding  241 --> 49
# Node  170  already present
# 32
# Node  119  already present
# 50
# Adding  170 --> 119
# Node  87  already present
# 233
# Node  291  already present
# 105
# Adding  87 --> 291
# Node  199  already present
# 23
# Node  200  already present
# 54
# Adding  199 --> 200
# Node  320  already present
# 142
# Node  80  already present
# 133
# Adding  320 --> 80
# Node  143  already present
# 244
# Node  321  already present
# 273
# Adding  143 --> 321
# Node  217  already present
# 111
# Node  189  already present
# 234
# Adding  217 --> 189
# Node  303  already present
# 189
# Node  67  already present
# 59
# Adding  303 --> 67
# Node  9  already present
# 9
# Node  188  already present
# 43
# Adding  9 --> 188
# Node  122  already present
# 2
# Node  239  already present
# 27
# Adding  122 --> 239
# Node  302  already present
# 100
# Node  299  already present
# 47
# Adding  302 --> 299
# Node  118  already present
# 60
# Node  203  already present
# 107
# Adding  118 --> 203
# Node  62  already present
# 26
# Node  186  already present
# 1
# Adding  62 --> 186
# Node  170  already present
# 32
# Node  62  already present
# 26
# Adding  170 --> 62
# Node  119  already present
# 50
# Node  324  already present
# 154
# Adding  119 --> 324
# Node  137  already present
# 148
# Node  140  already present
# 147
# Adding  137 --> 140
# Node  281  already present
# 198
# Node  135  already present
# 41
# Adding  281 --> 135
# Node  239  already present
# 27
# Node  265  already present
# 93
# Adding  239 --> 265
# Node  200  already present
# 54
# Node  45  already present
# 237
# Adding  200 --> 45
# Node  66  already present
# 136
# Node  122  already present
# 2
# Adding  66 --> 122
# Node  323  already present
# 51
# Node  26  already present
# 19
# Adding  323 --> 26
# Node  203  already present
# 107
# Node  270  already present
# 64
# Adding  203 --> 270
# Node  222  already present
# 161
# Node  211  already present
# 22
# Adding  222 --> 211
# Node  98  already present
# 55
# Node  239  already present
# 27
# Adding  98 --> 239
# Node  239  already present
# 27
# Node  142  already present
# 106
# Adding  239 --> 142
# Node  98  already present
# 55
# Node  109  already present
# 104
# Adding  98 --> 109
# Node  188  already present
# 43
# Node  208  already present
# 253
# Adding  188 --> 208
# Node  67  already present
# 59
# Node  224  already present
# 114
# Adding  67 --> 224
# Node  119  already present
# 50
# Node  318  already present
# 225
# Adding  119 --> 318
# Node  119  already present
# 50
# Node  261  already present
# 115
# Adding  119 --> 261
# Node  59  already present
# 130
# Node  118  already present
# 60
# Adding  59 --> 118
# Node  67  already present
# 59
# Node  122  already present
# 2
# Adding  67 --> 122
# Node  302  already present
# 100
# Node  48  already present
# 52
# Adding  302 --> 48
# Node  206  already present
# 309
# Node  121  already present
# 229
# Adding  206 --> 121
# Node  263  already present
# 199
# Node  68  already present
# 274
# Adding  263 --> 68
# Node  26  already present
# 19
# Node  66  already present
# 136
# Adding  26 --> 66
# Node  236  already present
# 0
# Node  30  already present
# 160
# Adding  236 --> 30
# Node  324  already present
# 154
# Node  67  already present
# 59
# Adding  324 --> 67
# Node  170  already present
# 32
# Node  122  already present
# 2
# Adding  170 --> 122
# Node  88  already present
# 69
# Node  178  already present
# 210
# Adding  88 --> 178
# Node  56  already present
# 35
# Node  113  already present
# 184
# Adding  56 --> 113
# Node  137  already present
# 148
# Node  243  already present
# 212
# Adding  137 --> 243
# Node  25  already present
# 120
# Node  246  already present
# 144
# Adding  25 --> 246
# Node  41  already present
# 247
# Node  20  already present
# 82
# Adding  41 --> 20
# Node  199  already present
# 23
# Node  26  already present
# 19
# Adding  199 --> 26
# Node  254  already present
# 36
# Node  180  already present
# 232
# Adding  254 --> 180
# Node  40  already present
# 164
# Node  258  already present
# 185
# Adding  40 --> 258
# Node  119  already present
# 50
# Node  189  already present
# 234
# Adding  119 --> 189
# Node  304  already present
# 7
# Node  31  already present
# 137
# Adding  304 --> 31
# Node  186  already present
# 1
# Node  25  already present
# 120
# Adding  186 --> 25
# Node  140  already present
# 147
# Node  28  already present
# 78
# Adding  140 --> 28
# Node  98  already present
# 55
# Node  277  already present
# 62
# Adding  98 --> 277
# Node  26  already present
# 19
# Node  56  already present
# 35
# Adding  26 --> 56
# Node  176  already present
# 8
# Node  122  already present
# 2
# Adding  176 --> 122
# Node  317  already present
# 97
# Node  40  already present
# 164
# Adding  317 --> 40
# Node  134  already present
# 63
# Node  277  already present
# 62
# Adding  134 --> 277
# Node  298  already present
# 277
# Node  199  already present
# 23
# Adding  298 --> 199
# Node  281  already present
# 198
# Node  122  already present
# 2
# Adding  281 --> 122
# Node  265  already present
# 93
# Node  252  already present
# 14
# Adding  265 --> 252
# Node  51  already present
# 201
# Node  31  already present
# 137
# Adding  51 --> 31
# Node  285  already present
# 3
# Node  188  already present
# 43
# Adding  285 --> 188
# Node  265  already present
# 93
# Node  26  already present
# 19
# Adding  265 --> 26
# Node  280  already present
# 20
# Node  297  already present
# 151
# Adding  280 --> 297
# Node  63  already present
# 57
# Node  271  already present
# 6
# Adding  63 --> 271
# Node  271  already present
# 6
# Node  314  already present
# 208
# Adding  271 --> 314
# Node  322  already present
# 29
# Node  67  already present
# 59
# Adding  322 --> 67
# Node  297  already present
# 151
# Node  25  already present
# 120
# Adding  297 --> 25
# Node  26  already present
# 19
# Node  248  already present
# 112
# Adding  26 --> 248
# Node  304  already present
# 7
# Node  13  already present
# 129
# Adding  304 --> 13
# Node  181  already present
# 214
# Node  218  already present
# 206
# Adding  181 --> 218
# Node  68  already present
# 274
# Node  296  already present
# 223
# Adding  68 --> 296
# Node  45  already present
# 237
# Node  345  already present
# 96
# Adding  45 --> 345
# Node  89  already present
# 250
# Node  147  already present
# 308
# Adding  89 --> 147
# Node  66  already present
# 136
# Node  308  already present
# 88
# Adding  66 --> 308
# Node  315  already present
# 49
# Node  1  already present
# 125
# Adding  315 --> 1
# Node  185  already present
# 152
# Node  26  already present
# 19
# Adding  185 --> 26
# Node  181  already present
# 214
# Node  306  already present
# 230
# Adding  181 --> 306
# Node  271  already present
# 6
# Node  56  already present
# 35
# Adding  271 --> 56
# Node  105  already present
# 108
# Node  315  already present
# 49
# Adding  105 --> 315
# Node  270  already present
# 64
# Node  25  already present
# 120
# Adding  270 --> 25
# Node  261  already present
# 115
# Node  56  already present
# 35
# Adding  261 --> 56
# Node  158  already present
# 98
# Node  60  already present
# 235
# Adding  158 --> 60
# Node  231  already present
# 38
# Node  25  already present
# 120
# Adding  231 --> 25
# Node  176  already present
# 8
# Node  188  already present
# 43
# Adding  176 --> 188
# Node  246  already present
# 144
# Node  25  already present
# 120
# Adding  246 --> 25
# Node  122  already present
# 2
# Node  136  already present
# 138
# Adding  122 --> 136
# Node  248  already present
# 112
# Node  134  already present
# 63
# Adding  248 --> 134
# Node  331  already present
# 219
# Node  25  already present
# 120
# Adding  331 --> 25
# Node  25  already present
# 120
# Node  332  already present
# 15
# Adding  25 --> 332
# Node  97  already present
# 284
# Node  182  already present
# 320
# Adding  97 --> 182
# Node  201  already present
# 269
# Node  259  already present
# 236
# Adding  201 --> 259
# Node  60  already present
# 235
# Node  313  already present
# 56
# Adding  60 --> 313
# Node  156  already present
# 188
# Node  272  already present
# 21
# Adding  156 --> 272
# Node  268  already present
# 207
# Node  172  already present
# 28
# Adding  268 --> 172
# Node  122  already present
# 2
# Node  251  already present
# 179
# Adding  122 --> 251
# Node  172  already present
# 28
# Node  313  already present
# 56
# Adding  172 --> 313
# Node  342  already present
# 121
# Node  285  already present
# 3
# Adding  342 --> 285
# Node  299  already present
# 47
# Node  1  already present
# 125
# Adding  299 --> 1
# Node  92  already present
# 162
# Node  80  already present
# 133
# Adding  92 --> 80
# Node  343  already present
# 149
# Node  144  already present
# 117
# Adding  343 --> 144
# Node  339  already present
# 71
# Node  158  already present
# 98
# Adding  339 --> 158
# Node  56  already present
# 35
# Node  142  already present
# 106
# Adding  56 --> 142
# Node  109  already present
# 104
# Node  325  already present
# 61
# Adding  109 --> 325
# Node  252  already present
# 14
# Node  170  already present
# 32
# Adding  252 --> 170
# Node  177  already present
# 231
# Node  68  already present
# 274
# Adding  177 --> 68
# Node  265  already present
# 93
# Node  313  already present
# 56
# Adding  265 --> 313
# Node  219  already present
# 315
# Node  154  already present
# 318
# Adding  219 --> 154
# Node  169  already present
# 74
# Node  252  already present
# 14
# Adding  169 --> 252
# Node  24  already present
# 4
# Node  249  already present
# 177
# Adding  24 --> 249
# Node  199  already present
# 23
# Node  313  already present
# 56
# Adding  199 --> 313
# Node  322  already present
# 29
# Node  224  already present
# 114
# Adding  322 --> 224
# Node  128  already present
# 90
# Node  98  already present
# 55
# Adding  128 --> 98
# Node  200  already present
# 54
# Node  142  already present
# 106
# Adding  200 --> 142
# Node  30  already present
# 160
# Node  178  already present
# 210
# Adding  30 --> 178
# Node  13  already present
# 129
# Node  325  already present
# 61
# Adding  13 --> 325
# Node  170  already present
# 32
# Node  252  already present
# 14
# Adding  170 --> 252
# Node  322  already present
# 29
# Node  271  already present
# 6
# Adding  322 --> 271
# Node  88  already present
# 69
# Node  25  already present
# 120
# Adding  88 --> 25
# Node  127  already present
# 40
# Node  197  already present
# 73
# Adding  127 --> 197
# Node  26  already present
# 19
# Node  212  already present
# 167
# Adding  26 --> 212
# Node  62  already present
# 26
# Node  96  already present
# 242
# Adding  62 --> 96
# Node  171  already present
# 155
# Node  58  already present
# 238
# Adding  171 --> 58
# Node  326  already present
# 132
# Node  20  already present
# 82
# Adding  326 --> 20
# Node  85  already present
# 143
# Node  75  already present
# 205
# Adding  85 --> 75
# Node  98  already present
# 55
# Node  332  already present
# 15
# Adding  98 --> 332
# Node  291  already present
# 105
# Node  339  already present
# 71
# Adding  291 --> 339

# %%
def calculate_eigen(g):
    eigen=g.evcent(directed=False)
    for i in range(1,6):
        maxVal=max(eigen)
        print(i,'==node',g.vs[eigen.index(maxVal)]['name'],' with score of ',maxVal)
        eigen.remove(maxVal)
    eigen=g.evcent(directed=False)
    return eigen

# %%
def calculate_closeness(g):
    close=g.closeness(g.vs)
    for i in range(1,6):
        maxVal=max(close)
        print(i,'==node',g.vs[close.index(maxVal)]['name'],' with score of ',maxVal)
        close.remove(maxVal)
    close=g.closeness(g.vs)
    return close

# %%
def calculate_between(g):
    between=g.betweenness(g.vs)
    for i in range(1,6):
        maxVal=max(between)
        print(i,'==node',g.vs[between.index(maxVal)]['name'],' with score of ',maxVal)
        between.remove(maxVal)
    between=g.betweenness(g.vs)
    return between

# %%
print('Eigen Vector')
global eigen
eigen=calculate_eigen(g)
global close
global between
print('Closeness')
close=calculate_closeness(g)
print('Betweenness')
between=calculate_between(g)
# Out:
# Eigen Vector
# 1 ==node 56  with score of  1.0
# 2 ==node 344  with score of  0.9964259456909766
# 3 ==node 271  with score of  0.9774565828157538
# 4 ==node 276  with score of  0.9407290596260326
# 5 ==node 213  with score of  0.8940959611043995
# Closeness
# 1 ==node 33  with score of  1.0
# 2 ==node 33  with score of  1.0
# 3 ==node 112  with score of  1.0
# 4 ==node 120  with score of  1.0
# 5 ==node 120  with score of  1.0
# Betweenness
# 1 ==node 277  with score of  14607.825084462022
# 2 ==node 175  with score of  13520.81138188322
# 3 ==node 338  with score of  9826.700526023209
# 4 ==node 188  with score of  7155.239878444397
# 5 ==node 144  with score of  4690.348420810955

# %% [markdown]
# ## Now Analyzing the graph using various Centrality measures

# %%
from igraph import * 
G=Graph()

load_dataset('abd',G)

N=len(G.vs)
layt=G.layout('kk', dim=3)

labels=[]
print(type(labels))
for eachNde in G.vs:
    labels.append(eachNde['name'])

Edges=list()
print(type(Edges))
for eachTuple in G.es:
    Edges.append(eachTuple.tuple)
    
Xn=[layt[k][0] for k in range(N)]# x-coordinates of nodes
Yn=[layt[k][1] for k in range(N)]# y-coordinates
Zn=[layt[k][2] for k in range(N)]# z-coordinates
Xe=[]
Ye=[]
Ze=[]

for e in Edges:
    Xe+=[layt[e[0]][0],layt[e[1]][0], None]# x-coordinates of edge ends
    Ye+=[layt[e[0]][1],layt[e[1]][1], None]
    Ze+=[layt[e[0]][2],layt[e[1]][2], None]
# Out:
# 0
# fileName= C:\Users\admin\Desktop\Baveet\Social_Datasets\facebook\edges\0.edges
# Inserted node  186
# Adding  236 --> 186
# Inserted node  122
# Inserted node  285
# Adding  122 --> 285
# Inserted node  24
# Inserted node  346
# Adding  24 --> 346
# Inserted node  271
# Inserted node  304
# Adding  271 --> 304
# Inserted node  176
# Inserted node  9
# Adding  176 --> 9
# Inserted node  130
# Inserted node  329
# Adding  130 --> 329
# Inserted node  204
# Inserted node  213
# Adding  204 --> 213
# Inserted node  252
# Inserted node  332
# Adding  252 --> 332
# Inserted node  82
# Inserted node  65
# Adding  82 --> 65
# Inserted node  276
# Inserted node  26
# Adding  276 --> 26
# Inserted node  280
# Inserted node  272
# Adding  280 --> 272
# Inserted node  211
# Inserted node  199
# Adding  211 --> 199
# Inserted node  84
# Node  236  already present
# 0
# Adding  84 --> 236
# Inserted node  133
# Inserted node  62
# Adding  133 --> 62
# Inserted node  239
# Inserted node  172
# Adding  239 --> 172
# Inserted node  322
# Inserted node  53
# Adding  322 --> 53
# Inserted node  3
# Inserted node  170
# Adding  3 --> 170
# Inserted node  175
# Inserted node  46
# Adding  175 --> 46
# Node  170  already present
# 32
# Node  176  already present
# 8
# Adding  170 --> 176
# Node  170  already present
# 32
# Inserted node  56
# Adding  170 --> 56
# Inserted node  254
# Inserted node  194
# Adding  254 --> 194
# Inserted node  231
# Inserted node  117
# Adding  231 --> 117
# Inserted node  127
# Inserted node  135
# Adding  127 --> 135
# Node  285  already present
# 3
# Inserted node  103
# Adding  285 --> 103
# Inserted node  188
# Node  133  already present
# 25
# Adding  188 --> 133
# Inserted node  23
# Inserted node  116
# Adding  23 --> 116
# Inserted node  73
# Inserted node  299
# Adding  73 --> 299
# Inserted node  288
# Inserted node  315
# Adding  288 --> 315
# Inserted node  119
# Inserted node  323
# Adding  119 --> 323
# Inserted node  48
# Inserted node  57
# Adding  48 --> 57
# Inserted node  200
# Inserted node  98
# Adding  200 --> 98
# Inserted node  313
# Inserted node  63
# Adding  313 --> 63
# Node  199  already present
# 23
# Node  304  already present
# 7
# Adding  199 --> 304
# Node  53  already present
# 30
# Node  346  already present
# 5
# Adding  53 --> 346
# Inserted node  344
# Node  239  already present
# 27
# Adding  344 --> 239
# Node  56  already present
# 35
# Inserted node  67
# Adding  56 --> 67
# Inserted node  118
# Inserted node  325
# Adding  118 --> 325
# Node  188  already present
# 43
# Node  119  already present
# 50
# Adding  188 --> 119
# Node  26  already present
# 19
# Inserted node  277
# Adding  26 --> 277
# Inserted node  134
# Node  56  already present
# 35
# Adding  134 --> 56
# Inserted node  270
# Inserted node  76
# Adding  270 --> 76
# Node  135  already present
# 41
# Inserted node  36
# Adding  135 --> 36
# Inserted node  223
# Node  170  already present
# 32
# Adding  223 --> 170
# Node  170  already present
# 32
# Inserted node  274
# Adding  170 --> 274
# Inserted node  88
# Inserted node  21
# Adding  88 --> 21
# Inserted node  339
# Node  119  already present
# 50
# Adding  339 --> 119
# Inserted node  108
# Inserted node  197
# Adding  108 --> 197
# Inserted node  169
# Node  271  already present
# 6
# Adding  169 --> 271
# Node  62  already present
# 26
# Node  236  already present
# 0
# Adding  62 --> 236
# Inserted node  275
# Inserted node  273
# Adding  275 --> 273
# Node  88  already present
# 69
# Node  186  already present
# 1
# Adding  88 --> 186
# Node  213  already present
# 13
# Node  186  already present
# 1
# Adding  213 --> 186
# Inserted node  83
# Node  23  already present
# 44
# Adding  83 --> 23
# Inserted node  28
# Inserted node  312
# Adding  28 --> 312
# Inserted node  242
# Node  57  already present
# 53
# Adding  242 --> 57
# Inserted node  214
# Inserted node  20
# Adding  214 --> 20
# Inserted node  307
# Inserted node  71
# Adding  307 --> 71
# Node  20  already present
# 82
# Inserted node  333
# Adding  20 --> 333
# Inserted node  207
# Node  322  already present
# 29
# Adding  207 --> 322
# Node  339  already present
# 71
# Inserted node  168
# Adding  339 --> 168
# Inserted node  308
# Node  277  already present
# 62
# Adding  308 --> 277
# Node  186  already present
# 1
# Inserted node  341
# Adding  186 --> 341
# Node  322  already present
# 29
# Node  122  already present
# 2
# Adding  322 --> 122
# Inserted node  128
# Node  9  already present
# 9
# Adding  128 --> 9
# Inserted node  334
# Node  252  already present
# 14
# Adding  334 --> 252
# Inserted node  238
# Inserted node  265
# Adding  238 --> 265
# Node  67  already present
# 59
# Inserted node  141
# Adding  67 --> 141
# Inserted node  78
# Node  273  already present
# 76
# Adding  78 --> 273
# Inserted node  345
# Node  122  already present
# 2
# Adding  345 --> 122
# Node  315  already present
# 49
# Node  345  already present
# 96
# Adding  315 --> 345
# Inserted node  317
# Inserted node  158
# Adding  317 --> 158
# Node  98  already present
# 55
# Node  21  already present
# 70
# Adding  98 --> 21
# Node  339  already present
# 71
# Inserted node  38
# Adding  339 --> 38
# Node  24  already present
# 4
# Inserted node  302
# Adding  24 --> 302
# Inserted node  27
# Inserted node  54
# Adding  27 --> 54
# Node  197  already present
# 73
# Inserted node  139
# Adding  197 --> 139
# Inserted node  109
# Node  118  already present
# 60
# Adding  109 --> 118
# Node  252  already present
# 14
# Inserted node  291
# Adding  252 --> 291
# Node  170  already present
# 32
# Inserted node  142
# Adding  170 --> 142
# Node  82  already present
# 16
# Node  271  already present
# 6
# Adding  82 --> 271
# Inserted node  203
# Node  332  already present
# 15
# Adding  203 --> 332
# Inserted node  105
# Node  9  already present
# 9
# Adding  105 --> 9
# Inserted node  232
# Node  285  already present
# 3
# Adding  232 --> 285
# Inserted node  64
# Inserted node  217
# Adding  64 --> 217
# Node  239  already present
# 27
# Node  62  already present
# 26
# Adding  239 --> 62
# Inserted node  248
# Node  332  already present
# 15
# Adding  248 --> 332
# Node  73  already present
# 46
# Inserted node  126
# Adding  73 --> 126
# Inserted node  224
# Inserted node  261
# Adding  224 --> 261
# Inserted node  283
# Node  3  already present
# 31
# Adding  283 --> 3
# Inserted node  144
# Inserted node  226
# Adding  144 --> 226
# Node  119  already present
# 50
# Node  48  already present
# 52
# Adding  119 --> 48
# Inserted node  290
# Inserted node  25
# Adding  290 --> 25
# Node  172  already present
# 28
# Inserted node  342
# Adding  172 --> 342
# Node  119  already present
# 50
# Node  170  already present
# 32
# Adding  119 --> 170
# Node  285  already present
# 3
# Inserted node  146
# Adding  285 --> 146
# Inserted node  300
# Inserted node  94
# Adding  300 --> 94
# Node  236  already present
# 0
# Node  142  already present
# 106
# Adding  236 --> 142
# Node  346  already present
# 5
# Inserted node  1
# Adding  346 --> 1
# Inserted node  184
# Inserted node  159
# Adding  184 --> 159
# Node  159  already present
# 127
# Node  139  already present
# 103
# Adding  159 --> 139
# Node  53  already present
# 30
# Node  299  already present
# 47
# Adding  53 --> 299
# Inserted node  149
# Node  20  already present
# 82
# Adding  149 --> 20
# Node  83  already present
# 77
# Node  25  already present
# 120
# Adding  83 --> 25
# Node  332  already present
# 15
# Inserted node  13
# Adding  332 --> 13
# Node  25  already present
# 120
# Node  94  already present
# 124
# Adding  25 --> 94
# Node  342  already present
# 121
# Inserted node  59
# Adding  342 --> 59
# Node  238  already present
# 92
# Node  239  already present
# 27
# Adding  238 --> 239
# Inserted node  17
# Inserted node  326
# Adding  17 --> 326
# Inserted node  80
# Inserted node  187
# Adding  80 --> 187
# Node  325  already present
# 61
# Node  109  already present
# 104
# Adding  325 --> 109
# Node  224  already present
# 114
# Node  84  already present
# 24
# Adding  224 --> 84
# Inserted node  161
# Node  142  already present
# 106
# Adding  161 --> 142
# Node  122  already present
# 2
# Node  323  already present
# 51
# Adding  122 --> 323
# Node  161  already present
# 135
# Node  308  already present
# 88
# Adding  161 --> 308
# Node  142  already present
# 106
# Inserted node  66
# Adding  142 --> 66
# Node  308  already present
# 88
# Inserted node  31
# Adding  308 --> 31
# Inserted node  136
# Inserted node  7
# Adding  136 --> 7
# Node  271  already present
# 6
# Node  252  already present
# 14
# Adding  271 --> 252
# Inserted node  255
# Inserted node  49
# Adding  255 --> 49
# Node  48  already present
# 52
# Inserted node  320
# Adding  48 --> 320
# Node  3  already present
# 31
# Inserted node  85
# Adding  3 --> 85
# Inserted node  246
# Node  7  already present
# 139
# Adding  246 --> 7
# Node  109  already present
# 104
# Node  56  already present
# 35
# Adding  109 --> 56
# Node  109  already present
# 104
# Node  119  already present
# 50
# Adding  109 --> 119
# Node  239  already present
# 27
# Node  238  already present
# 92
# Adding  239 --> 238
# Node  272  already present
# 21
# Node  186  already present
# 1
# Adding  272 --> 186
# Node  200  already present
# 54
# Inserted node  123
# Adding  200 --> 123
# Node  285  already present
# 3
# Node  246  already present
# 144
# Adding  285 --> 246
# Node  271  already present
# 6
# Node  188  already present
# 43
# Adding  271 --> 188
# Node  31  already present
# 137
# Node  277  already present
# 62
# Adding  31 --> 277
# Node  326  already present
# 132
# Node  17  already present
# 131
# Adding  326 --> 17
# Inserted node  284
# Node  108  already present
# 72
# Adding  284 --> 108
# Inserted node  140
# Inserted node  137
# Adding  140 --> 137
# Node  56  already present
# 35
# Node  26  already present
# 19
# Adding  56 --> 26
# Inserted node  343
# Inserted node  115
# Adding  343 --> 115
# Node  25  already present
# 120
# Node  323  already present
# 51
# Adding  25 --> 323
# Node  345  already present
# 96
# Node  159  already present
# 127
# Adding  345 --> 159
# Inserted node  297
# Node  26  already present
# 19
# Adding  297 --> 26
# Node  343  already present
# 149
# Node  149  already present
# 128
# Adding  343 --> 149
# Node  320  already present
# 142
# Node  48  already present
# 52
# Adding  320 --> 48
# Node  200  already present
# 54
# Node  109  already present
# 104
# Adding  200 --> 109
# Inserted node  185
# Node  271  already present
# 6
# Adding  185 --> 271
# Node  7  already present
# 139
# Node  136  already present
# 138
# Adding  7 --> 136
# Node  326  already present
# 132
# Node  149  already present
# 128
# Adding  326 --> 149
# Inserted node  104
# Node  56  already present
# 35
# Adding  104 --> 56
# Node  339  already present
# 71
# Node  136  already present
# 138
# Adding  339 --> 136
# Node  308  already present
# 88
# Node  142  already present
# 106
# Adding  308 --> 142
# Inserted node  324
# Node  329  already present
# 11
# Adding  324 --> 329
# Node  9  already present
# 9
# Node  252  already present
# 14
# Adding  9 --> 252
# Node  1  already present
# 125
# Node  315  already present
# 49
# Adding  1 --> 315
# Node  21  already present
# 70
# Node  274  already present
# 68
# Adding  21 --> 274
# Node  119  already present
# 50
# Inserted node  171
# Adding  119 --> 171
# Node  345  already present
# 96
# Node  67  already present
# 59
# Adding  345 --> 67
# Node  280  already present
# 20
# Node  1  already present
# 125
# Adding  280 --> 1
# Node  313  already present
# 56
# Node  265  already present
# 93
# Adding  313 --> 265
# Node  277  already present
# 62
# Node  271  already present
# 6
# Adding  277 --> 271
# Node  56  already present
# 35
# Node  88  already present
# 69
# Adding  56 --> 88
# Node  9  already present
# 9
# Node  203  already present
# 107
# Adding  9 --> 203
# Node  85  already present
# 143
# Node  176  already present
# 8
# Adding  85 --> 176
# Inserted node  111
# Node  343  already present
# 149
# Adding  111 --> 343
# Inserted node  14
# Node  20  already present
# 82
# Adding  14 --> 20
# Inserted node  310
# Inserted node  32
# Adding  310 --> 32
# Node  304  already present
# 7
# Inserted node  30
# Adding  304 --> 30
# Node  199  already present
# 23
# Inserted node  222
# Adding  199 --> 222
# Inserted node  92
# Node  346  already present
# 5
# Adding  92 --> 346
# Inserted node  72
# Inserted node  40
# Adding  72 --> 40
# Node  284  already present
# 146
# Node  184  already present
# 126
# Adding  284 --> 184
# Inserted node  125
# Node  136  already present
# 138
# Adding  125 --> 136
# Node  134  already present
# 63
# Node  118  already present
# 60
# Adding  134 --> 118
# Node  9  already present
# 9
# Node  322  already present
# 29
# Adding  9 --> 322
# Node  302  already present
# 100
# Inserted node  266
# Adding  302 --> 266
# Node  332  already present
# 15
# Node  104  already present
# 153
# Adding  332 --> 104
# Node  40  already present
# 164
# Node  199  already present
# 23
# Adding  40 --> 199
# Inserted node  212
# Node  67  already present
# 59
# Adding  212 --> 67
# Node  200  already present
# 54
# Node  277  already present
# 62
# Adding  200 --> 277
# Node  82  already present
# 16
# Node  169  already present
# 74
# Adding  82 --> 169
# Node  270  already present
# 64
# Node  203  already present
# 107
# Adding  270 --> 203
# Node  308  already present
# 88
# Node  172  already present
# 28
# Adding  308 --> 172
# Node  261  already present
# 115
# Node  63  already present
# 57
# Adding  261 --> 63
# Node  146  already present
# 122
# Node  313  already present
# 56
# Adding  146 --> 313
# Node  188  already present
# 43
# Node  285  already present
# 3
# Adding  188 --> 285
# Node  57  already present
# 53
# Node  92  already present
# 162
# Adding  57 --> 92
# Node  168  already present
# 87
# Node  304  already present
# 7
# Adding  168 --> 304
# Node  199  already present
# 23
# Node  265  already present
# 93
# Adding  199 --> 265
# Node  332  already present
# 15
# Node  98  already present
# 55
# Adding  332 --> 98
# Node  169  already present
# 74
# Node  136  already present
# 138
# Adding  169 --> 136
# Node  213  already present
# 13
# Node  57  already present
# 53
# Adding  213 --> 57
# Node  248  already present
# 112
# Node  277  already present
# 62
# Adding  248 --> 277
# Node  98  already present
# 55
# Node  271  already present
# 6
# Adding  98 --> 271
# Node  56  already present
# 35
# Node  141  already present
# 94
# Adding  56 --> 141
# Node  310  already present
# 158
# Node  17  already present
# 131
# Adding  310 --> 17
# Node  199  already present
# 23
# Node  118  already present
# 60
# Adding  199 --> 118
# Node  239  already present
# 27
# Node  141  already present
# 94
# Adding  239 --> 141
# Node  21  already present
# 70
# Node  212  already present
# 167
# Adding  21 --> 212
# Node  176  already present
# 8
# Node  128  already present
# 90
# Adding  176 --> 128
# Node  175  already present
# 33
# Inserted node  278
# Adding  175 --> 278
# Node  203  already present
# 107
# Node  25  already present
# 120
# Adding  203 --> 25
# Node  265  already present
# 93
# Node  40  already present
# 164
# Adding  265 --> 40
# Node  26  already present
# 19
# Node  252  already present
# 14
# Adding  26 --> 252
# Node  339  already present
# 71
# Inserted node  340
# Adding  339 --> 340
# Node  172  already present
# 28
# Node  232  already present
# 109
# Adding  172 --> 232
# Node  31  already present
# 137
# Inserted node  237
# Adding  31 --> 237
# Inserted node  311
# Node  265  already present
# 93
# Adding  311 --> 265
# Inserted node  309
# Node  135  already present
# 41
# Adding  309 --> 135
# Inserted node  330
# Node  80  already present
# 133
# Adding  330 --> 80
# Inserted node  230
# Inserted node  70
# Adding  230 --> 70
# Node  272  already present
# 21
# Node  159  already present
# 127
# Adding  272 --> 159
# Node  21  already present
# 70
# Node  134  already present
# 63
# Adding  21 --> 134
# Node  24  already present
# 4
# Node  53  already present
# 30
# Adding  24 --> 53
# Node  40  already present
# 164
# Node  332  already present
# 15
# Adding  40 --> 332
# Node  261  already present
# 115
# Inserted node  16
# Adding  261 --> 16
# Node  239  already present
# 27
# Node  223  already present
# 67
# Adding  239 --> 223
# Node  304  already present
# 7
# Inserted node  249
# Adding  304 --> 249
# Node  277  already present
# 62
# Inserted node  39
# Adding  277 --> 39
# Node  224  already present
# 114
# Node  141  already present
# 94
# Adding  224 --> 141
# Node  142  already present
# 106
# Node  345  already present
# 96
# Adding  142 --> 345
# Node  72  already present
# 163
# Node  141  already present
# 94
# Adding  72 --> 141
# Node  313  already present
# 56
# Node  21  already present
# 70
# Adding  313 --> 21
# Node  261  already present
# 115
# Node  271  already present
# 6
# Adding  261 --> 271
# Node  276  already present
# 18
# Node  25  already present
# 120
# Adding  276 --> 25
# Node  109  already present
# 104
# Node  200  already present
# 54
# Adding  109 --> 200
# Node  288  already present
# 48
# Node  25  already present
# 120
# Adding  288 --> 25
# Node  329  already present
# 11
# Node  291  already present
# 105
# Adding  329 --> 291
# Node  194  already present
# 37
# Node  242  already present
# 80
# Adding  194 --> 242
# Node  223  already present
# 67
# Node  203  already present
# 107
# Adding  223 --> 203
# Node  290  already present
# 119
# Node  170  already present
# 32
# Adding  290 --> 170
# Node  261  already present
# 115
# Node  325  already present
# 61
# Adding  261 --> 325
# Node  36  already present
# 66
# Inserted node  251
# Adding  36 --> 251
# Node  291  already present
# 105
# Inserted node  10
# Adding  291 --> 10
# Node  342  already present
# 121
# Node  67  already present
# 59
# Adding  342 --> 67
# Node  21  already present
# 70
# Inserted node  55
# Adding  21 --> 55
# Node  108  already present
# 72
# Node  284  already present
# 146
# Adding  108 --> 284
# Node  3  already present
# 31
# Inserted node  228
# Adding  3 --> 228
# Node  168  already present
# 87
# Node  31  already present
# 137
# Adding  168 --> 31
# Node  67  already present
# 59
# Inserted node  69
# Adding  67 --> 69
# Node  323  already present
# 51
# Node  142  already present
# 106
# Adding  323 --> 142
# Node  261  already present
# 115
# Inserted node  113
# Adding  261 --> 113
# Node  55  already present
# 181
# Node  200  already present
# 54
# Adding  55 --> 200
# Node  13  already present
# 129
# Node  277  already present
# 62
# Adding  13 --> 277
# Node  322  already present
# 29
# Node  25  already present
# 120
# Adding  322 --> 25
# Inserted node  258
# Inserted node  257
# Adding  258 --> 257
# Node  285  already present
# 3
# Node  136  already present
# 138
# Adding  285 --> 136
# Node  80  already present
# 133
# Node  320  already present
# 142
# Adding  80 --> 320
# Node  265  already present
# 93
# Node  98  already present
# 55
# Adding  265 --> 98
# Node  252  already present
# 14
# Node  248  already present
# 112
# Adding  252 --> 248
# Node  62  already present
# 26
# Node  200  already present
# 54
# Adding  62 --> 200
# Node  313  already present
# 56
# Node  54  already present
# 102
# Adding  313 --> 54
# Inserted node  196
# Node  249  already present
# 177
# Adding  196 --> 249
# Node  323  already present
# 51
# Node  85  already present
# 143
# Adding  323 --> 85
# Node  82  already present
# 16
# Node  231  already present
# 38
# Adding  82 --> 231
# Node  141  already present
# 94
# Node  224  already present
# 114
# Adding  141 --> 224
# Node  342  already present
# 121
# Node  119  already present
# 50
# Adding  342 --> 119
# Node  304  already present
# 7
# Node  325  already present
# 61
# Adding  304 --> 325
# Node  136  already present
# 138
# Inserted node  156
# Adding  136 --> 156
# Node  325  already present
# 61
# Node  104  already present
# 153
# Adding  325 --> 104
# Node  211  already present
# 22
# Node  325  already present
# 61
# Adding  211 --> 325
# Node  304  already present
# 7
# Node  158  already present
# 98
# Adding  304 --> 158
# Node  254  already present
# 36
# Node  302  already present
# 100
# Adding  254 --> 302
# Node  92  already present
# 162
# Node  242  already present
# 80
# Adding  92 --> 242
# Node  30  already present
# 160
# Inserted node  303
# Adding  30 --> 303
# Node  274  already present
# 68
# Node  188  already present
# 43
# Adding  274 --> 188
# Node  28  already present
# 78
# Node  310  already present
# 158
# Adding  28 --> 310
# Node  271  already present
# 6
# Node  30  already present
# 160
# Adding  271 --> 30
# Inserted node  286
# Inserted node  81
# Adding  286 --> 81
# Node  144  already present
# 117
# Node  326  already present
# 132
# Adding  144 --> 326
# Node  265  already present
# 93
# Node  56  already present
# 35
# Adding  265 --> 56
# Node  249  already present
# 177
# Node  57  already present
# 53
# Adding  249 --> 57
# Node  341  already present
# 89
# Node  186  already present
# 1
# Adding  341 --> 186
# Inserted node  174
# Inserted node  293
# Adding  174 --> 293
# Inserted node  33
# Inserted node  42
# Adding  33 --> 42
# Node  312  already present
# 79
# Node  28  already present
# 78
# Adding  312 --> 28
# Node  199  already present
# 23
# Node  212  already present
# 167
# Adding  199 --> 212
# Node  9  already present
# 9
# Node  323  already present
# 51
# Adding  9 --> 323
# Node  168  already present
# 87
# Inserted node  347
# Adding  168 --> 347
# Node  67  already present
# 59
# Node  142  already present
# 106
# Adding  67 --> 142
# Node  1  already present
# 125
# Node  53  already present
# 30
# Adding  1 --> 53
# Node  115  already present
# 150
# Inserted node  2
# Adding  115 --> 2
# Node  333  already present
# 85
# Node  2  already present
# 197
# Adding  333 --> 2
# Node  332  already present
# 15
# Node  38  already present
# 99
# Adding  332 --> 38
# Node  291  already present
# 105
# Node  280  already present
# 20
# Adding  291 --> 280
# Node  119  already present
# 50
# Node  54  already present
# 102
# Adding  119 --> 54
# Node  271  already present
# 6
# Node  232  already present
# 109
# Adding  271 --> 232
# Node  135  already present
# 41
# Inserted node  281
# Adding  135 --> 281
# Node  258  already present
# 185
# Node  9  already present
# 9
# Adding  258 --> 9
# Node  285  already present
# 3
# Node  200  already present
# 54
# Adding  285 --> 200
# Node  330  already present
# 173
# Node  94  already present
# 124
# Adding  330 --> 94
# Inserted node  263
# Node  175  already present
# 33
# Adding  263 --> 175
# Node  212  already present
# 167
# Node  304  already present
# 7
# Adding  212 --> 304
# Node  238  already present
# 92
# Node  342  already present
# 121
# Adding  238 --> 342
# Node  284  already present
# 146
# Node  159  already present
# 127
# Adding  284 --> 159
# Node  111  already present
# 156
# Inserted node  279
# Adding  111 --> 279
# Node  141  already present
# 94
# Node  172  already present
# 28
# Adding  141 --> 172
# Node  66  already present
# 136
# Node  21  already present
# 70
# Adding  66 --> 21
# Node  313  already present
# 56
# Node  203  already present
# 107
# Adding  313 --> 203
# Node  84  already present
# 24
# Inserted node  51
# Adding  84 --> 51
# Node  139  already present
# 103
# Node  320  already present
# 142
# Adding  139 --> 320
# Node  25  already present
# 120
# Node  186  already present
# 1
# Adding  25 --> 186
# Node  252  already present
# 14
# Inserted node  338
# Adding  252 --> 338
# Node  200  already present
# 54
# Node  188  already present
# 43
# Adding  200 --> 188
# Node  59  already present
# 130
# Node  342  already present
# 121
# Adding  59 --> 342
# Inserted node  162
# Node  149  already present
# 128
# Adding  162 --> 149
# Node  304  already present
# 7
# Node  322  already present
# 29
# Adding  304 --> 322
# Node  185  already present
# 152
# Node  169  already present
# 74
# Adding  185 --> 169
# Node  252  already present
# 14
# Node  236  already present
# 0
# Adding  252 --> 236
# Node  25  already present
# 120
# Node  290  already present
# 119
# Adding  25 --> 290
# Node  56  already present
# 35
# Node  185  already present
# 152
# Adding  56 --> 185
# Node  158  already present
# 98
# Node  40  already present
# 164
# Adding  158 --> 40
# Node  238  already present
# 92
# Node  222  already present
# 161
# Adding  238 --> 222
# Node  56  already present
# 35
# Node  128  already present
# 90
# Adding  56 --> 128
# Node  199  already present
# 23
# Node  261  already present
# 115
# Adding  199 --> 261
# Node  271  already present
# 6
# Node  203  already present
# 107
# Adding  271 --> 203
# Node  63  already present
# 57
# Node  313  already present
# 56
# Adding  63 --> 313
# Node  62  already present
# 26
# Node  161  already present
# 135
# Adding  62 --> 161
# Node  302  already present
# 100
# Node  57  already present
# 53
# Adding  302 --> 57
# Inserted node  19
# Node  175  already present
# 33
# Adding  19 --> 175
# Node  98  already present
# 55
# Node  172  already present
# 28
# Adding  98 --> 172
# Node  28  already present
# 78
# Node  144  already present
# 117
# Adding  28 --> 144
# Node  249  already present
# 177
# Node  213  already present
# 13
# Adding  249 --> 213
# Node  239  already present
# 27
# Node  252  already present
# 14
# Adding  239 --> 252
# Node  332  already present
# 15
# Node  25  already present
# 120
# Adding  332 --> 25
# Node  265  already present
# 93
# Node  203  already present
# 107
# Adding  265 --> 203
# Node  303  already present
# 189
# Node  104  already present
# 153
# Adding  303 --> 104
# Node  339  already present
# 71
# Node  161  already present
# 135
# Adding  339 --> 161
# Node  119  already present
# 50
# Node  39  already present
# 178
# Adding  119 --> 39
# Node  239  already present
# 27
# Node  211  already present
# 22
# Adding  239 --> 211
# Node  313  already present
# 56
# Node  172  already present
# 28
# Adding  313 --> 172
# Node  200  already present
# 54
# Node  122  already present
# 2
# Adding  200 --> 122
# Node  104  already present
# 153
# Node  303  already present
# 189
# Adding  104 --> 303
# Inserted node  75
# Node  9  already present
# 9
# Adding  75 --> 9
# Node  137  already present
# 148
# Node  312  already present
# 79
# Adding  137 --> 312
# Node  272  already present
# 21
# Node  203  already present
# 107
# Adding  272 --> 203
# Inserted node  218
# Node  78  already present
# 95
# Adding  218 --> 78
# Node  261  already present
# 115
# Inserted node  268
# Adding  261 --> 268
# Inserted node  314
# Node  65  already present
# 17
# Adding  314 --> 65
# Node  57  already present
# 53
# Node  213  already present
# 13
# Adding  57 --> 213
# Node  21  already present
# 70
# Node  56  already present
# 35
# Adding  21 --> 56
# Node  7  already present
# 139
# Node  213  already present
# 13
# Adding  7 --> 213
# Node  139  already present
# 103
# Node  281  already present
# 198
# Adding  139 --> 281
# Inserted node  5
# Node  122  already present
# 2
# Adding  5 --> 122
# Node  55  already present
# 181
# Node  21  already present
# 70
# Adding  55 --> 21
# Node  80  already present
# 133
# Node  24  already present
# 4
# Adding  80 --> 24
# Inserted node  178
# Node  38  already present
# 99
# Adding  178 --> 38
# Node  186  already present
# 1
# Node  109  already present
# 104
# Adding  186 --> 109
# Node  304  already present
# 7
# Node  21  already present
# 70
# Adding  304 --> 21
# Inserted node  192
# Node  49  already present
# 141
# Adding  192 --> 49
# Node  203  already present
# 107
# Node  21  already present
# 70
# Adding  203 --> 21
# Node  285  already present
# 3
# Node  271  already present
# 6
# Adding  285 --> 271
# Node  122  already present
# 2
# Node  248  already present
# 112
# Adding  122 --> 248
# Node  104  already present
# 153
# Node  322  already present
# 29
# Adding  104 --> 322
# Node  312  already present
# 79
# Inserted node  243
# Adding  312 --> 243
# Node  302  already present
# 100
# Node  254  already present
# 36
# Adding  302 --> 254
# Node  236  already present
# 0
# Node  169  already present
# 74
# Adding  236 --> 169
# Node  304  already present
# 7
# Node  324  already present
# 154
# Adding  304 --> 324
# Node  266  already present
# 166
# Node  249  already present
# 177
# Adding  266 --> 249
# Node  3  already present
# 31
# Node  280  already present
# 20
# Adding  3 --> 280
# Node  243  already present
# 212
# Node  312  already present
# 79
# Adding  243 --> 312
# Node  211  already present
# 22
# Node  98  already present
# 55
# Adding  211 --> 98
# Inserted node  195
# Inserted node  181
# Adding  195 --> 181
# Inserted node  8
# Inserted node  245
# Adding  8 --> 245
# Node  297  already present
# 151
# Node  185  already present
# 152
# Adding  297 --> 185
# Node  113  already present
# 184
# Node  104  already present
# 153
# Adding  113 --> 104
# Node  10  already present
# 180
# Node  142  already present
# 106
# Adding  10 --> 142
# Inserted node  129
# Node  7  already present
# 139
# Adding  129 --> 7
# Node  56  already present
# 35
# Node  297  already present
# 151
# Adding  56 --> 297
# Node  248  already present
# 112
# Node  323  already present
# 51
# Adding  248 --> 323
# Node  273  already present
# 76
# Inserted node  328
# Adding  273 --> 328
# Node  115  already present
# 150
# Node  19  already present
# 204
# Adding  115 --> 19
# Node  36  already present
# 66
# Node  309  already present
# 172
# Adding  36 --> 309
# Node  129  already present
# 217
# Node  168  already present
# 87
# Adding  129 --> 168
# Node  242  already present
# 80
# Node  194  already present
# 37
# Adding  242 --> 194
# Node  343  already present
# 149
# Node  2  already present
# 197
# Adding  343 --> 2
# Node  21  already present
# 70
# Node  169  already present
# 74
# Adding  21 --> 169
# Node  226  already present
# 118
# Node  343  already present
# 149
# Adding  226 --> 343
# Node  40  already present
# 164
# Node  200  already present
# 54
# Adding  40 --> 200
# Node  172  already present
# 28
# Inserted node  331
# Adding  172 --> 331
# Node  326  already present
# 132
# Node  343  already present
# 149
# Adding  326 --> 343
# Node  134  already present
# 63
# Node  26  already present
# 19
# Adding  134 --> 26
# Node  332  already present
# 15
# Node  329  already present
# 11
# Adding  332 --> 329
# Node  3  already present
# 31
# Node  200  already present
# 54
# Adding  3 --> 200
# Node  331  already present
# 219
# Node  109  already present
# 104
# Adding  331 --> 109
# Inserted node  150
# Node  128  already present
# 90
# Adding  150 --> 128
# Inserted node  101
# Node  299  already present
# 47
# Adding  101 --> 299
# Node  203  already present
# 107
# Node  59  already present
# 130
# Adding  203 --> 59
# Node  231  already present
# 38
# Node  315  already present
# 49
# Adding  231 --> 315
# Node  265  already present
# 93
# Node  199  already present
# 23
# Adding  265 --> 199
# Inserted node  99
# Inserted node  296
# Adding  99 --> 296
# Node  322  already present
# 29
# Node  290  already present
# 119
# Adding  322 --> 290
# Node  296  already present
# 223
# Inserted node  102
# Adding  296 --> 102
# Node  118  already present
# 60
# Node  261  already present
# 115
# Adding  118 --> 261
# Node  238  already present
# 92
# Node  56  already present
# 35
# Adding  238 --> 56
# Node  117  already present
# 39
# Node  231  already present
# 38
# Adding  117 --> 231
# Node  312  already present
# 79
# Node  149  already present
# 128
# Adding  312 --> 149
# Node  304  already present
# 7
# Node  308  already present
# 88
# Adding  304 --> 308
# Node  105  already present
# 108
# Node  277  already present
# 62
# Adding  105 --> 277
# Node  204  already present
# 12
# Node  196  already present
# 187
# Adding  204 --> 196
# Node  315  already present
# 49
# Node  303  already present
# 189
# Adding  315 --> 303
# Node  284  already present
# 146
# Node  21  already present
# 70
# Adding  284 --> 21
# Node  239  already present
# 27
# Node  21  already present
# 70
# Adding  239 --> 21
# Node  312  already present
# 79
# Node  326  already present
# 132
# Adding  312 --> 326
# Node  277  already present
# 62
# Node  161  already present
# 135
# Adding  277 --> 161
# Node  340  already present
# 169
# Node  213  already present
# 13
# Adding  340 --> 213
# Node  98  already present
# 55
# Node  223  already present
# 67
# Adding  98 --> 223
# Node  172  already present
# 28
# Node  277  already present
# 62
# Adding  172 --> 277
# Node  128  already present
# 90
# Node  104  already present
# 153
# Adding  128 --> 104
# Node  313  already present
# 56
# Node  222  already present
# 161
# Adding  313 --> 222
# Node  98  already present
# 55
# Node  331  already present
# 219
# Adding  98 --> 331
# Node  299  already present
# 47
# Node  194  already present
# 37
# Adding  299 --> 194
# Node  122  already present
# 2
# Node  141  already present
# 94
# Adding  122 --> 141
# Node  324  already present
# 154
# Node  217  already present
# 111
# Adding  324 --> 217
# Node  291  already present
# 105
# Node  25  already present
# 120
# Adding  291 --> 25
# Node  13  already present
# 129
# Node  188  already present
# 43
# Adding  13 --> 188
# Node  104  already present
# 153
# Inserted node  318
# Adding  104 --> 318
# Node  261  already present
# 115
# Node  65  already present
# 17
# Adding  261 --> 65
# Node  265  already present
# 93
# Node  128  already present
# 90
# Adding  265 --> 128
# Inserted node  163
# Inserted node  173
# Adding  163 --> 173
# Node  116  already present
# 45
# Node  14  already present
# 157
# Adding  116 --> 14
# Node  92  already present
# 162
# Node  1  already present
# 125
# Adding  92 --> 1
# Node  26  already present
# 19
# Node  3  already present
# 31
# Adding  26 --> 3
# Inserted node  165
# Inserted node  121
# Adding  165 --> 121
# Node  3  already present
# 31
# Node  25  already present
# 120
# Adding  3 --> 25
# Node  149  already present
# 128
# Node  226  already present
# 118
# Adding  149 --> 226
# Node  328  already present
# 218
# Inserted node  306
# Adding  328 --> 306
# Node  172  already present
# 28
# Node  141  already present
# 94
# Adding  172 --> 141
# Node  303  already present
# 189
# Node  315  already present
# 49
# Adding  303 --> 315
# Node  56  already present
# 35
# Node  239  already present
# 27
# Adding  56 --> 239
# Node  122  already present
# 2
# Node  274  already present
# 68
# Adding  122 --> 274
# Node  46  already present
# 34
# Inserted node  177
# Adding  46 --> 177
# Node  249  already present
# 177
# Inserted node  180
# Adding  249 --> 180
# Node  73  already present
# 46
# Node  1  already present
# 125
# Adding  73 --> 1
# Node  272  already present
# 21
# Node  346  already present
# 5
# Adding  272 --> 346
# Node  53  already present
# 30
# Node  48  already present
# 52
# Adding  53 --> 48
# Node  199  already present
# 23
# Node  119  already present
# 50
# Adding  199 --> 119
# Node  248  already present
# 112
# Node  38  already present
# 99
# Adding  248 --> 38
# Node  24  already present
# 4
# Node  187  already present
# 134
# Adding  24 --> 187
# Node  196  already present
# 187
# Node  67  already present
# 59
# Adding  196 --> 67
# Node  304  already present
# 7
# Node  172  already present
# 28
# Adding  304 --> 172
# Inserted node  87
# Node  136  already present
# 138
# Adding  87 --> 136
# Node  323  already present
# 51
# Node  141  already present
# 94
# Adding  323 --> 141
# Node  323  already present
# 51
# Node  62  already present
# 26
# Adding  323 --> 62
# Inserted node  189
# Node  217  already present
# 111
# Adding  189 --> 217
# Node  280  already present
# 20
# Node  236  already present
# 0
# Adding  280 --> 236
# Node  115  already present
# 150
# Node  137  already present
# 148
# Adding  115 --> 137
# Node  25  already present
# 120
# Node  276  already present
# 18
# Adding  25 --> 276
# Node  186  already present
# 1
# Node  55  already present
# 181
# Adding  186 --> 55
# Node  30  already present
# 160
# Node  56  already present
# 35
# Adding  30 --> 56
# Inserted node  60
# Node  285  already present
# 3
# Adding  60 --> 285
# Node  197  already present
# 73
# Node  127  already present
# 40
# Adding  197 --> 127
# Node  334  already present
# 91
# Node  26  already present
# 19
# Adding  334 --> 26
# Node  304  already present
# 7
# Node  170  already present
# 32
# Adding  304 --> 170
# Inserted node  259
# Node  8  already present
# 215
# Adding  259 --> 8
# Node  346  already present
# 5
# Node  184  already present
# 126
# Adding  346 --> 184
# Node  186  already present
# 1
# Node  199  already present
# 23
# Adding  186 --> 199
# Node  200  already present
# 54
# Node  39  already present
# 178
# Adding  200 --> 39
# Node  185  already present
# 152
# Node  344  already present
# 58
# Adding  185 --> 344
# Node  184  already present
# 126
# Node  329  already present
# 11
# Adding  184 --> 329
# Node  149  already present
# 128
# Node  162  already present
# 203
# Adding  149 --> 162
# Node  285  already present
# 3
# Node  213  already present
# 13
# Adding  285 --> 213
# Node  185  already present
# 152
# Node  290  already present
# 119
# Adding  185 --> 290
# Node  13  already present
# 129
# Node  261  already present
# 115
# Adding  13 --> 261
# Node  204  already present
# 12
# Node  5  already present
# 209
# Adding  204 --> 5
# Node  109  already present
# 104
# Node  26  already present
# 19
# Adding  109 --> 26
# Node  169  already present
# 74
# Node  40  already present
# 164
# Adding  169 --> 40
# Node  194  already present
# 37
# Node  196  already present
# 187
# Adding  194 --> 196
# Node  85  already present
# 143
# Node  156  already present
# 188
# Adding  85 --> 156
# Node  67  already present
# 59
# Node  55  already present
# 181
# Adding  67 --> 55
# Node  98  already present
# 55
# Node  285  already present
# 3
# Adding  98 --> 285
# Node  123  already present
# 145
# Node  342  already present
# 121
# Adding  123 --> 342
# Node  118  already present
# 60
# Node  283  already present
# 116
# Adding  118 --> 283
# Inserted node  45
# Node  67  already present
# 59
# Adding  45 --> 67
# Node  80  already present
# 133
# Node  48  already present
# 52
# Adding  80 --> 48
# Node  162  already present
# 203
# Node  343  already present
# 149
# Adding  162 --> 343
# Node  272  already present
# 21
# Node  21  already present
# 70
# Adding  272 --> 21
# Node  271  already present
# 6
# Node  133  already present
# 25
# Adding  271 --> 133
# Node  67  already present
# 59
# Node  297  already present
# 151
# Adding  67 --> 297
# Node  13  already present
# 129
# Node  118  already present
# 60
# Adding  13 --> 118
# Node  115  already present
# 150
# Node  28  already present
# 78
# Adding  115 --> 28
# Node  230  already present
# 174
# Node  23  already present
# 44
# Adding  230 --> 23
# Inserted node  58
# Inserted node  269
# Adding  58 --> 269
# Node  46  already present
# 34
# Node  175  already present
# 33
# Adding  46 --> 175
# Node  25  already present
# 120
# Node  169  already present
# 74
# Adding  25 --> 169
# Node  80  already present
# 133
# Node  57  already present
# 53
# Adding  80 --> 57
# Node  135  already present
# 41
# Node  197  already present
# 73
# Adding  135 --> 197
# Node  203  already present
# 107
# Node  161  already present
# 135
# Adding  203 --> 161
# Node  113  already present
# 184
# Node  261  already present
# 115
# Adding  113 --> 261
# Node  116  already present
# 45
# Node  23  already present
# 44
# Adding  116 --> 23
# Node  275  already present
# 75
# Node  218  already present
# 206
# Adding  275 --> 218
# Node  285  already present
# 3
# Node  170  already present
# 32
# Adding  285 --> 170
# Node  314  already present
# 208
# Node  199  already present
# 23
# Adding  314 --> 199
# Node  279  already present
# 200
# Node  111  already present
# 156
# Adding  279 --> 111
# Node  126  already present
# 113
# Node  48  already present
# 52
# Adding  126 --> 48
# Node  36  already present
# 66
# Node  320  already present
# 142
# Adding  36 --> 320
# Node  137  already present
# 148
# Inserted node  167
# Adding  137 --> 167
# Node  140  already present
# 147
# Node  326  already present
# 132
# Adding  140 --> 326
# Node  130  already present
# 10
# Node  48  already present
# 52
# Adding  130 --> 48
# Node  302  already present
# 100
# Node  94  already present
# 124
# Adding  302 --> 94
# Node  315  already present
# 49
# Node  80  already present
# 133
# Adding  315 --> 80
# Node  101  already present
# 221
# Node  80  already present
# 133
# Adding  101 --> 80
# Node  23  already present
# 44
# Inserted node  227
# Adding  23 --> 227
# Node  92  already present
# 162
# Node  194  already present
# 37
# Adding  92 --> 194
# Node  2  already present
# 197
# Node  20  already present
# 82
# Adding  2 --> 20
# Node  72  already present
# 163
# Node  252  already present
# 14
# Adding  72 --> 252
# Node  323  already present
# 51
# Inserted node  96
# Adding  323 --> 96
# Inserted node  91
# Node  8  already present
# 215
# Adding  91 --> 8
# Inserted node  143
# Node  177  already present
# 231
# Adding  143 --> 177
# Node  200  already present
# 54
# Node  30  already present
# 160
# Adding  200 --> 30
# Node  257  already present
# 186
# Node  26  already present
# 19
# Adding  257 --> 26
# Node  331  already present
# 219
# Node  324  already present
# 154
# Adding  331 --> 324
# Node  142  already present
# 106
# Node  322  already present
# 29
# Adding  142 --> 322
# Node  188  already present
# 43
# Node  104  already present
# 153
# Adding  188 --> 104
# Node  239  already present
# 27
# Node  276  already present
# 18
# Adding  239 --> 276
# Node  23  already present
# 44
# Inserted node  61
# Adding  23 --> 61
# Node  325  already present
# 61
# Node  21  already present
# 70
# Adding  325 --> 21
# Node  204  already present
# 12
# Node  94  already present
# 124
# Adding  204 --> 94
# Node  346  already present
# 5
# Node  194  already present
# 37
# Adding  346 --> 194
# Node  223  already present
# 67
# Node  186  already present
# 1
# Adding  223 --> 186
# Node  56  already present
# 35
# Node  252  already present
# 14
# Adding  56 --> 252
# Node  113  already present
# 184
# Node  142  already present
# 106
# Adding  113 --> 142
# Node  26  already present
# 19
# Node  21  already present
# 70
# Adding  26 --> 21
# Node  285  already present
# 3
# Node  323  already present
# 51
# Adding  285 --> 323
# Node  290  already present
# 119
# Node  176  already present
# 8
# Adding  290 --> 176
# Inserted node  93
# Node  167  already present
# 240
# Adding  93 --> 167
# Node  276  already present
# 18
# Node  122  already present
# 2
# Adding  276 --> 122
# Node  96  already present
# 242
# Node  133  already present
# 25
# Adding  96 --> 133
# Inserted node  41
# Node  243  already present
# 212
# Adding  41 --> 243
# Node  188  already present
# 43
# Node  304  already present
# 7
# Adding  188 --> 304
# Node  203  already present
# 107
# Node  313  already present
# 56
# Adding  203 --> 313
# Node  200  already present
# 54
# Node  170  already present
# 32
# Adding  200 --> 170
# Node  232  already present
# 109
# Node  200  already present
# 54
# Adding  232 --> 200
# Inserted node  235
# Node  5  already present
# 209
# Adding  235 --> 5
# Inserted node  6
# Inserted node  89
# Adding  6 --> 89
# Node  171  already present
# 155
# Inserted node  107
# Adding  171 --> 107
# Node  257  already present
# 186
# Node  169  already present
# 74
# Adding  257 --> 169
# Node  224  already present
# 114
# Node  232  already present
# 109
# Adding  224 --> 232
# Node  271  already present
# 6
# Inserted node  79
# Adding  271 --> 79
# Node  187  already present
# 134
# Node  24  already present
# 4
# Adding  187 --> 24
# Node  141  already present
# 94
# Node  67  already present
# 59
# Adding  141 --> 67
# Node  113  already present
# 184
# Node  66  already present
# 136
# Adding  113 --> 66
# Node  56  already present
# 35
# Node  103  already present
# 42
# Adding  56 --> 103
# Node  59  already present
# 130
# Node  271  already present
# 6
# Adding  59 --> 271
# Node  40  already present
# 164
# Node  213  already present
# 13
# Adding  40 --> 213
# Node  158  already present
# 98
# Node  26  already present
# 19
# Adding  158 --> 26
# Node  211  already present
# 22
# Node  82  already present
# 16
# Adding  211 --> 82
# Node  285  already present
# 3
# Inserted node  208
# Adding  285 --> 208
# Node  119  already present
# 50
# Node  285  already present
# 3
# Adding  119 --> 285
# Node  26  already present
# 19
# Node  9  already present
# 9
# Adding  26 --> 9
# Node  40  already present
# 164
# Node  133  already present
# 25
# Adding  40 --> 133
# Node  143  already present
# 244
# Node  175  already present
# 33
# Adding  143 --> 175
# Node  56  already present
# 35
# Inserted node  132
# Adding  56 --> 132
# Node  45  already present
# 237
# Inserted node  221
# Adding  45 --> 221
# Node  212  already present
# 167
# Node  344  already present
# 58
# Adding  212 --> 344
# Node  285  already present
# 3
# Node  315  already present
# 49
# Adding  285 --> 315
# Inserted node  301
# Node  324  already present
# 154
# Adding  301 --> 324
# Node  21  already present
# 70
# Node  170  already present
# 32
# Adding  21 --> 170
# Node  326  already present
# 132
# Node  214  already present
# 81
# Adding  326 --> 214
# Node  281  already present
# 198
# Node  159  already present
# 127
# Adding  281 --> 159
# Node  281  already present
# 198
# Node  251  already present
# 179
# Adding  281 --> 251
# Node  109  already present
# 104
# Node  67  already present
# 59
# Adding  109 --> 67
# Node  25  already present
# 120
# Node  232  already present
# 109
# Adding  25 --> 232
# Node  59  already present
# 130
# Node  56  already present
# 35
# Adding  59 --> 56
# Node  92  already present
# 162
# Node  180  already present
# 232
# Adding  92 --> 180
# Node  122  already present
# 2
# Node  284  already present
# 146
# Adding  122 --> 284
# Node  322  already present
# 29
# Node  48  already present
# 52
# Adding  322 --> 48
# Node  277  already present
# 62
# Node  308  already present
# 88
# Adding  277 --> 308
# Node  290  already present
# 119
# Node  323  already present
# 51
# Adding  290 --> 323
# Node  167  already present
# 240
# Node  93  already present
# 246
# Adding  167 --> 93
# Inserted node  250
# Node  59  already present
# 130
# Adding  250 --> 59
# Inserted node  106
# Inserted node  29
# Adding  106 --> 29
# Node  274  already present
# 68
# Node  341  already present
# 89
# Adding  274 --> 341
# Node  249  already present
# 177
# Node  302  already present
# 100
# Adding  249 --> 302
# Node  118  already present
# 60
# Node  239  already present
# 27
# Adding  118 --> 239
# Node  111  already present
# 156
# Inserted node  337
# Adding  111 --> 337
# Node  252  already present
# 14
# Node  109  already present
# 104
# Adding  252 --> 109
# Node  56  already present
# 35
# Node  55  already present
# 181
# Adding  56 --> 55
# Node  80  already present
# 133
# Node  266  already present
# 166
# Adding  80 --> 266
# Node  252  already present
# 14
# Node  134  already present
# 63
# Adding  252 --> 134
# Node  104  already present
# 153
# Node  67  already present
# 59
# Adding  104 --> 67
# Node  94  already present
# 124
# Node  346  already present
# 5
# Adding  94 --> 346
# Node  141  already present
# 94
# Node  280  already present
# 20
# Adding  141 --> 280
# Node  325  already present
# 61
# Node  161  already present
# 135
# Adding  325 --> 161
# Node  322  already present
# 29
# Node  203  already present
# 107
# Adding  322 --> 203
# Node  96  already present
# 242
# Node  274  already present
# 68
# Adding  96 --> 274
# Node  158  already present
# 98
# Node  315  already present
# 49
# Adding  158 --> 315
# Node  199  already present
# 23
# Node  98  already present
# 55
# Adding  199 --> 98
# Node  134  already present
# 63
# Node  132  already present
# 254
# Adding  134 --> 132
# Node  280  already present
# 20
# Node  98  already present
# 55
# Adding  280 --> 98
# Node  254  already present
# 36
# Node  187  already present
# 134
# Adding  254 --> 187
# Node  329  already present
# 11
# Node  269  already present
# 239
# Adding  329 --> 269
# Node  297  already present
# 151
# Node  21  already present
# 70
# Adding  297 --> 21
# Inserted node  100
# Node  150  already present
# 220
# Adding  100 --> 150
# Inserted node  110
# Inserted node  264
# Adding  110 --> 264
# Node  266  already present
# 166
# Node  330  already present
# 173
# Adding  266 --> 330
# Node  171  already present
# 155
# Node  150  already present
# 220
# Adding  171 --> 150
# Node  322  already present
# 29
# Node  45  already present
# 237
# Adding  322 --> 45
# Node  72  already present
# 163
# Node  165  already present
# 228
# Adding  72 --> 165
# Node  344  already present
# 58
# Node  257  already present
# 186
# Adding  344 --> 257
# Node  184  already present
# 126
# Node  21  already present
# 70
# Adding  184 --> 21
# Node  119  already present
# 50
# Node  332  already present
# 15
# Adding  119 --> 332
# Node  257  already present
# 186
# Node  236  already present
# 0
# Adding  257 --> 236
# Node  277  already present
# 62
# Node  324  already present
# 154
# Adding  277 --> 324
# Node  332  already present
# 15
# Node  248  already present
# 112
# Adding  332 --> 248
# Node  329  already present
# 11
# Node  119  already present
# 50
# Adding  329 --> 119
# Inserted node  225
# Inserted node  86
# Adding  225 --> 86
# Node  232  already present
# 109
# Node  56  already present
# 35
# Adding  232 --> 56
# Node  291  already present
# 105
# Node  224  already present
# 114
# Adding  291 --> 224
# Node  53  already present
# 30
# Node  196  already present
# 187
# Adding  53 --> 196
# Node  315  already present
# 49
# Node  213  already present
# 13
# Adding  315 --> 213
# Node  322  already present
# 29
# Node  136  already present
# 138
# Adding  322 --> 136
# Node  181  already present
# 214
# Inserted node  152
# Adding  181 --> 152
# Node  141  already present
# 94
# Node  257  already present
# 186
# Adding  141 --> 257
# Node  180  already present
# 232
# Node  80  already present
# 133
# Adding  180 --> 80
# Node  26  already present
# 19
# Node  199  already present
# 23
# Adding  26 --> 199
# Node  45  already present
# 237
# Node  104  already present
# 153
# Adding  45 --> 104
# Node  332  already present
# 15
# Node  67  already present
# 59
# Adding  332 --> 67
# Node  303  already present
# 189
# Node  45  already present
# 237
# Adding  303 --> 45
# Node  250  already present
# 257
# Node  252  already present
# 14
# Adding  250 --> 252
# Node  3  already present
# 31
# Node  26  already present
# 19
# Adding  3 --> 26
# Node  98  already present
# 55
# Inserted node  148
# Adding  98 --> 148
# Node  185  already present
# 152
# Node  55  already present
# 181
# Adding  185 --> 55
# Node  172  already present
# 28
# Node  239  already present
# 27
# Adding  172 --> 239
# Inserted node  295
# Node  239  already present
# 27
# Adding  295 --> 239
# Node  325  already present
# 61
# Node  98  already present
# 55
# Adding  325 --> 98
# Node  252  already present
# 14
# Node  113  already present
# 184
# Adding  252 --> 113
# Node  323  already present
# 51
# Node  119  already present
# 50
# Adding  323 --> 119
# Node  188  already present
# 43
# Node  315  already present
# 49
# Adding  188 --> 315
# Node  55  already present
# 181
# Node  203  already present
# 107
# Adding  55 --> 203
# Node  137  already present
# 148
# Node  111  already present
# 156
# Adding  137 --> 111
# Node  224  already present
# 114
# Node  200  already present
# 54
# Adding  224 --> 200
# Node  194  already present
# 37
# Node  80  already present
# 133
# Adding  194 --> 80
# Node  295  already present
# 268
# Node  104  already present
# 153
# Adding  295 --> 104
# Node  17  already present
# 131
# Node  140  already present
# 147
# Adding  17 --> 140
# Node  266  already present
# 166
# Node  302  already present
# 100
# Adding  266 --> 302
# Node  232  already present
# 109
# Node  212  already present
# 167
# Adding  232 --> 212
# Node  249  already present
# 177
# Node  24  already present
# 4
# Adding  249 --> 24
# Node  200  already present
# 54
# Node  323  already present
# 51
# Adding  200 --> 323
# Node  323  already present
# 51
# Node  122  already present
# 2
# Adding  323 --> 122
# Node  203  already present
# 107
# Node  65  already present
# 17
# Adding  203 --> 65
# Node  259  already present
# 236
# Inserted node  201
# Adding  259 --> 201
# Node  161  already present
# 135
# Node  56  already present
# 35
# Adding  161 --> 56
# Node  119  already present
# 50
# Node  252  already present
# 14
# Adding  119 --> 252
# Node  238  already present
# 92
# Node  82  already present
# 16
# Adding  238 --> 82
# Node  197  already present
# 73
# Node  251  already present
# 179
# Adding  197 --> 251
# Node  105  already present
# 108
# Node  272  already present
# 21
# Adding  105 --> 272
# Node  291  already present
# 105
# ...
# 79
# Node  144  already present
# 117
# Adding  312 --> 144
# Node  164  already present
# 312
# Node  285  already present
# 3
# Adding  164 --> 285
# Node  39  already present
# 178
# Node  257  already present
# 186
# Adding  39 --> 257
# Node  132  already present
# 254
# Node  242  already present
# 80
# Adding  132 --> 242
# Node  239  already present
# 27
# Node  40  already present
# 164
# Adding  239 --> 40
# Node  230  already present
# 174
# Node  214  already present
# 81
# Adding  230 --> 214
# Node  80  already present
# 133
# Node  330  already present
# 173
# Adding  80 --> 330
# Node  149  already present
# 128
# Node  14  already present
# 157
# Adding  149 --> 14
# Node  126  already present
# 113
# Node  1  already present
# 125
# Adding  126 --> 1
# Node  21  already present
# 70
# Node  313  already present
# 56
# Adding  21 --> 313
# Node  113  already present
# 184
# Node  199  already present
# 23
# Adding  113 --> 199
# Node  272  already present
# 21
# Node  85  already present
# 143
# Adding  272 --> 85
# Node  257  already present
# 186
# Node  105  already present
# 108
# Adding  257 --> 105
# Node  66  already present
# 136
# Node  134  already present
# 63
# Adding  66 --> 134
# Node  271  already present
# 6
# Node  63  already present
# 57
# Adding  271 --> 63
# Node  274  already present
# 68
# Node  185  already present
# 152
# Adding  274 --> 185
# Node  172  already present
# 28
# Node  203  already present
# 107
# Adding  172 --> 203
# Node  313  already present
# 56
# Node  119  already present
# 50
# Adding  313 --> 119
# Node  119  already present
# 50
# Node  1  already present
# 125
# Adding  119 --> 1
# Node  203  already present
# 107
# Node  341  already present
# 89
# Adding  203 --> 341
# Node  119  already present
# 50
# Node  248  already present
# 112
# Adding  119 --> 248
# Node  8  already present
# 215
# Node  110  already present
# 262
# Adding  8 --> 110
# Node  324  already present
# 154
# Node  27  already present
# 101
# Adding  324 --> 27
# Node  98  already present
# 55
# Node  200  already present
# 54
# Adding  98 --> 200
# Node  323  already present
# 51
# Node  188  already present
# 43
# Adding  323 --> 188
# Node  232  already present
# 109
# Node  271  already present
# 6
# Adding  232 --> 271
# Node  4  already present
# 293
# Node  181  already present
# 214
# Adding  4 --> 181
# Node  21  already present
# 70
# Node  127  already present
# 40
# Adding  21 --> 127
# Node  304  already present
# 7
# Node  285  already present
# 3
# Adding  304 --> 285
# Node  158  already present
# 98
# Node  232  already present
# 109
# Adding  158 --> 232
# Node  211  already present
# 22
# Node  172  already present
# 28
# Adding  211 --> 172
# Node  204  already present
# 12
# Node  180  already present
# 232
# Adding  204 --> 180
# Node  45  already present
# 237
# Node  132  already present
# 254
# Adding  45 --> 132
# Node  98  already present
# 55
# Node  13  already present
# 129
# Adding  98 --> 13
# Node  142  already present
# 106
# Node  203  already present
# 107
# Adding  142 --> 203
# Node  304  already present
# 7
# Node  246  already present
# 144
# Adding  304 --> 246
# Node  269  already present
# 239
# Node  100  already present
# 261
# Adding  269 --> 100
# Node  25  already present
# 120
# Node  65  already present
# 17
# Adding  25 --> 65
# Node  55  already present
# 181
# Node  185  already present
# 152
# Adding  55 --> 185
# Node  213  already present
# 13
# Node  56  already present
# 35
# Adding  213 --> 56
# Node  332  already present
# 15
# Node  213  already present
# 13
# Adding  332 --> 213
# Node  285  already present
# 3
# Node  332  already present
# 15
# Adding  285 --> 332
# Node  142  already present
# 106
# Node  188  already present
# 43
# Adding  142 --> 188
# Node  324  already present
# 154
# Node  224  already present
# 114
# Adding  324 --> 224
# Node  202  already present
# 305
# Node  173  already present
# 227
# Adding  202 --> 173
# Node  48  already present
# 52
# Node  126  already present
# 113
# Adding  48 --> 126
# Node  187  already present
# 134
# Node  266  already present
# 166
# Adding  187 --> 266
# Node  9  already present
# 9
# Node  3  already present
# 31
# Adding  9 --> 3
# Node  113  already present
# 184
# Node  169  already present
# 74
# Adding  113 --> 169
# Node  246  already present
# 144
# Node  285  already present
# 3
# Adding  246 --> 285
# Node  303  already present
# 189
# Node  213  already present
# 13
# Adding  303 --> 213
# Node  142  already present
# 106
# Node  239  already present
# 27
# Adding  142 --> 239
# Node  251  already present
# 179
# Node  184  already present
# 126
# Adding  251 --> 184
# Node  53  already present
# 30
# Node  242  already present
# 80
# Adding  53 --> 242
# Node  172  already present
# 28
# Node  231  already present
# 38
# Adding  172 --> 231
# Node  188  already present
# 43
# Node  13  already present
# 129
# Adding  188 --> 13
# Node  203  already present
# 107
# Node  338  already present
# 202
# Adding  203 --> 338
# Node  111  already present
# 156
# Node  137  already present
# 148
# Adding  111 --> 137
# Node  214  already present
# 81
# Node  19  already present
# 204
# Adding  214 --> 19
# Node  41  already present
# 247
# Node  326  already present
# 132
# Adding  41 --> 326
# Node  113  already present
# 184
# Node  134  already present
# 63
# Adding  113 --> 134
# Node  98  already present
# 55
# Node  304  already present
# 7
# Adding  98 --> 304
# Node  10  already present
# 180
# Node  332  already present
# 15
# Adding  10 --> 332
# Node  184  already present
# 126
# Node  108  already present
# 72
# Adding  184 --> 108
# Node  343  already present
# 149
# Node  20  already present
# 82
# Adding  343 --> 20
# Node  170  already present
# 32
# Node  239  already present
# 27
# Adding  170 --> 239
# Node  147  already present
# 308
# Node  89  already present
# 250
# Adding  147 --> 89
# Node  141  already present
# 94
# Node  25  already present
# 120
# Adding  141 --> 25
# Node  236  already present
# 0
# Node  84  already present
# 24
# Adding  236 --> 84
# Node  34  already present
# 331
# Node  173  already present
# 227
# Adding  34 --> 173
# Node  9  already present
# 9
# Node  231  already present
# 38
# Adding  9 --> 231
# Node  67  already present
# 59
# Node  82  already present
# 16
# Adding  67 --> 82
# Node  148  already present
# 267
# Node  224  already present
# 114
# Adding  148 --> 224
# Node  320  already present
# 142
# Node  197  already present
# 73
# Adding  320 --> 197
# Node  26  already present
# 19
# Node  142  already present
# 106
# Adding  26 --> 142
# Node  241  already present
# 322
# Node  49  already present
# 141
# Adding  241 --> 49
# Node  170  already present
# 32
# Node  119  already present
# 50
# Adding  170 --> 119
# Node  87  already present
# 233
# Node  291  already present
# 105
# Adding  87 --> 291
# Node  199  already present
# 23
# Node  200  already present
# 54
# Adding  199 --> 200
# Node  320  already present
# 142
# Node  80  already present
# 133
# Adding  320 --> 80
# Node  143  already present
# 244
# Node  321  already present
# 273
# Adding  143 --> 321
# Node  217  already present
# 111
# Node  189  already present
# 234
# Adding  217 --> 189
# Node  303  already present
# 189
# Node  67  already present
# 59
# Adding  303 --> 67
# Node  9  already present
# 9
# Node  188  already present
# 43
# Adding  9 --> 188
# Node  122  already present
# 2
# Node  239  already present
# 27
# Adding  122 --> 239
# Node  302  already present
# 100
# Node  299  already present
# 47
# Adding  302 --> 299
# Node  118  already present
# 60
# Node  203  already present
# 107
# Adding  118 --> 203
# Node  62  already present
# 26
# Node  186  already present
# 1
# Adding  62 --> 186
# Node  170  already present
# 32
# Node  62  already present
# 26
# Adding  170 --> 62
# Node  119  already present
# 50
# Node  324  already present
# 154
# Adding  119 --> 324
# Node  137  already present
# 148
# Node  140  already present
# 147
# Adding  137 --> 140
# Node  281  already present
# 198
# Node  135  already present
# 41
# Adding  281 --> 135
# Node  239  already present
# 27
# Node  265  already present
# 93
# Adding  239 --> 265
# Node  200  already present
# 54
# Node  45  already present
# 237
# Adding  200 --> 45
# Node  66  already present
# 136
# Node  122  already present
# 2
# Adding  66 --> 122
# Node  323  already present
# 51
# Node  26  already present
# 19
# Adding  323 --> 26
# Node  203  already present
# 107
# Node  270  already present
# 64
# Adding  203 --> 270
# Node  222  already present
# 161
# Node  211  already present
# 22
# Adding  222 --> 211
# Node  98  already present
# 55
# Node  239  already present
# 27
# Adding  98 --> 239
# Node  239  already present
# 27
# Node  142  already present
# 106
# Adding  239 --> 142
# Node  98  already present
# 55
# Node  109  already present
# 104
# Adding  98 --> 109
# Node  188  already present
# 43
# Node  208  already present
# 253
# Adding  188 --> 208
# Node  67  already present
# 59
# Node  224  already present
# 114
# Adding  67 --> 224
# Node  119  already present
# 50
# Node  318  already present
# 225
# Adding  119 --> 318
# Node  119  already present
# 50
# Node  261  already present
# 115
# Adding  119 --> 261
# Node  59  already present
# 130
# Node  118  already present
# 60
# Adding  59 --> 118
# Node  67  already present
# 59
# Node  122  already present
# 2
# Adding  67 --> 122
# Node  302  already present
# 100
# Node  48  already present
# 52
# Adding  302 --> 48
# Node  206  already present
# 309
# Node  121  already present
# 229
# Adding  206 --> 121
# Node  263  already present
# 199
# Node  68  already present
# 274
# Adding  263 --> 68
# Node  26  already present
# 19
# Node  66  already present
# 136
# Adding  26 --> 66
# Node  236  already present
# 0
# Node  30  already present
# 160
# Adding  236 --> 30
# Node  324  already present
# 154
# Node  67  already present
# 59
# Adding  324 --> 67
# Node  170  already present
# 32
# Node  122  already present
# 2
# Adding  170 --> 122
# Node  88  already present
# 69
# Node  178  already present
# 210
# Adding  88 --> 178
# Node  56  already present
# 35
# Node  113  already present
# 184
# Adding  56 --> 113
# Node  137  already present
# 148
# Node  243  already present
# 212
# Adding  137 --> 243
# Node  25  already present
# 120
# Node  246  already present
# 144
# Adding  25 --> 246
# Node  41  already present
# 247
# Node  20  already present
# 82
# Adding  41 --> 20
# Node  199  already present
# 23
# Node  26  already present
# 19
# Adding  199 --> 26
# Node  254  already present
# 36
# Node  180  already present
# 232
# Adding  254 --> 180
# Node  40  already present
# 164
# Node  258  already present
# 185
# Adding  40 --> 258
# Node  119  already present
# 50
# Node  189  already present
# 234
# Adding  119 --> 189
# Node  304  already present
# 7
# Node  31  already present
# 137
# Adding  304 --> 31
# Node  186  already present
# 1
# Node  25  already present
# 120
# Adding  186 --> 25
# Node  140  already present
# 147
# Node  28  already present
# 78
# Adding  140 --> 28
# Node  98  already present
# 55
# Node  277  already present
# 62
# Adding  98 --> 277
# Node  26  already present
# 19
# Node  56  already present
# 35
# Adding  26 --> 56
# Node  176  already present
# 8
# Node  122  already present
# 2
# Adding  176 --> 122
# Node  317  already present
# 97
# Node  40  already present
# 164
# Adding  317 --> 40
# Node  134  already present
# 63
# Node  277  already present
# 62
# Adding  134 --> 277
# Node  298  already present
# 277
# Node  199  already present
# 23
# Adding  298 --> 199
# Node  281  already present
# 198
# Node  122  already present
# 2
# Adding  281 --> 122
# Node  265  already present
# 93
# Node  252  already present
# 14
# Adding  265 --> 252
# Node  51  already present
# 201
# Node  31  already present
# 137
# Adding  51 --> 31
# Node  285  already present
# 3
# Node  188  already present
# 43
# Adding  285 --> 188
# Node  265  already present
# 93
# Node  26  already present
# 19
# Adding  265 --> 26
# Node  280  already present
# 20
# Node  297  already present
# 151
# Adding  280 --> 297
# Node  63  already present
# 57
# Node  271  already present
# 6
# Adding  63 --> 271
# Node  271  already present
# 6
# Node  314  already present
# 208
# Adding  271 --> 314
# Node  322  already present
# 29
# Node  67  already present
# 59
# Adding  322 --> 67
# Node  297  already present
# 151
# Node  25  already present
# 120
# Adding  297 --> 25
# Node  26  already present
# 19
# Node  248  already present
# 112
# Adding  26 --> 248
# Node  304  already present
# 7
# Node  13  already present
# 129
# Adding  304 --> 13
# Node  181  already present
# 214
# Node  218  already present
# 206
# Adding  181 --> 218
# Node  68  already present
# 274
# Node  296  already present
# 223
# Adding  68 --> 296
# Node  45  already present
# 237
# Node  345  already present
# 96
# Adding  45 --> 345
# Node  89  already present
# 250
# Node  147  already present
# 308
# Adding  89 --> 147
# Node  66  already present
# 136
# Node  308  already present
# 88
# Adding  66 --> 308
# Node  315  already present
# 49
# Node  1  already present
# 125
# Adding  315 --> 1
# Node  185  already present
# 152
# Node  26  already present
# 19
# Adding  185 --> 26
# Node  181  already present
# 214
# Node  306  already present
# 230
# Adding  181 --> 306
# Node  271  already present
# 6
# Node  56  already present
# 35
# Adding  271 --> 56
# Node  105  already present
# 108
# Node  315  already present
# 49
# Adding  105 --> 315
# Node  270  already present
# 64
# Node  25  already present
# 120
# Adding  270 --> 25
# Node  261  already present
# 115
# Node  56  already present
# 35
# Adding  261 --> 56
# Node  158  already present
# 98
# Node  60  already present
# 235
# Adding  158 --> 60
# Node  231  already present
# 38
# Node  25  already present
# 120
# Adding  231 --> 25
# Node  176  already present
# 8
# Node  188  already present
# 43
# Adding  176 --> 188
# Node  246  already present
# 144
# Node  25  already present
# 120
# Adding  246 --> 25
# Node  122  already present
# 2
# Node  136  already present
# 138
# Adding  122 --> 136
# Node  248  already present
# 112
# Node  134  already present
# 63
# Adding  248 --> 134
# Node  331  already present
# 219
# Node  25  already present
# 120
# Adding  331 --> 25
# Node  25  already present
# 120
# Node  332  already present
# 15
# Adding  25 --> 332
# Node  97  already present
# 284
# Node  182  already present
# 320
# Adding  97 --> 182
# Node  201  already present
# 269
# Node  259  already present
# 236
# Adding  201 --> 259
# Node  60  already present
# 235
# Node  313  already present
# 56
# Adding  60 --> 313
# Node  156  already present
# 188
# Node  272  already present
# 21
# Adding  156 --> 272
# Node  268  already present
# 207
# Node  172  already present
# 28
# Adding  268 --> 172
# Node  122  already present
# 2
# Node  251  already present
# 179
# Adding  122 --> 251
# Node  172  already present
# 28
# Node  313  already present
# 56
# Adding  172 --> 313
# Node  342  already present
# 121
# Node  285  already present
# 3
# Adding  342 --> 285
# Node  299  already present
# 47
# Node  1  already present
# 125
# Adding  299 --> 1
# Node  92  already present
# 162
# Node  80  already present
# 133
# Adding  92 --> 80
# Node  343  already present
# 149
# Node  144  already present
# 117
# Adding  343 --> 144
# Node  339  already present
# 71
# Node  158  already present
# 98
# Adding  339 --> 158
# Node  56  already present
# 35
# Node  142  already present
# 106
# Adding  56 --> 142
# Node  109  already present
# 104
# Node  325  already present
# 61
# Adding  109 --> 325
# Node  252  already present
# 14
# Node  170  already present
# 32
# Adding  252 --> 170
# Node  177  already present
# 231
# Node  68  already present
# 274
# Adding  177 --> 68
# Node  265  already present
# 93
# Node  313  already present
# 56
# Adding  265 --> 313
# Node  219  already present
# 315
# Node  154  already present
# 318
# Adding  219 --> 154
# Node  169  already present
# 74
# Node  252  already present
# 14
# Adding  169 --> 252
# Node  24  already present
# 4
# Node  249  already present
# 177
# Adding  24 --> 249
# Node  199  already present
# 23
# Node  313  already present
# 56
# Adding  199 --> 313
# Node  322  already present
# 29
# Node  224  already present
# 114
# Adding  322 --> 224
# Node  128  already present
# 90
# Node  98  already present
# 55
# Adding  128 --> 98
# Node  200  already present
# 54
# Node  142  already present
# 106
# Adding  200 --> 142
# Node  30  already present
# 160
# Node  178  already present
# 210
# Adding  30 --> 178
# Node  13  already present
# 129
# Node  325  already present
# 61
# Adding  13 --> 325
# Node  170  already present
# 32
# Node  252  already present
# 14
# Adding  170 --> 252
# Node  322  already present
# 29
# Node  271  already present
# 6
# Adding  322 --> 271
# Node  88  already present
# 69
# Node  25  already present
# 120
# Adding  88 --> 25
# Node  127  already present
# 40
# Node  197  already present
# 73
# Adding  127 --> 197
# Node  26  already present
# 19
# Node  212  already present
# 167
# Adding  26 --> 212
# Node  62  already present
# 26
# Node  96  already present
# 242
# Adding  62 --> 96
# Node  171  already present
# 155
# Node  58  already present
# 238
# Adding  171 --> 58
# Node  326  already present
# 132
# Node  20  already present
# 82
# Adding  326 --> 20
# Node  85  already present
# 143
# Node  75  already present
# 205
# Adding  85 --> 75
# Node  98  already present
# 55
# Node  332  already present
# 15
# Adding  98 --> 332
# Node  291  already present
# 105
# Node  339  already present
# 71
# Adding  291 --> 339
# <class 'list'>
# <class 'list'>

# %%
#!pip install plotly==3.10.0
from chart_studio import plotly
#plotly.set_credentials_file(username='201901256', api_key='2lQX0OsYXgYR9YzPa3SH')
from plotly.graph_objs import Line
from plotly.graph_objs.scatter.marker import Line
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
from plotly.plotly import iplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22380\3155025599.py in <module>
#       7 import plotly.plotly as py
#       8 from plotly.graph_objs import *
# ----> 9 from plotly.plotly import iplot
#
# ImportError: cannot import name 'iplot' from 'plotly.plotly' (c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\plotly\__init__.py)

# %%
# In[26]:

from plotly.graph_objs import *


trace1=Scatter3d(x=Xe,
               y=Ye,
               z=Ze,
               mode='lines',
               line=Line(color='rgb(125,125,125)', width=1),
               hoverinfo='none'
               )

trace2=Scatter3d(x=Xn,
               y=Yn,
               z=Zn,
               mode='markers',
               name='actors',
               marker=Marker(symbol='circle',
                             color=eigen,
                             size=6,colorbar=ColorBar(
                title='Colorbar'
            ),
                             colorscale='Viridis',
                             line=Line(color='rgb(158,18,130)', width=0.5)
                             ),
               text=labels,
               hoverinfo='text'
               )

axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = Layout(
         title="3D Visualization of the Facebook nodes",
         width=1000,
         height=1000,
         showlegend=False,
         scene=Scene(
         xaxis=XAxis(axis),
         yaxis=YAxis(axis),
         zaxis=ZAxis(axis),
        ),
     margin=Margin(
        t=100
    ),
    hovermode='closest',
    annotations=Annotations([
           Annotation(
           showarrow=False,
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=Font(
            size=14
            )
            )
        ]),    )

data=Data([trace1, trace2])
import plotly.graph_objs as go
fig=go.Figure(data=data, layout=layout)
#py.iplot(fig)
fig.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:372: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:174: DeprecationWarning:
#
# plotly.graph_objs.ColorBar is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.marker.ColorBar
#   - plotly.graph_objs.surface.ColorBar
#   - etc.
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:426: DeprecationWarning:
#
# plotly.graph_objs.Marker is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Marker
#   - plotly.graph_objs.histogram.selected.Marker
#   - etc.
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:531: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:582: DeprecationWarning:
#
# plotly.graph_objs.ZAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.scene.ZAxis
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:396: DeprecationWarning:
#
# plotly.graph_objs.Margin is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Margin
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:144: DeprecationWarning:
#
# plotly.graph_objs.Annotation is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:66: DeprecationWarning:
#
# plotly.graph_objs.Annotations is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
#
#
# c:\Users\admin\AppData\Local\Programs\Python\Python37\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.

# %% [markdown]
# ## 2nd Phase : Dataset preparation and ML prediction

# %%
g=Graph()
load_dataset('abd',g)
# Out:
# 0
# fileName= C:\Users\admin\Desktop\Baveet\Social_Datasets\facebook\edges\0.edges
# Inserted node  186
# Adding  236 --> 186
# Inserted node  122
# Inserted node  285
# Adding  122 --> 285
# Inserted node  24
# Inserted node  346
# Adding  24 --> 346
# Inserted node  271
# Inserted node  304
# Adding  271 --> 304
# Inserted node  176
# Inserted node  9
# Adding  176 --> 9
# Inserted node  130
# Inserted node  329
# Adding  130 --> 329
# Inserted node  204
# Inserted node  213
# Adding  204 --> 213
# Inserted node  252
# Inserted node  332
# Adding  252 --> 332
# Inserted node  82
# Inserted node  65
# Adding  82 --> 65
# Inserted node  276
# Inserted node  26
# Adding  276 --> 26
# Inserted node  280
# Inserted node  272
# Adding  280 --> 272
# Inserted node  211
# Inserted node  199
# Adding  211 --> 199
# Inserted node  84
# Node  236  already present
# 0
# Adding  84 --> 236
# Inserted node  133
# Inserted node  62
# Adding  133 --> 62
# Inserted node  239
# Inserted node  172
# Adding  239 --> 172
# Inserted node  322
# Inserted node  53
# Adding  322 --> 53
# Inserted node  3
# Inserted node  170
# Adding  3 --> 170
# Inserted node  175
# Inserted node  46
# Adding  175 --> 46
# Node  170  already present
# 32
# Node  176  already present
# 8
# Adding  170 --> 176
# Node  170  already present
# 32
# Inserted node  56
# Adding  170 --> 56
# Inserted node  254
# Inserted node  194
# Adding  254 --> 194
# Inserted node  231
# Inserted node  117
# Adding  231 --> 117
# Inserted node  127
# Inserted node  135
# Adding  127 --> 135
# Node  285  already present
# 3
# Inserted node  103
# Adding  285 --> 103
# Inserted node  188
# Node  133  already present
# 25
# Adding  188 --> 133
# Inserted node  23
# Inserted node  116
# Adding  23 --> 116
# Inserted node  73
# Inserted node  299
# Adding  73 --> 299
# Inserted node  288
# Inserted node  315
# Adding  288 --> 315
# Inserted node  119
# Inserted node  323
# Adding  119 --> 323
# Inserted node  48
# Inserted node  57
# Adding  48 --> 57
# Inserted node  200
# Inserted node  98
# Adding  200 --> 98
# Inserted node  313
# Inserted node  63
# Adding  313 --> 63
# Node  199  already present
# 23
# Node  304  already present
# 7
# Adding  199 --> 304
# Node  53  already present
# 30
# Node  346  already present
# 5
# Adding  53 --> 346
# Inserted node  344
# Node  239  already present
# 27
# Adding  344 --> 239
# Node  56  already present
# 35
# Inserted node  67
# Adding  56 --> 67
# Inserted node  118
# Inserted node  325
# Adding  118 --> 325
# Node  188  already present
# 43
# Node  119  already present
# 50
# Adding  188 --> 119
# Node  26  already present
# 19
# Inserted node  277
# Adding  26 --> 277
# Inserted node  134
# Node  56  already present
# 35
# Adding  134 --> 56
# Inserted node  270
# Inserted node  76
# Adding  270 --> 76
# Node  135  already present
# 41
# Inserted node  36
# Adding  135 --> 36
# Inserted node  223
# Node  170  already present
# 32
# Adding  223 --> 170
# Node  170  already present
# 32
# Inserted node  274
# Adding  170 --> 274
# Inserted node  88
# Inserted node  21
# Adding  88 --> 21
# Inserted node  339
# Node  119  already present
# 50
# Adding  339 --> 119
# Inserted node  108
# Inserted node  197
# Adding  108 --> 197
# Inserted node  169
# Node  271  already present
# 6
# Adding  169 --> 271
# Node  62  already present
# 26
# Node  236  already present
# 0
# Adding  62 --> 236
# Inserted node  275
# Inserted node  273
# Adding  275 --> 273
# Node  88  already present
# 69
# Node  186  already present
# 1
# Adding  88 --> 186
# Node  213  already present
# 13
# Node  186  already present
# 1
# Adding  213 --> 186
# Inserted node  83
# Node  23  already present
# 44
# Adding  83 --> 23
# Inserted node  28
# Inserted node  312
# Adding  28 --> 312
# Inserted node  242
# Node  57  already present
# 53
# Adding  242 --> 57
# Inserted node  214
# Inserted node  20
# Adding  214 --> 20
# Inserted node  307
# Inserted node  71
# Adding  307 --> 71
# Node  20  already present
# 82
# Inserted node  333
# Adding  20 --> 333
# Inserted node  207
# Node  322  already present
# 29
# Adding  207 --> 322
# Node  339  already present
# 71
# Inserted node  168
# Adding  339 --> 168
# Inserted node  308
# Node  277  already present
# 62
# Adding  308 --> 277
# Node  186  already present
# 1
# Inserted node  341
# Adding  186 --> 341
# Node  322  already present
# 29
# Node  122  already present
# 2
# Adding  322 --> 122
# Inserted node  128
# Node  9  already present
# 9
# Adding  128 --> 9
# Inserted node  334
# Node  252  already present
# 14
# Adding  334 --> 252
# Inserted node  238
# Inserted node  265
# Adding  238 --> 265
# Node  67  already present
# 59
# Inserted node  141
# Adding  67 --> 141
# Inserted node  78
# Node  273  already present
# 76
# Adding  78 --> 273
# Inserted node  345
# Node  122  already present
# 2
# Adding  345 --> 122
# Node  315  already present
# 49
# Node  345  already present
# 96
# Adding  315 --> 345
# Inserted node  317
# Inserted node  158
# Adding  317 --> 158
# Node  98  already present
# 55
# Node  21  already present
# 70
# Adding  98 --> 21
# Node  339  already present
# 71
# Inserted node  38
# Adding  339 --> 38
# Node  24  already present
# 4
# Inserted node  302
# Adding  24 --> 302
# Inserted node  27
# Inserted node  54
# Adding  27 --> 54
# Node  197  already present
# 73
# Inserted node  139
# Adding  197 --> 139
# Inserted node  109
# Node  118  already present
# 60
# Adding  109 --> 118
# Node  252  already present
# 14
# Inserted node  291
# Adding  252 --> 291
# Node  170  already present
# 32
# Inserted node  142
# Adding  170 --> 142
# Node  82  already present
# 16
# Node  271  already present
# 6
# Adding  82 --> 271
# Inserted node  203
# Node  332  already present
# 15
# Adding  203 --> 332
# Inserted node  105
# Node  9  already present
# 9
# Adding  105 --> 9
# Inserted node  232
# Node  285  already present
# 3
# Adding  232 --> 285
# Inserted node  64
# Inserted node  217
# Adding  64 --> 217
# Node  239  already present
# 27
# Node  62  already present
# 26
# Adding  239 --> 62
# Inserted node  248
# Node  332  already present
# 15
# Adding  248 --> 332
# Node  73  already present
# 46
# Inserted node  126
# Adding  73 --> 126
# Inserted node  224
# Inserted node  261
# Adding  224 --> 261
# Inserted node  283
# Node  3  already present
# 31
# Adding  283 --> 3
# Inserted node  144
# Inserted node  226
# Adding  144 --> 226
# Node  119  already present
# 50
# Node  48  already present
# 52
# Adding  119 --> 48
# Inserted node  290
# Inserted node  25
# Adding  290 --> 25
# Node  172  already present
# 28
# Inserted node  342
# Adding  172 --> 342
# Node  119  already present
# 50
# Node  170  already present
# 32
# Adding  119 --> 170
# Node  285  already present
# 3
# Inserted node  146
# Adding  285 --> 146
# Inserted node  300
# Inserted node  94
# Adding  300 --> 94
# Node  236  already present
# 0
# Node  142  already present
# 106
# Adding  236 --> 142
# Node  346  already present
# 5
# Inserted node  1
# Adding  346 --> 1
# Inserted node  184
# Inserted node  159
# Adding  184 --> 159
# Node  159  already present
# 127
# Node  139  already present
# 103
# Adding  159 --> 139
# Node  53  already present
# 30
# Node  299  already present
# 47
# Adding  53 --> 299
# Inserted node  149
# Node  20  already present
# 82
# Adding  149 --> 20
# Node  83  already present
# 77
# Node  25  already present
# 120
# Adding  83 --> 25
# Node  332  already present
# 15
# Inserted node  13
# Adding  332 --> 13
# Node  25  already present
# 120
# Node  94  already present
# 124
# Adding  25 --> 94
# Node  342  already present
# 121
# Inserted node  59
# Adding  342 --> 59
# Node  238  already present
# 92
# Node  239  already present
# 27
# Adding  238 --> 239
# Inserted node  17
# Inserted node  326
# Adding  17 --> 326
# Inserted node  80
# Inserted node  187
# Adding  80 --> 187
# Node  325  already present
# 61
# Node  109  already present
# 104
# Adding  325 --> 109
# Node  224  already present
# 114
# Node  84  already present
# 24
# Adding  224 --> 84
# Inserted node  161
# Node  142  already present
# 106
# Adding  161 --> 142
# Node  122  already present
# 2
# Node  323  already present
# 51
# Adding  122 --> 323
# Node  161  already present
# 135
# Node  308  already present
# 88
# Adding  161 --> 308
# Node  142  already present
# 106
# Inserted node  66
# Adding  142 --> 66
# Node  308  already present
# 88
# Inserted node  31
# Adding  308 --> 31
# Inserted node  136
# Inserted node  7
# Adding  136 --> 7
# Node  271  already present
# 6
# Node  252  already present
# 14
# Adding  271 --> 252
# Inserted node  255
# Inserted node  49
# Adding  255 --> 49
# Node  48  already present
# 52
# Inserted node  320
# Adding  48 --> 320
# Node  3  already present
# 31
# Inserted node  85
# Adding  3 --> 85
# Inserted node  246
# Node  7  already present
# 139
# Adding  246 --> 7
# Node  109  already present
# 104
# Node  56  already present
# 35
# Adding  109 --> 56
# Node  109  already present
# 104
# Node  119  already present
# 50
# Adding  109 --> 119
# Node  239  already present
# 27
# Node  238  already present
# 92
# Adding  239 --> 238
# Node  272  already present
# 21
# Node  186  already present
# 1
# Adding  272 --> 186
# Node  200  already present
# 54
# Inserted node  123
# Adding  200 --> 123
# Node  285  already present
# 3
# Node  246  already present
# 144
# Adding  285 --> 246
# Node  271  already present
# 6
# Node  188  already present
# 43
# Adding  271 --> 188
# Node  31  already present
# 137
# Node  277  already present
# 62
# Adding  31 --> 277
# Node  326  already present
# 132
# Node  17  already present
# 131
# Adding  326 --> 17
# Inserted node  284
# Node  108  already present
# 72
# Adding  284 --> 108
# Inserted node  140
# Inserted node  137
# Adding  140 --> 137
# Node  56  already present
# 35
# Node  26  already present
# 19
# Adding  56 --> 26
# Inserted node  343
# Inserted node  115
# Adding  343 --> 115
# Node  25  already present
# 120
# Node  323  already present
# 51
# Adding  25 --> 323
# Node  345  already present
# 96
# Node  159  already present
# 127
# Adding  345 --> 159
# Inserted node  297
# Node  26  already present
# 19
# Adding  297 --> 26
# Node  343  already present
# 149
# Node  149  already present
# 128
# Adding  343 --> 149
# Node  320  already present
# 142
# Node  48  already present
# 52
# Adding  320 --> 48
# Node  200  already present
# 54
# Node  109  already present
# 104
# Adding  200 --> 109
# Inserted node  185
# Node  271  already present
# 6
# Adding  185 --> 271
# Node  7  already present
# 139
# Node  136  already present
# 138
# Adding  7 --> 136
# Node  326  already present
# 132
# Node  149  already present
# 128
# Adding  326 --> 149
# Inserted node  104
# Node  56  already present
# 35
# Adding  104 --> 56
# Node  339  already present
# 71
# Node  136  already present
# 138
# Adding  339 --> 136
# Node  308  already present
# 88
# Node  142  already present
# 106
# Adding  308 --> 142
# Inserted node  324
# Node  329  already present
# 11
# Adding  324 --> 329
# Node  9  already present
# 9
# Node  252  already present
# 14
# Adding  9 --> 252
# Node  1  already present
# 125
# Node  315  already present
# 49
# Adding  1 --> 315
# Node  21  already present
# 70
# Node  274  already present
# 68
# Adding  21 --> 274
# Node  119  already present
# 50
# Inserted node  171
# Adding  119 --> 171
# Node  345  already present
# 96
# Node  67  already present
# 59
# Adding  345 --> 67
# Node  280  already present
# 20
# Node  1  already present
# 125
# Adding  280 --> 1
# Node  313  already present
# 56
# Node  265  already present
# 93
# Adding  313 --> 265
# Node  277  already present
# 62
# Node  271  already present
# 6
# Adding  277 --> 271
# Node  56  already present
# 35
# Node  88  already present
# 69
# Adding  56 --> 88
# Node  9  already present
# 9
# Node  203  already present
# 107
# Adding  9 --> 203
# Node  85  already present
# 143
# Node  176  already present
# 8
# Adding  85 --> 176
# Inserted node  111
# Node  343  already present
# 149
# Adding  111 --> 343
# Inserted node  14
# Node  20  already present
# 82
# Adding  14 --> 20
# Inserted node  310
# Inserted node  32
# Adding  310 --> 32
# Node  304  already present
# 7
# Inserted node  30
# Adding  304 --> 30
# Node  199  already present
# 23
# Inserted node  222
# Adding  199 --> 222
# Inserted node  92
# Node  346  already present
# 5
# Adding  92 --> 346
# Inserted node  72
# Inserted node  40
# Adding  72 --> 40
# Node  284  already present
# 146
# Node  184  already present
# 126
# Adding  284 --> 184
# Inserted node  125
# Node  136  already present
# 138
# Adding  125 --> 136
# Node  134  already present
# 63
# Node  118  already present
# 60
# Adding  134 --> 118
# Node  9  already present
# 9
# Node  322  already present
# 29
# Adding  9 --> 322
# Node  302  already present
# 100
# Inserted node  266
# Adding  302 --> 266
# Node  332  already present
# 15
# Node  104  already present
# 153
# Adding  332 --> 104
# Node  40  already present
# 164
# Node  199  already present
# 23
# Adding  40 --> 199
# Inserted node  212
# Node  67  already present
# 59
# Adding  212 --> 67
# Node  200  already present
# 54
# Node  277  already present
# 62
# Adding  200 --> 277
# Node  82  already present
# 16
# Node  169  already present
# 74
# Adding  82 --> 169
# Node  270  already present
# 64
# Node  203  already present
# 107
# Adding  270 --> 203
# Node  308  already present
# 88
# Node  172  already present
# 28
# Adding  308 --> 172
# Node  261  already present
# 115
# Node  63  already present
# 57
# Adding  261 --> 63
# Node  146  already present
# 122
# Node  313  already present
# 56
# Adding  146 --> 313
# Node  188  already present
# 43
# Node  285  already present
# 3
# Adding  188 --> 285
# Node  57  already present
# 53
# Node  92  already present
# 162
# Adding  57 --> 92
# Node  168  already present
# 87
# Node  304  already present
# 7
# Adding  168 --> 304
# Node  199  already present
# 23
# Node  265  already present
# 93
# Adding  199 --> 265
# Node  332  already present
# 15
# Node  98  already present
# 55
# Adding  332 --> 98
# Node  169  already present
# 74
# Node  136  already present
# 138
# Adding  169 --> 136
# Node  213  already present
# 13
# Node  57  already present
# 53
# Adding  213 --> 57
# Node  248  already present
# 112
# Node  277  already present
# 62
# Adding  248 --> 277
# Node  98  already present
# 55
# Node  271  already present
# 6
# Adding  98 --> 271
# Node  56  already present
# 35
# Node  141  already present
# 94
# Adding  56 --> 141
# Node  310  already present
# 158
# Node  17  already present
# 131
# Adding  310 --> 17
# Node  199  already present
# 23
# Node  118  already present
# 60
# Adding  199 --> 118
# Node  239  already present
# 27
# Node  141  already present
# 94
# Adding  239 --> 141
# Node  21  already present
# 70
# Node  212  already present
# 167
# Adding  21 --> 212
# Node  176  already present
# 8
# Node  128  already present
# 90
# Adding  176 --> 128
# Node  175  already present
# 33
# Inserted node  278
# Adding  175 --> 278
# Node  203  already present
# 107
# Node  25  already present
# 120
# Adding  203 --> 25
# Node  265  already present
# 93
# Node  40  already present
# 164
# Adding  265 --> 40
# Node  26  already present
# 19
# Node  252  already present
# 14
# Adding  26 --> 252
# Node  339  already present
# 71
# Inserted node  340
# Adding  339 --> 340
# Node  172  already present
# 28
# Node  232  already present
# 109
# Adding  172 --> 232
# Node  31  already present
# 137
# Inserted node  237
# Adding  31 --> 237
# Inserted node  311
# Node  265  already present
# 93
# Adding  311 --> 265
# Inserted node  309
# Node  135  already present
# 41
# Adding  309 --> 135
# Inserted node  330
# Node  80  already present
# 133
# Adding  330 --> 80
# Inserted node  230
# Inserted node  70
# Adding  230 --> 70
# Node  272  already present
# 21
# Node  159  already present
# 127
# Adding  272 --> 159
# Node  21  already present
# 70
# Node  134  already present
# 63
# Adding  21 --> 134
# Node  24  already present
# 4
# Node  53  already present
# 30
# Adding  24 --> 53
# Node  40  already present
# 164
# Node  332  already present
# 15
# Adding  40 --> 332
# Node  261  already present
# 115
# Inserted node  16
# Adding  261 --> 16
# Node  239  already present
# 27
# Node  223  already present
# 67
# Adding  239 --> 223
# Node  304  already present
# 7
# Inserted node  249
# Adding  304 --> 249
# Node  277  already present
# 62
# Inserted node  39
# Adding  277 --> 39
# Node  224  already present
# 114
# Node  141  already present
# 94
# Adding  224 --> 141
# Node  142  already present
# 106
# Node  345  already present
# 96
# Adding  142 --> 345
# Node  72  already present
# 163
# Node  141  already present
# 94
# Adding  72 --> 141
# Node  313  already present
# 56
# Node  21  already present
# 70
# Adding  313 --> 21
# Node  261  already present
# 115
# Node  271  already present
# 6
# Adding  261 --> 271
# Node  276  already present
# 18
# Node  25  already present
# 120
# Adding  276 --> 25
# Node  109  already present
# 104
# Node  200  already present
# 54
# Adding  109 --> 200
# Node  288  already present
# 48
# Node  25  already present
# 120
# Adding  288 --> 25
# Node  329  already present
# 11
# Node  291  already present
# 105
# Adding  329 --> 291
# Node  194  already present
# 37
# Node  242  already present
# 80
# Adding  194 --> 242
# Node  223  already present
# 67
# Node  203  already present
# 107
# Adding  223 --> 203
# Node  290  already present
# 119
# Node  170  already present
# 32
# Adding  290 --> 170
# Node  261  already present
# 115
# Node  325  already present
# 61
# Adding  261 --> 325
# Node  36  already present
# 66
# Inserted node  251
# Adding  36 --> 251
# Node  291  already present
# 105
# Inserted node  10
# Adding  291 --> 10
# Node  342  already present
# 121
# Node  67  already present
# 59
# Adding  342 --> 67
# Node  21  already present
# 70
# Inserted node  55
# Adding  21 --> 55
# Node  108  already present
# 72
# Node  284  already present
# 146
# Adding  108 --> 284
# Node  3  already present
# 31
# Inserted node  228
# Adding  3 --> 228
# Node  168  already present
# 87
# Node  31  already present
# 137
# Adding  168 --> 31
# Node  67  already present
# 59
# Inserted node  69
# Adding  67 --> 69
# Node  323  already present
# 51
# Node  142  already present
# 106
# Adding  323 --> 142
# Node  261  already present
# 115
# Inserted node  113
# Adding  261 --> 113
# Node  55  already present
# 181
# Node  200  already present
# 54
# Adding  55 --> 200
# Node  13  already present
# 129
# Node  277  already present
# 62
# Adding  13 --> 277
# Node  322  already present
# 29
# Node  25  already present
# 120
# Adding  322 --> 25
# Inserted node  258
# Inserted node  257
# Adding  258 --> 257
# Node  285  already present
# 3
# Node  136  already present
# 138
# Adding  285 --> 136
# Node  80  already present
# 133
# Node  320  already present
# 142
# Adding  80 --> 320
# Node  265  already present
# 93
# Node  98  already present
# 55
# Adding  265 --> 98
# Node  252  already present
# 14
# Node  248  already present
# 112
# Adding  252 --> 248
# Node  62  already present
# 26
# Node  200  already present
# 54
# Adding  62 --> 200
# Node  313  already present
# 56
# Node  54  already present
# 102
# Adding  313 --> 54
# Inserted node  196
# Node  249  already present
# 177
# Adding  196 --> 249
# Node  323  already present
# 51
# Node  85  already present
# 143
# Adding  323 --> 85
# Node  82  already present
# 16
# Node  231  already present
# 38
# Adding  82 --> 231
# Node  141  already present
# 94
# Node  224  already present
# 114
# Adding  141 --> 224
# Node  342  already present
# 121
# Node  119  already present
# 50
# Adding  342 --> 119
# Node  304  already present
# 7
# Node  325  already present
# 61
# Adding  304 --> 325
# Node  136  already present
# 138
# Inserted node  156
# Adding  136 --> 156
# Node  325  already present
# 61
# Node  104  already present
# 153
# Adding  325 --> 104
# Node  211  already present
# 22
# Node  325  already present
# 61
# Adding  211 --> 325
# Node  304  already present
# 7
# Node  158  already present
# 98
# Adding  304 --> 158
# Node  254  already present
# 36
# Node  302  already present
# 100
# Adding  254 --> 302
# Node  92  already present
# 162
# Node  242  already present
# 80
# Adding  92 --> 242
# Node  30  already present
# 160
# Inserted node  303
# Adding  30 --> 303
# Node  274  already present
# 68
# Node  188  already present
# 43
# Adding  274 --> 188
# Node  28  already present
# 78
# Node  310  already present
# 158
# Adding  28 --> 310
# Node  271  already present
# 6
# Node  30  already present
# 160
# Adding  271 --> 30
# Inserted node  286
# Inserted node  81
# Adding  286 --> 81
# Node  144  already present
# 117
# Node  326  already present
# 132
# Adding  144 --> 326
# Node  265  already present
# 93
# Node  56  already present
# 35
# Adding  265 --> 56
# Node  249  already present
# 177
# Node  57  already present
# 53
# Adding  249 --> 57
# Node  341  already present
# 89
# Node  186  already present
# 1
# Adding  341 --> 186
# Inserted node  174
# Inserted node  293
# Adding  174 --> 293
# Inserted node  33
# Inserted node  42
# Adding  33 --> 42
# Node  312  already present
# 79
# Node  28  already present
# 78
# Adding  312 --> 28
# Node  199  already present
# 23
# Node  212  already present
# 167
# Adding  199 --> 212
# Node  9  already present
# 9
# Node  323  already present
# 51
# Adding  9 --> 323
# Node  168  already present
# 87
# Inserted node  347
# Adding  168 --> 347
# Node  67  already present
# 59
# Node  142  already present
# 106
# Adding  67 --> 142
# Node  1  already present
# 125
# Node  53  already present
# 30
# Adding  1 --> 53
# Node  115  already present
# 150
# Inserted node  2
# Adding  115 --> 2
# Node  333  already present
# 85
# Node  2  already present
# 197
# Adding  333 --> 2
# Node  332  already present
# 15
# Node  38  already present
# 99
# Adding  332 --> 38
# Node  291  already present
# 105
# Node  280  already present
# 20
# Adding  291 --> 280
# Node  119  already present
# 50
# Node  54  already present
# 102
# Adding  119 --> 54
# Node  271  already present
# 6
# Node  232  already present
# 109
# Adding  271 --> 232
# Node  135  already present
# 41
# Inserted node  281
# Adding  135 --> 281
# Node  258  already present
# 185
# Node  9  already present
# 9
# Adding  258 --> 9
# Node  285  already present
# 3
# Node  200  already present
# 54
# Adding  285 --> 200
# Node  330  already present
# 173
# Node  94  already present
# 124
# Adding  330 --> 94
# Inserted node  263
# Node  175  already present
# 33
# Adding  263 --> 175
# Node  212  already present
# 167
# Node  304  already present
# 7
# Adding  212 --> 304
# Node  238  already present
# 92
# Node  342  already present
# 121
# Adding  238 --> 342
# Node  284  already present
# 146
# Node  159  already present
# 127
# Adding  284 --> 159
# Node  111  already present
# 156
# Inserted node  279
# Adding  111 --> 279
# Node  141  already present
# 94
# Node  172  already present
# 28
# Adding  141 --> 172
# Node  66  already present
# 136
# Node  21  already present
# 70
# Adding  66 --> 21
# Node  313  already present
# 56
# Node  203  already present
# 107
# Adding  313 --> 203
# Node  84  already present
# 24
# Inserted node  51
# Adding  84 --> 51
# Node  139  already present
# 103
# Node  320  already present
# 142
# Adding  139 --> 320
# Node  25  already present
# 120
# Node  186  already present
# 1
# Adding  25 --> 186
# Node  252  already present
# 14
# Inserted node  338
# Adding  252 --> 338
# Node  200  already present
# 54
# Node  188  already present
# 43
# Adding  200 --> 188
# Node  59  already present
# 130
# Node  342  already present
# 121
# Adding  59 --> 342
# Inserted node  162
# Node  149  already present
# 128
# Adding  162 --> 149
# Node  304  already present
# 7
# Node  322  already present
# 29
# Adding  304 --> 322
# Node  185  already present
# 152
# Node  169  already present
# 74
# Adding  185 --> 169
# Node  252  already present
# 14
# Node  236  already present
# 0
# Adding  252 --> 236
# Node  25  already present
# 120
# Node  290  already present
# 119
# Adding  25 --> 290
# Node  56  already present
# 35
# Node  185  already present
# 152
# Adding  56 --> 185
# Node  158  already present
# 98
# Node  40  already present
# 164
# Adding  158 --> 40
# Node  238  already present
# 92
# Node  222  already present
# 161
# Adding  238 --> 222
# Node  56  already present
# 35
# Node  128  already present
# 90
# Adding  56 --> 128
# Node  199  already present
# 23
# Node  261  already present
# 115
# Adding  199 --> 261
# Node  271  already present
# 6
# Node  203  already present
# 107
# Adding  271 --> 203
# Node  63  already present
# 57
# Node  313  already present
# 56
# Adding  63 --> 313
# Node  62  already present
# 26
# Node  161  already present
# 135
# Adding  62 --> 161
# Node  302  already present
# 100
# Node  57  already present
# 53
# Adding  302 --> 57
# Inserted node  19
# Node  175  already present
# 33
# Adding  19 --> 175
# Node  98  already present
# 55
# Node  172  already present
# 28
# Adding  98 --> 172
# Node  28  already present
# 78
# Node  144  already present
# 117
# Adding  28 --> 144
# Node  249  already present
# 177
# Node  213  already present
# 13
# Adding  249 --> 213
# Node  239  already present
# 27
# Node  252  already present
# 14
# Adding  239 --> 252
# Node  332  already present
# 15
# Node  25  already present
# 120
# Adding  332 --> 25
# Node  265  already present
# 93
# Node  203  already present
# 107
# Adding  265 --> 203
# Node  303  already present
# 189
# Node  104  already present
# 153
# Adding  303 --> 104
# Node  339  already present
# 71
# Node  161  already present
# 135
# Adding  339 --> 161
# Node  119  already present
# 50
# Node  39  already present
# 178
# Adding  119 --> 39
# Node  239  already present
# 27
# Node  211  already present
# 22
# Adding  239 --> 211
# Node  313  already present
# 56
# Node  172  already present
# 28
# Adding  313 --> 172
# Node  200  already present
# 54
# Node  122  already present
# 2
# Adding  200 --> 122
# Node  104  already present
# 153
# Node  303  already present
# 189
# Adding  104 --> 303
# Inserted node  75
# Node  9  already present
# 9
# Adding  75 --> 9
# Node  137  already present
# 148
# Node  312  already present
# 79
# Adding  137 --> 312
# Node  272  already present
# 21
# Node  203  already present
# 107
# Adding  272 --> 203
# Inserted node  218
# Node  78  already present
# 95
# Adding  218 --> 78
# Node  261  already present
# 115
# Inserted node  268
# Adding  261 --> 268
# Inserted node  314
# Node  65  already present
# 17
# Adding  314 --> 65
# Node  57  already present
# 53
# Node  213  already present
# 13
# Adding  57 --> 213
# Node  21  already present
# 70
# Node  56  already present
# 35
# Adding  21 --> 56
# Node  7  already present
# 139
# Node  213  already present
# 13
# Adding  7 --> 213
# Node  139  already present
# 103
# Node  281  already present
# 198
# Adding  139 --> 281
# Inserted node  5
# Node  122  already present
# 2
# Adding  5 --> 122
# Node  55  already present
# 181
# Node  21  already present
# 70
# Adding  55 --> 21
# Node  80  already present
# 133
# Node  24  already present
# 4
# Adding  80 --> 24
# Inserted node  178
# Node  38  already present
# 99
# Adding  178 --> 38
# Node  186  already present
# 1
# Node  109  already present
# 104
# Adding  186 --> 109
# Node  304  already present
# 7
# Node  21  already present
# 70
# Adding  304 --> 21
# Inserted node  192
# Node  49  already present
# 141
# Adding  192 --> 49
# Node  203  already present
# 107
# Node  21  already present
# 70
# Adding  203 --> 21
# Node  285  already present
# 3
# Node  271  already present
# 6
# Adding  285 --> 271
# Node  122  already present
# 2
# Node  248  already present
# 112
# Adding  122 --> 248
# Node  104  already present
# 153
# Node  322  already present
# 29
# Adding  104 --> 322
# Node  312  already present
# 79
# Inserted node  243
# Adding  312 --> 243
# Node  302  already present
# 100
# Node  254  already present
# 36
# Adding  302 --> 254
# Node  236  already present
# 0
# Node  169  already present
# 74
# Adding  236 --> 169
# Node  304  already present
# 7
# Node  324  already present
# 154
# Adding  304 --> 324
# Node  266  already present
# 166
# Node  249  already present
# 177
# Adding  266 --> 249
# Node  3  already present
# 31
# Node  280  already present
# 20
# Adding  3 --> 280
# Node  243  already present
# 212
# Node  312  already present
# 79
# Adding  243 --> 312
# Node  211  already present
# 22
# Node  98  already present
# 55
# Adding  211 --> 98
# Inserted node  195
# Inserted node  181
# Adding  195 --> 181
# Inserted node  8
# Inserted node  245
# Adding  8 --> 245
# Node  297  already present
# 151
# Node  185  already present
# 152
# Adding  297 --> 185
# Node  113  already present
# 184
# Node  104  already present
# 153
# Adding  113 --> 104
# Node  10  already present
# 180
# Node  142  already present
# 106
# Adding  10 --> 142
# Inserted node  129
# Node  7  already present
# 139
# Adding  129 --> 7
# Node  56  already present
# 35
# Node  297  already present
# 151
# Adding  56 --> 297
# Node  248  already present
# 112
# Node  323  already present
# 51
# Adding  248 --> 323
# Node  273  already present
# 76
# Inserted node  328
# Adding  273 --> 328
# Node  115  already present
# 150
# Node  19  already present
# 204
# Adding  115 --> 19
# Node  36  already present
# 66
# Node  309  already present
# 172
# Adding  36 --> 309
# Node  129  already present
# 217
# Node  168  already present
# 87
# Adding  129 --> 168
# Node  242  already present
# 80
# Node  194  already present
# 37
# Adding  242 --> 194
# Node  343  already present
# 149
# Node  2  already present
# 197
# Adding  343 --> 2
# Node  21  already present
# 70
# Node  169  already present
# 74
# Adding  21 --> 169
# Node  226  already present
# 118
# Node  343  already present
# 149
# Adding  226 --> 343
# Node  40  already present
# 164
# Node  200  already present
# 54
# Adding  40 --> 200
# Node  172  already present
# 28
# Inserted node  331
# Adding  172 --> 331
# Node  326  already present
# 132
# Node  343  already present
# 149
# Adding  326 --> 343
# Node  134  already present
# 63
# Node  26  already present
# 19
# Adding  134 --> 26
# Node  332  already present
# 15
# Node  329  already present
# 11
# Adding  332 --> 329
# Node  3  already present
# 31
# Node  200  already present
# 54
# Adding  3 --> 200
# Node  331  already present
# 219
# Node  109  already present
# 104
# Adding  331 --> 109
# Inserted node  150
# Node  128  already present
# 90
# Adding  150 --> 128
# Inserted node  101
# Node  299  already present
# 47
# Adding  101 --> 299
# Node  203  already present
# 107
# Node  59  already present
# 130
# Adding  203 --> 59
# Node  231  already present
# 38
# Node  315  already present
# 49
# Adding  231 --> 315
# Node  265  already present
# 93
# Node  199  already present
# 23
# Adding  265 --> 199
# Inserted node  99
# Inserted node  296
# Adding  99 --> 296
# Node  322  already present
# 29
# Node  290  already present
# 119
# Adding  322 --> 290
# Node  296  already present
# 223
# Inserted node  102
# Adding  296 --> 102
# Node  118  already present
# 60
# Node  261  already present
# 115
# Adding  118 --> 261
# Node  238  already present
# 92
# Node  56  already present
# 35
# Adding  238 --> 56
# Node  117  already present
# 39
# Node  231  already present
# 38
# Adding  117 --> 231
# Node  312  already present
# 79
# Node  149  already present
# 128
# Adding  312 --> 149
# Node  304  already present
# 7
# Node  308  already present
# 88
# Adding  304 --> 308
# Node  105  already present
# 108
# Node  277  already present
# 62
# Adding  105 --> 277
# Node  204  already present
# 12
# Node  196  already present
# 187
# Adding  204 --> 196
# Node  315  already present
# 49
# Node  303  already present
# 189
# Adding  315 --> 303
# Node  284  already present
# 146
# Node  21  already present
# 70
# Adding  284 --> 21
# Node  239  already present
# 27
# Node  21  already present
# 70
# Adding  239 --> 21
# Node  312  already present
# 79
# Node  326  already present
# 132
# Adding  312 --> 326
# Node  277  already present
# 62
# Node  161  already present
# 135
# Adding  277 --> 161
# Node  340  already present
# 169
# Node  213  already present
# 13
# Adding  340 --> 213
# Node  98  already present
# 55
# Node  223  already present
# 67
# Adding  98 --> 223
# Node  172  already present
# 28
# Node  277  already present
# 62
# Adding  172 --> 277
# Node  128  already present
# 90
# Node  104  already present
# 153
# Adding  128 --> 104
# Node  313  already present
# 56
# Node  222  already present
# 161
# Adding  313 --> 222
# Node  98  already present
# 55
# Node  331  already present
# 219
# Adding  98 --> 331
# Node  299  already present
# 47
# Node  194  already present
# 37
# Adding  299 --> 194
# Node  122  already present
# 2
# Node  141  already present
# 94
# Adding  122 --> 141
# Node  324  already present
# 154
# Node  217  already present
# 111
# Adding  324 --> 217
# Node  291  already present
# 105
# Node  25  already present
# 120
# Adding  291 --> 25
# Node  13  already present
# 129
# Node  188  already present
# 43
# Adding  13 --> 188
# Node  104  already present
# 153
# Inserted node  318
# Adding  104 --> 318
# Node  261  already present
# 115
# Node  65  already present
# 17
# Adding  261 --> 65
# Node  265  already present
# 93
# Node  128  already present
# 90
# Adding  265 --> 128
# Inserted node  163
# Inserted node  173
# Adding  163 --> 173
# Node  116  already present
# 45
# Node  14  already present
# 157
# Adding  116 --> 14
# Node  92  already present
# 162
# Node  1  already present
# 125
# Adding  92 --> 1
# Node  26  already present
# 19
# Node  3  already present
# 31
# Adding  26 --> 3
# Inserted node  165
# Inserted node  121
# Adding  165 --> 121
# Node  3  already present
# 31
# Node  25  already present
# 120
# Adding  3 --> 25
# Node  149  already present
# 128
# Node  226  already present
# 118
# Adding  149 --> 226
# Node  328  already present
# 218
# Inserted node  306
# Adding  328 --> 306
# Node  172  already present
# 28
# Node  141  already present
# 94
# Adding  172 --> 141
# Node  303  already present
# 189
# Node  315  already present
# 49
# Adding  303 --> 315
# Node  56  already present
# 35
# Node  239  already present
# 27
# Adding  56 --> 239
# Node  122  already present
# 2
# Node  274  already present
# 68
# Adding  122 --> 274
# Node  46  already present
# 34
# Inserted node  177
# Adding  46 --> 177
# Node  249  already present
# 177
# Inserted node  180
# Adding  249 --> 180
# Node  73  already present
# 46
# Node  1  already present
# 125
# Adding  73 --> 1
# Node  272  already present
# 21
# Node  346  already present
# 5
# Adding  272 --> 346
# Node  53  already present
# 30
# Node  48  already present
# 52
# Adding  53 --> 48
# Node  199  already present
# 23
# Node  119  already present
# 50
# Adding  199 --> 119
# Node  248  already present
# 112
# Node  38  already present
# 99
# Adding  248 --> 38
# Node  24  already present
# 4
# Node  187  already present
# 134
# Adding  24 --> 187
# Node  196  already present
# 187
# Node  67  already present
# 59
# Adding  196 --> 67
# Node  304  already present
# 7
# Node  172  already present
# 28
# Adding  304 --> 172
# Inserted node  87
# Node  136  already present
# 138
# Adding  87 --> 136
# Node  323  already present
# 51
# Node  141  already present
# 94
# Adding  323 --> 141
# Node  323  already present
# 51
# Node  62  already present
# 26
# Adding  323 --> 62
# Inserted node  189
# Node  217  already present
# 111
# Adding  189 --> 217
# Node  280  already present
# 20
# Node  236  already present
# 0
# Adding  280 --> 236
# Node  115  already present
# 150
# Node  137  already present
# 148
# Adding  115 --> 137
# Node  25  already present
# 120
# Node  276  already present
# 18
# Adding  25 --> 276
# Node  186  already present
# 1
# Node  55  already present
# 181
# Adding  186 --> 55
# Node  30  already present
# 160
# Node  56  already present
# 35
# Adding  30 --> 56
# Inserted node  60
# Node  285  already present
# 3
# Adding  60 --> 285
# Node  197  already present
# 73
# Node  127  already present
# 40
# Adding  197 --> 127
# Node  334  already present
# 91
# Node  26  already present
# 19
# Adding  334 --> 26
# Node  304  already present
# 7
# Node  170  already present
# 32
# Adding  304 --> 170
# Inserted node  259
# Node  8  already present
# 215
# Adding  259 --> 8
# Node  346  already present
# 5
# Node  184  already present
# 126
# Adding  346 --> 184
# Node  186  already present
# 1
# Node  199  already present
# 23
# Adding  186 --> 199
# Node  200  already present
# 54
# Node  39  already present
# 178
# Adding  200 --> 39
# Node  185  already present
# 152
# Node  344  already present
# 58
# Adding  185 --> 344
# Node  184  already present
# 126
# Node  329  already present
# 11
# Adding  184 --> 329
# Node  149  already present
# 128
# Node  162  already present
# 203
# Adding  149 --> 162
# Node  285  already present
# 3
# Node  213  already present
# 13
# Adding  285 --> 213
# Node  185  already present
# 152
# Node  290  already present
# 119
# Adding  185 --> 290
# Node  13  already present
# 129
# Node  261  already present
# 115
# Adding  13 --> 261
# Node  204  already present
# 12
# Node  5  already present
# 209
# Adding  204 --> 5
# Node  109  already present
# 104
# Node  26  already present
# 19
# Adding  109 --> 26
# Node  169  already present
# 74
# Node  40  already present
# 164
# Adding  169 --> 40
# Node  194  already present
# 37
# Node  196  already present
# 187
# Adding  194 --> 196
# Node  85  already present
# 143
# Node  156  already present
# 188
# Adding  85 --> 156
# Node  67  already present
# 59
# Node  55  already present
# 181
# Adding  67 --> 55
# Node  98  already present
# 55
# Node  285  already present
# 3
# Adding  98 --> 285
# Node  123  already present
# 145
# Node  342  already present
# 121
# Adding  123 --> 342
# Node  118  already present
# 60
# Node  283  already present
# 116
# Adding  118 --> 283
# Inserted node  45
# Node  67  already present
# 59
# Adding  45 --> 67
# Node  80  already present
# 133
# Node  48  already present
# 52
# Adding  80 --> 48
# Node  162  already present
# 203
# Node  343  already present
# 149
# Adding  162 --> 343
# Node  272  already present
# 21
# Node  21  already present
# 70
# Adding  272 --> 21
# Node  271  already present
# 6
# Node  133  already present
# 25
# Adding  271 --> 133
# Node  67  already present
# 59
# Node  297  already present
# 151
# Adding  67 --> 297
# Node  13  already present
# 129
# Node  118  already present
# 60
# Adding  13 --> 118
# Node  115  already present
# 150
# Node  28  already present
# 78
# Adding  115 --> 28
# Node  230  already present
# 174
# Node  23  already present
# 44
# Adding  230 --> 23
# Inserted node  58
# Inserted node  269
# Adding  58 --> 269
# Node  46  already present
# 34
# Node  175  already present
# 33
# Adding  46 --> 175
# Node  25  already present
# 120
# Node  169  already present
# 74
# Adding  25 --> 169
# Node  80  already present
# 133
# Node  57  already present
# 53
# Adding  80 --> 57
# Node  135  already present
# 41
# Node  197  already present
# 73
# Adding  135 --> 197
# Node  203  already present
# 107
# Node  161  already present
# 135
# Adding  203 --> 161
# Node  113  already present
# 184
# Node  261  already present
# 115
# Adding  113 --> 261
# Node  116  already present
# 45
# Node  23  already present
# 44
# Adding  116 --> 23
# Node  275  already present
# 75
# Node  218  already present
# 206
# Adding  275 --> 218
# Node  285  already present
# 3
# Node  170  already present
# 32
# Adding  285 --> 170
# Node  314  already present
# 208
# Node  199  already present
# 23
# Adding  314 --> 199
# Node  279  already present
# 200
# Node  111  already present
# 156
# Adding  279 --> 111
# Node  126  already present
# 113
# Node  48  already present
# 52
# Adding  126 --> 48
# Node  36  already present
# 66
# Node  320  already present
# 142
# Adding  36 --> 320
# Node  137  already present
# 148
# Inserted node  167
# Adding  137 --> 167
# Node  140  already present
# 147
# Node  326  already present
# 132
# Adding  140 --> 326
# Node  130  already present
# 10
# Node  48  already present
# 52
# Adding  130 --> 48
# Node  302  already present
# 100
# Node  94  already present
# 124
# Adding  302 --> 94
# Node  315  already present
# 49
# Node  80  already present
# 133
# Adding  315 --> 80
# Node  101  already present
# 221
# Node  80  already present
# 133
# Adding  101 --> 80
# Node  23  already present
# 44
# Inserted node  227
# Adding  23 --> 227
# Node  92  already present
# 162
# Node  194  already present
# 37
# Adding  92 --> 194
# Node  2  already present
# 197
# Node  20  already present
# 82
# Adding  2 --> 20
# Node  72  already present
# 163
# Node  252  already present
# 14
# Adding  72 --> 252
# Node  323  already present
# 51
# Inserted node  96
# Adding  323 --> 96
# Inserted node  91
# Node  8  already present
# 215
# Adding  91 --> 8
# Inserted node  143
# Node  177  already present
# 231
# Adding  143 --> 177
# Node  200  already present
# 54
# Node  30  already present
# 160
# Adding  200 --> 30
# Node  257  already present
# 186
# Node  26  already present
# 19
# Adding  257 --> 26
# Node  331  already present
# 219
# Node  324  already present
# 154
# Adding  331 --> 324
# Node  142  already present
# 106
# Node  322  already present
# 29
# Adding  142 --> 322
# Node  188  already present
# 43
# Node  104  already present
# 153
# Adding  188 --> 104
# Node  239  already present
# 27
# Node  276  already present
# 18
# Adding  239 --> 276
# Node  23  already present
# 44
# Inserted node  61
# Adding  23 --> 61
# Node  325  already present
# 61
# Node  21  already present
# 70
# Adding  325 --> 21
# Node  204  already present
# 12
# Node  94  already present
# 124
# Adding  204 --> 94
# Node  346  already present
# 5
# Node  194  already present
# 37
# Adding  346 --> 194
# Node  223  already present
# 67
# Node  186  already present
# 1
# Adding  223 --> 186
# Node  56  already present
# 35
# Node  252  already present
# 14
# Adding  56 --> 252
# Node  113  already present
# 184
# Node  142  already present
# 106
# Adding  113 --> 142
# Node  26  already present
# 19
# Node  21  already present
# 70
# Adding  26 --> 21
# Node  285  already present
# 3
# Node  323  already present
# 51
# Adding  285 --> 323
# Node  290  already present
# 119
# Node  176  already present
# 8
# Adding  290 --> 176
# Inserted node  93
# Node  167  already present
# 240
# Adding  93 --> 167
# Node  276  already present
# 18
# Node  122  already present
# 2
# Adding  276 --> 122
# Node  96  already present
# 242
# Node  133  already present
# 25
# Adding  96 --> 133
# Inserted node  41
# Node  243  already present
# 212
# Adding  41 --> 243
# Node  188  already present
# 43
# Node  304  already present
# 7
# Adding  188 --> 304
# Node  203  already present
# 107
# Node  313  already present
# 56
# Adding  203 --> 313
# Node  200  already present
# 54
# Node  170  already present
# 32
# Adding  200 --> 170
# Node  232  already present
# 109
# Node  200  already present
# 54
# Adding  232 --> 200
# Inserted node  235
# Node  5  already present
# 209
# Adding  235 --> 5
# Inserted node  6
# Inserted node  89
# Adding  6 --> 89
# Node  171  already present
# 155
# Inserted node  107
# Adding  171 --> 107
# Node  257  already present
# 186
# Node  169  already present
# 74
# Adding  257 --> 169
# Node  224  already present
# 114
# Node  232  already present
# 109
# Adding  224 --> 232
# Node  271  already present
# 6
# Inserted node  79
# Adding  271 --> 79
# Node  187  already present
# 134
# Node  24  already present
# 4
# Adding  187 --> 24
# Node  141  already present
# 94
# Node  67  already present
# 59
# Adding  141 --> 67
# Node  113  already present
# 184
# Node  66  already present
# 136
# Adding  113 --> 66
# Node  56  already present
# 35
# Node  103  already present
# 42
# Adding  56 --> 103
# Node  59  already present
# 130
# Node  271  already present
# 6
# Adding  59 --> 271
# Node  40  already present
# 164
# Node  213  already present
# 13
# Adding  40 --> 213
# Node  158  already present
# 98
# Node  26  already present
# 19
# Adding  158 --> 26
# Node  211  already present
# 22
# Node  82  already present
# 16
# Adding  211 --> 82
# Node  285  already present
# 3
# Inserted node  208
# Adding  285 --> 208
# Node  119  already present
# 50
# Node  285  already present
# 3
# Adding  119 --> 285
# Node  26  already present
# 19
# Node  9  already present
# 9
# Adding  26 --> 9
# Node  40  already present
# 164
# Node  133  already present
# 25
# Adding  40 --> 133
# Node  143  already present
# 244
# Node  175  already present
# 33
# Adding  143 --> 175
# Node  56  already present
# 35
# Inserted node  132
# Adding  56 --> 132
# Node  45  already present
# 237
# Inserted node  221
# Adding  45 --> 221
# Node  212  already present
# 167
# Node  344  already present
# 58
# Adding  212 --> 344
# Node  285  already present
# 3
# Node  315  already present
# 49
# Adding  285 --> 315
# Inserted node  301
# Node  324  already present
# 154
# Adding  301 --> 324
# Node  21  already present
# 70
# Node  170  already present
# 32
# Adding  21 --> 170
# Node  326  already present
# 132
# Node  214  already present
# 81
# Adding  326 --> 214
# Node  281  already present
# 198
# Node  159  already present
# 127
# Adding  281 --> 159
# Node  281  already present
# 198
# Node  251  already present
# 179
# Adding  281 --> 251
# Node  109  already present
# 104
# Node  67  already present
# 59
# Adding  109 --> 67
# Node  25  already present
# 120
# Node  232  already present
# 109
# Adding  25 --> 232
# Node  59  already present
# 130
# Node  56  already present
# 35
# Adding  59 --> 56
# Node  92  already present
# 162
# Node  180  already present
# 232
# Adding  92 --> 180
# Node  122  already present
# 2
# Node  284  already present
# 146
# Adding  122 --> 284
# Node  322  already present
# 29
# Node  48  already present
# 52
# Adding  322 --> 48
# Node  277  already present
# 62
# Node  308  already present
# 88
# Adding  277 --> 308
# Node  290  already present
# 119
# Node  323  already present
# 51
# Adding  290 --> 323
# Node  167  already present
# 240
# Node  93  already present
# 246
# Adding  167 --> 93
# Inserted node  250
# Node  59  already present
# 130
# Adding  250 --> 59
# Inserted node  106
# Inserted node  29
# Adding  106 --> 29
# Node  274  already present
# 68
# Node  341  already present
# 89
# Adding  274 --> 341
# Node  249  already present
# 177
# Node  302  already present
# 100
# Adding  249 --> 302
# Node  118  already present
# 60
# Node  239  already present
# 27
# Adding  118 --> 239
# Node  111  already present
# 156
# Inserted node  337
# Adding  111 --> 337
# Node  252  already present
# 14
# Node  109  already present
# 104
# Adding  252 --> 109
# Node  56  already present
# 35
# Node  55  already present
# 181
# Adding  56 --> 55
# Node  80  already present
# 133
# Node  266  already present
# 166
# Adding  80 --> 266
# Node  252  already present
# 14
# Node  134  already present
# 63
# Adding  252 --> 134
# Node  104  already present
# 153
# Node  67  already present
# 59
# Adding  104 --> 67
# Node  94  already present
# 124
# Node  346  already present
# 5
# Adding  94 --> 346
# Node  141  already present
# 94
# Node  280  already present
# 20
# Adding  141 --> 280
# Node  325  already present
# 61
# Node  161  already present
# 135
# Adding  325 --> 161
# Node  322  already present
# 29
# Node  203  already present
# 107
# Adding  322 --> 203
# Node  96  already present
# 242
# Node  274  already present
# 68
# Adding  96 --> 274
# Node  158  already present
# 98
# Node  315  already present
# 49
# Adding  158 --> 315
# Node  199  already present
# 23
# Node  98  already present
# 55
# Adding  199 --> 98
# Node  134  already present
# 63
# Node  132  already present
# 254
# Adding  134 --> 132
# Node  280  already present
# 20
# Node  98  already present
# 55
# Adding  280 --> 98
# Node  254  already present
# 36
# Node  187  already present
# 134
# Adding  254 --> 187
# Node  329  already present
# 11
# Node  269  already present
# 239
# Adding  329 --> 269
# Node  297  already present
# 151
# Node  21  already present
# 70
# Adding  297 --> 21
# Inserted node  100
# Node  150  already present
# 220
# Adding  100 --> 150
# Inserted node  110
# Inserted node  264
# Adding  110 --> 264
# Node  266  already present
# 166
# Node  330  already present
# 173
# Adding  266 --> 330
# Node  171  already present
# 155
# Node  150  already present
# 220
# Adding  171 --> 150
# Node  322  already present
# 29
# Node  45  already present
# 237
# Adding  322 --> 45
# Node  72  already present
# 163
# Node  165  already present
# 228
# Adding  72 --> 165
# Node  344  already present
# 58
# Node  257  already present
# 186
# Adding  344 --> 257
# Node  184  already present
# 126
# Node  21  already present
# 70
# Adding  184 --> 21
# Node  119  already present
# 50
# Node  332  already present
# 15
# Adding  119 --> 332
# Node  257  already present
# 186
# Node  236  already present
# 0
# Adding  257 --> 236
# Node  277  already present
# 62
# Node  324  already present
# 154
# Adding  277 --> 324
# Node  332  already present
# 15
# Node  248  already present
# 112
# Adding  332 --> 248
# Node  329  already present
# 11
# Node  119  already present
# 50
# Adding  329 --> 119
# Inserted node  225
# Inserted node  86
# Adding  225 --> 86
# Node  232  already present
# 109
# Node  56  already present
# 35
# Adding  232 --> 56
# Node  291  already present
# 105
# Node  224  already present
# 114
# Adding  291 --> 224
# Node  53  already present
# 30
# Node  196  already present
# 187
# Adding  53 --> 196
# Node  315  already present
# 49
# Node  213  already present
# 13
# Adding  315 --> 213
# Node  322  already present
# 29
# Node  136  already present
# 138
# Adding  322 --> 136
# Node  181  already present
# 214
# Inserted node  152
# Adding  181 --> 152
# Node  141  already present
# 94
# Node  257  already present
# 186
# Adding  141 --> 257
# Node  180  already present
# 232
# Node  80  already present
# 133
# Adding  180 --> 80
# Node  26  already present
# 19
# Node  199  already present
# 23
# Adding  26 --> 199
# Node  45  already present
# 237
# Node  104  already present
# 153
# Adding  45 --> 104
# Node  332  already present
# 15
# Node  67  already present
# 59
# Adding  332 --> 67
# Node  303  already present
# 189
# Node  45  already present
# 237
# Adding  303 --> 45
# Node  250  already present
# 257
# Node  252  already present
# 14
# Adding  250 --> 252
# Node  3  already present
# 31
# Node  26  already present
# 19
# Adding  3 --> 26
# Node  98  already present
# 55
# Inserted node  148
# Adding  98 --> 148
# Node  185  already present
# 152
# Node  55  already present
# 181
# Adding  185 --> 55
# Node  172  already present
# 28
# Node  239  already present
# 27
# Adding  172 --> 239
# Inserted node  295
# Node  239  already present
# 27
# Adding  295 --> 239
# Node  325  already present
# 61
# Node  98  already present
# 55
# Adding  325 --> 98
# Node  252  already present
# 14
# Node  113  already present
# 184
# Adding  252 --> 113
# Node  323  already present
# 51
# Node  119  already present
# 50
# Adding  323 --> 119
# Node  188  already present
# 43
# Node  315  already present
# 49
# Adding  188 --> 315
# Node  55  already present
# 181
# Node  203  already present
# 107
# Adding  55 --> 203
# Node  137  already present
# 148
# Node  111  already present
# 156
# Adding  137 --> 111
# Node  224  already present
# 114
# Node  200  already present
# 54
# Adding  224 --> 200
# Node  194  already present
# 37
# Node  80  already present
# 133
# Adding  194 --> 80
# Node  295  already present
# 268
# Node  104  already present
# 153
# Adding  295 --> 104
# Node  17  already present
# 131
# Node  140  already present
# 147
# Adding  17 --> 140
# Node  266  already present
# 166
# Node  302  already present
# 100
# Adding  266 --> 302
# Node  232  already present
# 109
# Node  212  already present
# 167
# Adding  232 --> 212
# Node  249  already present
# 177
# Node  24  already present
# 4
# Adding  249 --> 24
# Node  200  already present
# 54
# Node  323  already present
# 51
# Adding  200 --> 323
# Node  323  already present
# 51
# Node  122  already present
# 2
# Adding  323 --> 122
# Node  203  already present
# 107
# Node  65  already present
# 17
# Adding  203 --> 65
# Node  259  already present
# 236
# Inserted node  201
# Adding  259 --> 201
# Node  161  already present
# 135
# Node  56  already present
# 35
# Adding  161 --> 56
# Node  119  already present
# 50
# Node  252  already present
# 14
# Adding  119 --> 252
# Node  238  already present
# 92
# Node  82  already present
# 16
# Adding  238 --> 82
# Node  197  already present
# 73
# Node  251  already present
# 179
# Adding  197 --> 251
# Node  105  already present
# 108
# Node  272  already present
# 21
# Adding  105 --> 272
# Node  291  already present
# 105
# ...
# Node  312  already present
# 79
# Node  144  already present
# 117
# Adding  312 --> 144
# Node  164  already present
# 312
# Node  285  already present
# 3
# Adding  164 --> 285
# Node  39  already present
# 178
# Node  257  already present
# 186
# Adding  39 --> 257
# Node  132  already present
# 254
# Node  242  already present
# 80
# Adding  132 --> 242
# Node  239  already present
# 27
# Node  40  already present
# 164
# Adding  239 --> 40
# Node  230  already present
# 174
# Node  214  already present
# 81
# Adding  230 --> 214
# Node  80  already present
# 133
# Node  330  already present
# 173
# Adding  80 --> 330
# Node  149  already present
# 128
# Node  14  already present
# 157
# Adding  149 --> 14
# Node  126  already present
# 113
# Node  1  already present
# 125
# Adding  126 --> 1
# Node  21  already present
# 70
# Node  313  already present
# 56
# Adding  21 --> 313
# Node  113  already present
# 184
# Node  199  already present
# 23
# Adding  113 --> 199
# Node  272  already present
# 21
# Node  85  already present
# 143
# Adding  272 --> 85
# Node  257  already present
# 186
# Node  105  already present
# 108
# Adding  257 --> 105
# Node  66  already present
# 136
# Node  134  already present
# 63
# Adding  66 --> 134
# Node  271  already present
# 6
# Node  63  already present
# 57
# Adding  271 --> 63
# Node  274  already present
# 68
# Node  185  already present
# 152
# Adding  274 --> 185
# Node  172  already present
# 28
# Node  203  already present
# 107
# Adding  172 --> 203
# Node  313  already present
# 56
# Node  119  already present
# 50
# Adding  313 --> 119
# Node  119  already present
# 50
# Node  1  already present
# 125
# Adding  119 --> 1
# Node  203  already present
# 107
# Node  341  already present
# 89
# Adding  203 --> 341
# Node  119  already present
# 50
# Node  248  already present
# 112
# Adding  119 --> 248
# Node  8  already present
# 215
# Node  110  already present
# 262
# Adding  8 --> 110
# Node  324  already present
# 154
# Node  27  already present
# 101
# Adding  324 --> 27
# Node  98  already present
# 55
# Node  200  already present
# 54
# Adding  98 --> 200
# Node  323  already present
# 51
# Node  188  already present
# 43
# Adding  323 --> 188
# Node  232  already present
# 109
# Node  271  already present
# 6
# Adding  232 --> 271
# Node  4  already present
# 293
# Node  181  already present
# 214
# Adding  4 --> 181
# Node  21  already present
# 70
# Node  127  already present
# 40
# Adding  21 --> 127
# Node  304  already present
# 7
# Node  285  already present
# 3
# Adding  304 --> 285
# Node  158  already present
# 98
# Node  232  already present
# 109
# Adding  158 --> 232
# Node  211  already present
# 22
# Node  172  already present
# 28
# Adding  211 --> 172
# Node  204  already present
# 12
# Node  180  already present
# 232
# Adding  204 --> 180
# Node  45  already present
# 237
# Node  132  already present
# 254
# Adding  45 --> 132
# Node  98  already present
# 55
# Node  13  already present
# 129
# Adding  98 --> 13
# Node  142  already present
# 106
# Node  203  already present
# 107
# Adding  142 --> 203
# Node  304  already present
# 7
# Node  246  already present
# 144
# Adding  304 --> 246
# Node  269  already present
# 239
# Node  100  already present
# 261
# Adding  269 --> 100
# Node  25  already present
# 120
# Node  65  already present
# 17
# Adding  25 --> 65
# Node  55  already present
# 181
# Node  185  already present
# 152
# Adding  55 --> 185
# Node  213  already present
# 13
# Node  56  already present
# 35
# Adding  213 --> 56
# Node  332  already present
# 15
# Node  213  already present
# 13
# Adding  332 --> 213
# Node  285  already present
# 3
# Node  332  already present
# 15
# Adding  285 --> 332
# Node  142  already present
# 106
# Node  188  already present
# 43
# Adding  142 --> 188
# Node  324  already present
# 154
# Node  224  already present
# 114
# Adding  324 --> 224
# Node  202  already present
# 305
# Node  173  already present
# 227
# Adding  202 --> 173
# Node  48  already present
# 52
# Node  126  already present
# 113
# Adding  48 --> 126
# Node  187  already present
# 134
# Node  266  already present
# 166
# Adding  187 --> 266
# Node  9  already present
# 9
# Node  3  already present
# 31
# Adding  9 --> 3
# Node  113  already present
# 184
# Node  169  already present
# 74
# Adding  113 --> 169
# Node  246  already present
# 144
# Node  285  already present
# 3
# Adding  246 --> 285
# Node  303  already present
# 189
# Node  213  already present
# 13
# Adding  303 --> 213
# Node  142  already present
# 106
# Node  239  already present
# 27
# Adding  142 --> 239
# Node  251  already present
# 179
# Node  184  already present
# 126
# Adding  251 --> 184
# Node  53  already present
# 30
# Node  242  already present
# 80
# Adding  53 --> 242
# Node  172  already present
# 28
# Node  231  already present
# 38
# Adding  172 --> 231
# Node  188  already present
# 43
# Node  13  already present
# 129
# Adding  188 --> 13
# Node  203  already present
# 107
# Node  338  already present
# 202
# Adding  203 --> 338
# Node  111  already present
# 156
# Node  137  already present
# 148
# Adding  111 --> 137
# Node  214  already present
# 81
# Node  19  already present
# 204
# Adding  214 --> 19
# Node  41  already present
# 247
# Node  326  already present
# 132
# Adding  41 --> 326
# Node  113  already present
# 184
# Node  134  already present
# 63
# Adding  113 --> 134
# Node  98  already present
# 55
# Node  304  already present
# 7
# Adding  98 --> 304
# Node  10  already present
# 180
# Node  332  already present
# 15
# Adding  10 --> 332
# Node  184  already present
# 126
# Node  108  already present
# 72
# Adding  184 --> 108
# Node  343  already present
# 149
# Node  20  already present
# 82
# Adding  343 --> 20
# Node  170  already present
# 32
# Node  239  already present
# 27
# Adding  170 --> 239
# Node  147  already present
# 308
# Node  89  already present
# 250
# Adding  147 --> 89
# Node  141  already present
# 94
# Node  25  already present
# 120
# Adding  141 --> 25
# Node  236  already present
# 0
# Node  84  already present
# 24
# Adding  236 --> 84
# Node  34  already present
# 331
# Node  173  already present
# 227
# Adding  34 --> 173
# Node  9  already present
# 9
# Node  231  already present
# 38
# Adding  9 --> 231
# Node  67  already present
# 59
# Node  82  already present
# 16
# Adding  67 --> 82
# Node  148  already present
# 267
# Node  224  already present
# 114
# Adding  148 --> 224
# Node  320  already present
# 142
# Node  197  already present
# 73
# Adding  320 --> 197
# Node  26  already present
# 19
# Node  142  already present
# 106
# Adding  26 --> 142
# Node  241  already present
# 322
# Node  49  already present
# 141
# Adding  241 --> 49
# Node  170  already present
# 32
# Node  119  already present
# 50
# Adding  170 --> 119
# Node  87  already present
# 233
# Node  291  already present
# 105
# Adding  87 --> 291
# Node  199  already present
# 23
# Node  200  already present
# 54
# Adding  199 --> 200
# Node  320  already present
# 142
# Node  80  already present
# 133
# Adding  320 --> 80
# Node  143  already present
# 244
# Node  321  already present
# 273
# Adding  143 --> 321
# Node  217  already present
# 111
# Node  189  already present
# 234
# Adding  217 --> 189
# Node  303  already present
# 189
# Node  67  already present
# 59
# Adding  303 --> 67
# Node  9  already present
# 9
# Node  188  already present
# 43
# Adding  9 --> 188
# Node  122  already present
# 2
# Node  239  already present
# 27
# Adding  122 --> 239
# Node  302  already present
# 100
# Node  299  already present
# 47
# Adding  302 --> 299
# Node  118  already present
# 60
# Node  203  already present
# 107
# Adding  118 --> 203
# Node  62  already present
# 26
# Node  186  already present
# 1
# Adding  62 --> 186
# Node  170  already present
# 32
# Node  62  already present
# 26
# Adding  170 --> 62
# Node  119  already present
# 50
# Node  324  already present
# 154
# Adding  119 --> 324
# Node  137  already present
# 148
# Node  140  already present
# 147
# Adding  137 --> 140
# Node  281  already present
# 198
# Node  135  already present
# 41
# Adding  281 --> 135
# Node  239  already present
# 27
# Node  265  already present
# 93
# Adding  239 --> 265
# Node  200  already present
# 54
# Node  45  already present
# 237
# Adding  200 --> 45
# Node  66  already present
# 136
# Node  122  already present
# 2
# Adding  66 --> 122
# Node  323  already present
# 51
# Node  26  already present
# 19
# Adding  323 --> 26
# Node  203  already present
# 107
# Node  270  already present
# 64
# Adding  203 --> 270
# Node  222  already present
# 161
# Node  211  already present
# 22
# Adding  222 --> 211
# Node  98  already present
# 55
# Node  239  already present
# 27
# Adding  98 --> 239
# Node  239  already present
# 27
# Node  142  already present
# 106
# Adding  239 --> 142
# Node  98  already present
# 55
# Node  109  already present
# 104
# Adding  98 --> 109
# Node  188  already present
# 43
# Node  208  already present
# 253
# Adding  188 --> 208
# Node  67  already present
# 59
# Node  224  already present
# 114
# Adding  67 --> 224
# Node  119  already present
# 50
# Node  318  already present
# 225
# Adding  119 --> 318
# Node  119  already present
# 50
# Node  261  already present
# 115
# Adding  119 --> 261
# Node  59  already present
# 130
# Node  118  already present
# 60
# Adding  59 --> 118
# Node  67  already present
# 59
# Node  122  already present
# 2
# Adding  67 --> 122
# Node  302  already present
# 100
# Node  48  already present
# 52
# Adding  302 --> 48
# Node  206  already present
# 309
# Node  121  already present
# 229
# Adding  206 --> 121
# Node  263  already present
# 199
# Node  68  already present
# 274
# Adding  263 --> 68
# Node  26  already present
# 19
# Node  66  already present
# 136
# Adding  26 --> 66
# Node  236  already present
# 0
# Node  30  already present
# 160
# Adding  236 --> 30
# Node  324  already present
# 154
# Node  67  already present
# 59
# Adding  324 --> 67
# Node  170  already present
# 32
# Node  122  already present
# 2
# Adding  170 --> 122
# Node  88  already present
# 69
# Node  178  already present
# 210
# Adding  88 --> 178
# Node  56  already present
# 35
# Node  113  already present
# 184
# Adding  56 --> 113
# Node  137  already present
# 148
# Node  243  already present
# 212
# Adding  137 --> 243
# Node  25  already present
# 120
# Node  246  already present
# 144
# Adding  25 --> 246
# Node  41  already present
# 247
# Node  20  already present
# 82
# Adding  41 --> 20
# Node  199  already present
# 23
# Node  26  already present
# 19
# Adding  199 --> 26
# Node  254  already present
# 36
# Node  180  already present
# 232
# Adding  254 --> 180
# Node  40  already present
# 164
# Node  258  already present
# 185
# Adding  40 --> 258
# Node  119  already present
# 50
# Node  189  already present
# 234
# Adding  119 --> 189
# Node  304  already present
# 7
# Node  31  already present
# 137
# Adding  304 --> 31
# Node  186  already present
# 1
# Node  25  already present
# 120
# Adding  186 --> 25
# Node  140  already present
# 147
# Node  28  already present
# 78
# Adding  140 --> 28
# Node  98  already present
# 55
# Node  277  already present
# 62
# Adding  98 --> 277
# Node  26  already present
# 19
# Node  56  already present
# 35
# Adding  26 --> 56
# Node  176  already present
# 8
# Node  122  already present
# 2
# Adding  176 --> 122
# Node  317  already present
# 97
# Node  40  already present
# 164
# Adding  317 --> 40
# Node  134  already present
# 63
# Node  277  already present
# 62
# Adding  134 --> 277
# Node  298  already present
# 277
# Node  199  already present
# 23
# Adding  298 --> 199
# Node  281  already present
# 198
# Node  122  already present
# 2
# Adding  281 --> 122
# Node  265  already present
# 93
# Node  252  already present
# 14
# Adding  265 --> 252
# Node  51  already present
# 201
# Node  31  already present
# 137
# Adding  51 --> 31
# Node  285  already present
# 3
# Node  188  already present
# 43
# Adding  285 --> 188
# Node  265  already present
# 93
# Node  26  already present
# 19
# Adding  265 --> 26
# Node  280  already present
# 20
# Node  297  already present
# 151
# Adding  280 --> 297
# Node  63  already present
# 57
# Node  271  already present
# 6
# Adding  63 --> 271
# Node  271  already present
# 6
# Node  314  already present
# 208
# Adding  271 --> 314
# Node  322  already present
# 29
# Node  67  already present
# 59
# Adding  322 --> 67
# Node  297  already present
# 151
# Node  25  already present
# 120
# Adding  297 --> 25
# Node  26  already present
# 19
# Node  248  already present
# 112
# Adding  26 --> 248
# Node  304  already present
# 7
# Node  13  already present
# 129
# Adding  304 --> 13
# Node  181  already present
# 214
# Node  218  already present
# 206
# Adding  181 --> 218
# Node  68  already present
# 274
# Node  296  already present
# 223
# Adding  68 --> 296
# Node  45  already present
# 237
# Node  345  already present
# 96
# Adding  45 --> 345
# Node  89  already present
# 250
# Node  147  already present
# 308
# Adding  89 --> 147
# Node  66  already present
# 136
# Node  308  already present
# 88
# Adding  66 --> 308
# Node  315  already present
# 49
# Node  1  already present
# 125
# Adding  315 --> 1
# Node  185  already present
# 152
# Node  26  already present
# 19
# Adding  185 --> 26
# Node  181  already present
# 214
# Node  306  already present
# 230
# Adding  181 --> 306
# Node  271  already present
# 6
# Node  56  already present
# 35
# Adding  271 --> 56
# Node  105  already present
# 108
# Node  315  already present
# 49
# Adding  105 --> 315
# Node  270  already present
# 64
# Node  25  already present
# 120
# Adding  270 --> 25
# Node  261  already present
# 115
# Node  56  already present
# 35
# Adding  261 --> 56
# Node  158  already present
# 98
# Node  60  already present
# 235
# Adding  158 --> 60
# Node  231  already present
# 38
# Node  25  already present
# 120
# Adding  231 --> 25
# Node  176  already present
# 8
# Node  188  already present
# 43
# Adding  176 --> 188
# Node  246  already present
# 144
# Node  25  already present
# 120
# Adding  246 --> 25
# Node  122  already present
# 2
# Node  136  already present
# 138
# Adding  122 --> 136
# Node  248  already present
# 112
# Node  134  already present
# 63
# Adding  248 --> 134
# Node  331  already present
# 219
# Node  25  already present
# 120
# Adding  331 --> 25
# Node  25  already present
# 120
# Node  332  already present
# 15
# Adding  25 --> 332
# Node  97  already present
# 284
# Node  182  already present
# 320
# Adding  97 --> 182
# Node  201  already present
# 269
# Node  259  already present
# 236
# Adding  201 --> 259
# Node  60  already present
# 235
# Node  313  already present
# 56
# Adding  60 --> 313
# Node  156  already present
# 188
# Node  272  already present
# 21
# Adding  156 --> 272
# Node  268  already present
# 207
# Node  172  already present
# 28
# Adding  268 --> 172
# Node  122  already present
# 2
# Node  251  already present
# 179
# Adding  122 --> 251
# Node  172  already present
# 28
# Node  313  already present
# 56
# Adding  172 --> 313
# Node  342  already present
# 121
# Node  285  already present
# 3
# Adding  342 --> 285
# Node  299  already present
# 47
# Node  1  already present
# 125
# Adding  299 --> 1
# Node  92  already present
# 162
# Node  80  already present
# 133
# Adding  92 --> 80
# Node  343  already present
# 149
# Node  144  already present
# 117
# Adding  343 --> 144
# Node  339  already present
# 71
# Node  158  already present
# 98
# Adding  339 --> 158
# Node  56  already present
# 35
# Node  142  already present
# 106
# Adding  56 --> 142
# Node  109  already present
# 104
# Node  325  already present
# 61
# Adding  109 --> 325
# Node  252  already present
# 14
# Node  170  already present
# 32
# Adding  252 --> 170
# Node  177  already present
# 231
# Node  68  already present
# 274
# Adding  177 --> 68
# Node  265  already present
# 93
# Node  313  already present
# 56
# Adding  265 --> 313
# Node  219  already present
# 315
# Node  154  already present
# 318
# Adding  219 --> 154
# Node  169  already present
# 74
# Node  252  already present
# 14
# Adding  169 --> 252
# Node  24  already present
# 4
# Node  249  already present
# 177
# Adding  24 --> 249
# Node  199  already present
# 23
# Node  313  already present
# 56
# Adding  199 --> 313
# Node  322  already present
# 29
# Node  224  already present
# 114
# Adding  322 --> 224
# Node  128  already present
# 90
# Node  98  already present
# 55
# Adding  128 --> 98
# Node  200  already present
# 54
# Node  142  already present
# 106
# Adding  200 --> 142
# Node  30  already present
# 160
# Node  178  already present
# 210
# Adding  30 --> 178
# Node  13  already present
# 129
# Node  325  already present
# 61
# Adding  13 --> 325
# Node  170  already present
# 32
# Node  252  already present
# 14
# Adding  170 --> 252
# Node  322  already present
# 29
# Node  271  already present
# 6
# Adding  322 --> 271
# Node  88  already present
# 69
# Node  25  already present
# 120
# Adding  88 --> 25
# Node  127  already present
# 40
# Node  197  already present
# 73
# Adding  127 --> 197
# Node  26  already present
# 19
# Node  212  already present
# 167
# Adding  26 --> 212
# Node  62  already present
# 26
# Node  96  already present
# 242
# Adding  62 --> 96
# Node  171  already present
# 155
# Node  58  already present
# 238
# Adding  171 --> 58
# Node  326  already present
# 132
# Node  20  already present
# 82
# Adding  326 --> 20
# Node  85  already present
# 143
# Node  75  already present
# 205
# Adding  85 --> 75
# Node  98  already present
# 55
# Node  332  already present
# 15
# Adding  98 --> 332
# Node  291  already present
# 105
# Node  339  already present
# 71
# Adding  291 --> 339

# %%
import random

# %%
def write_tuple_to_file(f,t):
    string=str(t[0])+' '+str(t[1])+'\n'
    f.write(string)

def retrieve_edge_name_tuple(g,t):
    a=(g.vs[t[0]]['name'],g.vs[t[1]]['name'])
    return a

# %%
def generate_datasets(g,num,train_filename,valid_filename,test_filename):
    load_dataset('abd',g)

    f=open(train_filename,'a+');

    global train_num
    train_num=int(len(g.es)*0.5)
    print('train length=',train_num)

    global test_num
    test_num=int(len(g.es)*0.25)
    print('test length=',test_num)

    global valid_num
    valid_num=int(len(g.es)*0.15)
    print('valid num=',valid_num)

    for i in range(train_num):
        edgeSet=g.es;
        r=random.randint(0,len(edgeSet)-1);
        t=edgeSet[r].tuple
        g.delete_edges(t);
        print('len of es=',len(edgeSet))
        write_tuple_to_file(f,retrieve_edge_name_tuple(g,t))
    f.close()

    f=open(test_filename,'a+');
    for i in range(test_num):
        edgeSet=g.es;
        r=random.randint(0,len(edgeSet)-1);
        print('r=',r)
        t=edgeSet[r].tuple
        g.delete_edges(t);
        print('len of es=',len(edgeSet))
        write_tuple_to_file(f,retrieve_edge_name_tuple(g,t))
    f.close()
    
    f=open(valid_filename,'a+');
    for i in range(valid_num):
        edgeSet=g.es;
        if(len(g.es)==0):
            break
        else:
            print('len of es=',len(edgeSet))
            r=random.randint(0,len(edgeSet)-1);
            print('r=',r)
            t=edgeSet[r].tuple
            g.delete_edges(t);
            write_tuple_to_file(f,retrieve_edge_name_tuple(g,t))
            if(len(g.es)==0):
                f.close()
                break

# %%
g = Graph()
generate_datasets(g,len(g.es)/10,'C:\\Users\\admin\\Desktop\\Baveet\\Social_Datasets\\made_dataset\\sample_train.edges','C:\\Users\\admin\\Desktop\\Baveet\\Social_Datasets\\made_dataset\\sample_valid.edges','C:\\Users\\admin\\Desktop\\Baveet\\Social_Datasets\\made_dataset\\sample_test.edges')
# Out:
# 0
# fileName= C:\Users\admin\Desktop\Baveet\Social_Datasets\facebook\edges\0.edges
# Inserted node  186
# Adding  236 --> 186
# Inserted node  122
# Inserted node  285
# Adding  122 --> 285
# Inserted node  24
# Inserted node  346
# Adding  24 --> 346
# Inserted node  271
# Inserted node  304
# Adding  271 --> 304
# Inserted node  176
# Inserted node  9
# Adding  176 --> 9
# Inserted node  130
# Inserted node  329
# Adding  130 --> 329
# Inserted node  204
# Inserted node  213
# Adding  204 --> 213
# Inserted node  252
# Inserted node  332
# Adding  252 --> 332
# Inserted node  82
# Inserted node  65
# Adding  82 --> 65
# Inserted node  276
# Inserted node  26
# Adding  276 --> 26
# Inserted node  280
# Inserted node  272
# Adding  280 --> 272
# Inserted node  211
# Inserted node  199
# Adding  211 --> 199
# Inserted node  84
# Node  236  already present
# 0
# Adding  84 --> 236
# Inserted node  133
# Inserted node  62
# Adding  133 --> 62
# Inserted node  239
# Inserted node  172
# Adding  239 --> 172
# Inserted node  322
# Inserted node  53
# Adding  322 --> 53
# Inserted node  3
# Inserted node  170
# Adding  3 --> 170
# Inserted node  175
# Inserted node  46
# Adding  175 --> 46
# Node  170  already present
# 32
# Node  176  already present
# 8
# Adding  170 --> 176
# Node  170  already present
# 32
# Inserted node  56
# Adding  170 --> 56
# Inserted node  254
# Inserted node  194
# Adding  254 --> 194
# Inserted node  231
# Inserted node  117
# Adding  231 --> 117
# Inserted node  127
# Inserted node  135
# Adding  127 --> 135
# Node  285  already present
# 3
# Inserted node  103
# Adding  285 --> 103
# Inserted node  188
# Node  133  already present
# 25
# Adding  188 --> 133
# Inserted node  23
# Inserted node  116
# Adding  23 --> 116
# Inserted node  73
# Inserted node  299
# Adding  73 --> 299
# Inserted node  288
# Inserted node  315
# Adding  288 --> 315
# Inserted node  119
# Inserted node  323
# Adding  119 --> 323
# Inserted node  48
# Inserted node  57
# Adding  48 --> 57
# Inserted node  200
# Inserted node  98
# Adding  200 --> 98
# Inserted node  313
# Inserted node  63
# Adding  313 --> 63
# Node  199  already present
# 23
# Node  304  already present
# 7
# Adding  199 --> 304
# Node  53  already present
# 30
# Node  346  already present
# 5
# Adding  53 --> 346
# Inserted node  344
# Node  239  already present
# 27
# Adding  344 --> 239
# Node  56  already present
# 35
# Inserted node  67
# Adding  56 --> 67
# Inserted node  118
# Inserted node  325
# Adding  118 --> 325
# Node  188  already present
# 43
# Node  119  already present
# 50
# Adding  188 --> 119
# Node  26  already present
# 19
# Inserted node  277
# Adding  26 --> 277
# Inserted node  134
# Node  56  already present
# 35
# Adding  134 --> 56
# Inserted node  270
# Inserted node  76
# Adding  270 --> 76
# Node  135  already present
# 41
# Inserted node  36
# Adding  135 --> 36
# Inserted node  223
# Node  170  already present
# 32
# Adding  223 --> 170
# Node  170  already present
# 32
# Inserted node  274
# Adding  170 --> 274
# Inserted node  88
# Inserted node  21
# Adding  88 --> 21
# Inserted node  339
# Node  119  already present
# 50
# Adding  339 --> 119
# Inserted node  108
# Inserted node  197
# Adding  108 --> 197
# Inserted node  169
# Node  271  already present
# 6
# Adding  169 --> 271
# Node  62  already present
# 26
# Node  236  already present
# 0
# Adding  62 --> 236
# Inserted node  275
# Inserted node  273
# Adding  275 --> 273
# Node  88  already present
# 69
# Node  186  already present
# 1
# Adding  88 --> 186
# Node  213  already present
# 13
# Node  186  already present
# 1
# Adding  213 --> 186
# Inserted node  83
# Node  23  already present
# 44
# Adding  83 --> 23
# Inserted node  28
# Inserted node  312
# Adding  28 --> 312
# Inserted node  242
# Node  57  already present
# 53
# Adding  242 --> 57
# Inserted node  214
# Inserted node  20
# Adding  214 --> 20
# Inserted node  307
# Inserted node  71
# Adding  307 --> 71
# Node  20  already present
# 82
# Inserted node  333
# Adding  20 --> 333
# Inserted node  207
# Node  322  already present
# 29
# Adding  207 --> 322
# Node  339  already present
# 71
# Inserted node  168
# Adding  339 --> 168
# Inserted node  308
# Node  277  already present
# 62
# Adding  308 --> 277
# Node  186  already present
# 1
# Inserted node  341
# Adding  186 --> 341
# Node  322  already present
# 29
# Node  122  already present
# 2
# Adding  322 --> 122
# Inserted node  128
# Node  9  already present
# 9
# Adding  128 --> 9
# Inserted node  334
# Node  252  already present
# 14
# Adding  334 --> 252
# Inserted node  238
# Inserted node  265
# Adding  238 --> 265
# Node  67  already present
# 59
# Inserted node  141
# Adding  67 --> 141
# Inserted node  78
# Node  273  already present
# 76
# Adding  78 --> 273
# Inserted node  345
# Node  122  already present
# 2
# Adding  345 --> 122
# Node  315  already present
# 49
# Node  345  already present
# 96
# Adding  315 --> 345
# Inserted node  317
# Inserted node  158
# Adding  317 --> 158
# Node  98  already present
# 55
# Node  21  already present
# 70
# Adding  98 --> 21
# Node  339  already present
# 71
# Inserted node  38
# Adding  339 --> 38
# Node  24  already present
# 4
# Inserted node  302
# Adding  24 --> 302
# Inserted node  27
# Inserted node  54
# Adding  27 --> 54
# Node  197  already present
# 73
# Inserted node  139
# Adding  197 --> 139
# Inserted node  109
# Node  118  already present
# 60
# Adding  109 --> 118
# Node  252  already present
# 14
# Inserted node  291
# Adding  252 --> 291
# Node  170  already present
# 32
# Inserted node  142
# Adding  170 --> 142
# Node  82  already present
# 16
# Node  271  already present
# 6
# Adding  82 --> 271
# Inserted node  203
# Node  332  already present
# 15
# Adding  203 --> 332
# Inserted node  105
# Node  9  already present
# 9
# Adding  105 --> 9
# Inserted node  232
# Node  285  already present
# 3
# Adding  232 --> 285
# Inserted node  64
# Inserted node  217
# Adding  64 --> 217
# Node  239  already present
# 27
# Node  62  already present
# 26
# Adding  239 --> 62
# Inserted node  248
# Node  332  already present
# 15
# Adding  248 --> 332
# Node  73  already present
# 46
# Inserted node  126
# Adding  73 --> 126
# Inserted node  224
# Inserted node  261
# Adding  224 --> 261
# Inserted node  283
# Node  3  already present
# 31
# Adding  283 --> 3
# Inserted node  144
# Inserted node  226
# Adding  144 --> 226
# Node  119  already present
# 50
# Node  48  already present
# 52
# Adding  119 --> 48
# Inserted node  290
# Inserted node  25
# Adding  290 --> 25
# Node  172  already present
# 28
# Inserted node  342
# Adding  172 --> 342
# Node  119  already present
# 50
# Node  170  already present
# 32
# Adding  119 --> 170
# Node  285  already present
# 3
# Inserted node  146
# Adding  285 --> 146
# Inserted node  300
# Inserted node  94
# Adding  300 --> 94
# Node  236  already present
# 0
# Node  142  already present
# 106
# Adding  236 --> 142
# Node  346  already present
# 5
# Inserted node  1
# Adding  346 --> 1
# Inserted node  184
# Inserted node  159
# Adding  184 --> 159
# Node  159  already present
# 127
# Node  139  already present
# 103
# Adding  159 --> 139
# Node  53  already present
# 30
# Node  299  already present
# 47
# Adding  53 --> 299
# Inserted node  149
# Node  20  already present
# 82
# Adding  149 --> 20
# Node  83  already present
# 77
# Node  25  already present
# 120
# Adding  83 --> 25
# Node  332  already present
# 15
# Inserted node  13
# Adding  332 --> 13
# Node  25  already present
# 120
# Node  94  already present
# 124
# Adding  25 --> 94
# Node  342  already present
# 121
# Inserted node  59
# Adding  342 --> 59
# Node  238  already present
# 92
# Node  239  already present
# 27
# Adding  238 --> 239
# Inserted node  17
# Inserted node  326
# Adding  17 --> 326
# Inserted node  80
# Inserted node  187
# Adding  80 --> 187
# Node  325  already present
# 61
# Node  109  already present
# 104
# Adding  325 --> 109
# Node  224  already present
# 114
# Node  84  already present
# 24
# Adding  224 --> 84
# Inserted node  161
# Node  142  already present
# 106
# Adding  161 --> 142
# Node  122  already present
# 2
# Node  323  already present
# 51
# Adding  122 --> 323
# Node  161  already present
# 135
# Node  308  already present
# 88
# Adding  161 --> 308
# Node  142  already present
# 106
# Inserted node  66
# Adding  142 --> 66
# Node  308  already present
# 88
# Inserted node  31
# Adding  308 --> 31
# Inserted node  136
# Inserted node  7
# Adding  136 --> 7
# Node  271  already present
# 6
# Node  252  already present
# 14
# Adding  271 --> 252
# Inserted node  255
# Inserted node  49
# Adding  255 --> 49
# Node  48  already present
# 52
# Inserted node  320
# Adding  48 --> 320
# Node  3  already present
# 31
# Inserted node  85
# Adding  3 --> 85
# Inserted node  246
# Node  7  already present
# 139
# Adding  246 --> 7
# Node  109  already present
# 104
# Node  56  already present
# 35
# Adding  109 --> 56
# Node  109  already present
# 104
# Node  119  already present
# 50
# Adding  109 --> 119
# Node  239  already present
# 27
# Node  238  already present
# 92
# Adding  239 --> 238
# Node  272  already present
# 21
# Node  186  already present
# 1
# Adding  272 --> 186
# Node  200  already present
# 54
# Inserted node  123
# Adding  200 --> 123
# Node  285  already present
# 3
# Node  246  already present
# 144
# Adding  285 --> 246
# Node  271  already present
# 6
# Node  188  already present
# 43
# Adding  271 --> 188
# Node  31  already present
# 137
# Node  277  already present
# 62
# Adding  31 --> 277
# Node  326  already present
# 132
# Node  17  already present
# 131
# Adding  326 --> 17
# Inserted node  284
# Node  108  already present
# 72
# Adding  284 --> 108
# Inserted node  140
# Inserted node  137
# Adding  140 --> 137
# Node  56  already present
# 35
# Node  26  already present
# 19
# Adding  56 --> 26
# Inserted node  343
# Inserted node  115
# Adding  343 --> 115
# Node  25  already present
# 120
# Node  323  already present
# 51
# Adding  25 --> 323
# Node  345  already present
# 96
# Node  159  already present
# 127
# Adding  345 --> 159
# Inserted node  297
# Node  26  already present
# 19
# Adding  297 --> 26
# Node  343  already present
# 149
# Node  149  already present
# 128
# Adding  343 --> 149
# Node  320  already present
# 142
# Node  48  already present
# 52
# Adding  320 --> 48
# Node  200  already present
# 54
# Node  109  already present
# 104
# Adding  200 --> 109
# Inserted node  185
# Node  271  already present
# 6
# Adding  185 --> 271
# Node  7  already present
# 139
# Node  136  already present
# 138
# Adding  7 --> 136
# Node  326  already present
# 132
# Node  149  already present
# 128
# Adding  326 --> 149
# Inserted node  104
# Node  56  already present
# 35
# Adding  104 --> 56
# Node  339  already present
# 71
# Node  136  already present
# 138
# Adding  339 --> 136
# Node  308  already present
# 88
# Node  142  already present
# 106
# Adding  308 --> 142
# Inserted node  324
# Node  329  already present
# 11
# Adding  324 --> 329
# Node  9  already present
# 9
# Node  252  already present
# 14
# Adding  9 --> 252
# Node  1  already present
# 125
# Node  315  already present
# 49
# Adding  1 --> 315
# Node  21  already present
# 70
# Node  274  already present
# 68
# Adding  21 --> 274
# Node  119  already present
# 50
# Inserted node  171
# Adding  119 --> 171
# Node  345  already present
# 96
# Node  67  already present
# 59
# Adding  345 --> 67
# Node  280  already present
# 20
# Node  1  already present
# 125
# Adding  280 --> 1
# Node  313  already present
# 56
# Node  265  already present
# 93
# Adding  313 --> 265
# Node  277  already present
# 62
# Node  271  already present
# 6
# Adding  277 --> 271
# Node  56  already present
# 35
# Node  88  already present
# 69
# Adding  56 --> 88
# Node  9  already present
# 9
# Node  203  already present
# 107
# Adding  9 --> 203
# Node  85  already present
# 143
# Node  176  already present
# 8
# Adding  85 --> 176
# Inserted node  111
# Node  343  already present
# 149
# Adding  111 --> 343
# Inserted node  14
# Node  20  already present
# 82
# Adding  14 --> 20
# Inserted node  310
# Inserted node  32
# Adding  310 --> 32
# Node  304  already present
# 7
# Inserted node  30
# Adding  304 --> 30
# Node  199  already present
# 23
# Inserted node  222
# Adding  199 --> 222
# Inserted node  92
# Node  346  already present
# 5
# Adding  92 --> 346
# Inserted node  72
# Inserted node  40
# Adding  72 --> 40
# Node  284  already present
# 146
# Node  184  already present
# 126
# Adding  284 --> 184
# Inserted node  125
# Node  136  already present
# 138
# Adding  125 --> 136
# Node  134  already present
# 63
# Node  118  already present
# 60
# Adding  134 --> 118
# Node  9  already present
# 9
# Node  322  already present
# 29
# Adding  9 --> 322
# Node  302  already present
# 100
# Inserted node  266
# Adding  302 --> 266
# Node  332  already present
# 15
# Node  104  already present
# 153
# Adding  332 --> 104
# Node  40  already present
# 164
# Node  199  already present
# 23
# Adding  40 --> 199
# Inserted node  212
# Node  67  already present
# 59
# Adding  212 --> 67
# Node  200  already present
# 54
# Node  277  already present
# 62
# Adding  200 --> 277
# Node  82  already present
# 16
# Node  169  already present
# 74
# Adding  82 --> 169
# Node  270  already present
# 64
# Node  203  already present
# 107
# Adding  270 --> 203
# Node  308  already present
# 88
# Node  172  already present
# 28
# Adding  308 --> 172
# Node  261  already present
# 115
# Node  63  already present
# 57
# Adding  261 --> 63
# Node  146  already present
# 122
# Node  313  already present
# 56
# Adding  146 --> 313
# Node  188  already present
# 43
# Node  285  already present
# 3
# Adding  188 --> 285
# Node  57  already present
# 53
# Node  92  already present
# 162
# Adding  57 --> 92
# Node  168  already present
# 87
# Node  304  already present
# 7
# Adding  168 --> 304
# Node  199  already present
# 23
# Node  265  already present
# 93
# Adding  199 --> 265
# Node  332  already present
# 15
# Node  98  already present
# 55
# Adding  332 --> 98
# Node  169  already present
# 74
# Node  136  already present
# 138
# Adding  169 --> 136
# Node  213  already present
# 13
# Node  57  already present
# 53
# Adding  213 --> 57
# Node  248  already present
# 112
# Node  277  already present
# 62
# Adding  248 --> 277
# Node  98  already present
# 55
# Node  271  already present
# 6
# Adding  98 --> 271
# Node  56  already present
# 35
# Node  141  already present
# 94
# Adding  56 --> 141
# Node  310  already present
# 158
# Node  17  already present
# 131
# Adding  310 --> 17
# Node  199  already present
# 23
# Node  118  already present
# 60
# Adding  199 --> 118
# Node  239  already present
# 27
# Node  141  already present
# 94
# Adding  239 --> 141
# Node  21  already present
# 70
# Node  212  already present
# 167
# Adding  21 --> 212
# Node  176  already present
# 8
# Node  128  already present
# 90
# Adding  176 --> 128
# Node  175  already present
# 33
# Inserted node  278
# Adding  175 --> 278
# Node  203  already present
# 107
# Node  25  already present
# 120
# Adding  203 --> 25
# Node  265  already present
# 93
# Node  40  already present
# 164
# Adding  265 --> 40
# Node  26  already present
# 19
# Node  252  already present
# 14
# Adding  26 --> 252
# Node  339  already present
# 71
# Inserted node  340
# Adding  339 --> 340
# Node  172  already present
# 28
# Node  232  already present
# 109
# Adding  172 --> 232
# Node  31  already present
# 137
# Inserted node  237
# Adding  31 --> 237
# Inserted node  311
# Node  265  already present
# 93
# Adding  311 --> 265
# Inserted node  309
# Node  135  already present
# 41
# Adding  309 --> 135
# Inserted node  330
# Node  80  already present
# 133
# Adding  330 --> 80
# Inserted node  230
# Inserted node  70
# Adding  230 --> 70
# Node  272  already present
# 21
# Node  159  already present
# 127
# Adding  272 --> 159
# Node  21  already present
# 70
# Node  134  already present
# 63
# Adding  21 --> 134
# Node  24  already present
# 4
# Node  53  already present
# 30
# Adding  24 --> 53
# Node  40  already present
# 164
# Node  332  already present
# 15
# Adding  40 --> 332
# Node  261  already present
# 115
# Inserted node  16
# Adding  261 --> 16
# Node  239  already present
# 27
# Node  223  already present
# 67
# Adding  239 --> 223
# Node  304  already present
# 7
# Inserted node  249
# Adding  304 --> 249
# Node  277  already present
# 62
# Inserted node  39
# Adding  277 --> 39
# Node  224  already present
# 114
# Node  141  already present
# 94
# Adding  224 --> 141
# Node  142  already present
# 106
# Node  345  already present
# 96
# Adding  142 --> 345
# Node  72  already present
# 163
# Node  141  already present
# 94
# Adding  72 --> 141
# Node  313  already present
# 56
# Node  21  already present
# 70
# Adding  313 --> 21
# Node  261  already present
# 115
# Node  271  already present
# 6
# Adding  261 --> 271
# Node  276  already present
# 18
# Node  25  already present
# 120
# Adding  276 --> 25
# Node  109  already present
# 104
# Node  200  already present
# 54
# Adding  109 --> 200
# Node  288  already present
# 48
# Node  25  already present
# 120
# Adding  288 --> 25
# Node  329  already present
# 11
# Node  291  already present
# 105
# Adding  329 --> 291
# Node  194  already present
# 37
# Node  242  already present
# 80
# Adding  194 --> 242
# Node  223  already present
# 67
# Node  203  already present
# 107
# Adding  223 --> 203
# Node  290  already present
# 119
# Node  170  already present
# 32
# Adding  290 --> 170
# Node  261  already present
# 115
# Node  325  already present
# 61
# Adding  261 --> 325
# Node  36  already present
# 66
# Inserted node  251
# Adding  36 --> 251
# Node  291  already present
# 105
# Inserted node  10
# Adding  291 --> 10
# Node  342  already present
# 121
# Node  67  already present
# 59
# Adding  342 --> 67
# Node  21  already present
# 70
# Inserted node  55
# Adding  21 --> 55
# Node  108  already present
# 72
# Node  284  already present
# 146
# Adding  108 --> 284
# Node  3  already present
# 31
# Inserted node  228
# Adding  3 --> 228
# Node  168  already present
# 87
# Node  31  already present
# 137
# Adding  168 --> 31
# Node  67  already present
# 59
# Inserted node  69
# Adding  67 --> 69
# Node  323  already present
# 51
# Node  142  already present
# 106
# Adding  323 --> 142
# Node  261  already present
# 115
# Inserted node  113
# Adding  261 --> 113
# Node  55  already present
# 181
# Node  200  already present
# 54
# Adding  55 --> 200
# Node  13  already present
# 129
# Node  277  already present
# 62
# Adding  13 --> 277
# Node  322  already present
# 29
# Node  25  already present
# 120
# Adding  322 --> 25
# Inserted node  258
# Inserted node  257
# Adding  258 --> 257
# Node  285  already present
# 3
# Node  136  already present
# 138
# Adding  285 --> 136
# Node  80  already present
# 133
# Node  320  already present
# 142
# Adding  80 --> 320
# Node  265  already present
# 93
# Node  98  already present
# 55
# Adding  265 --> 98
# Node  252  already present
# 14
# Node  248  already present
# 112
# Adding  252 --> 248
# Node  62  already present
# 26
# Node  200  already present
# 54
# Adding  62 --> 200
# Node  313  already present
# 56
# Node  54  already present
# 102
# Adding  313 --> 54
# Inserted node  196
# Node  249  already present
# 177
# Adding  196 --> 249
# Node  323  already present
# 51
# Node  85  already present
# 143
# Adding  323 --> 85
# Node  82  already present
# 16
# Node  231  already present
# 38
# Adding  82 --> 231
# Node  141  already present
# 94
# Node  224  already present
# 114
# Adding  141 --> 224
# Node  342  already present
# 121
# Node  119  already present
# 50
# Adding  342 --> 119
# Node  304  already present
# 7
# Node  325  already present
# 61
# Adding  304 --> 325
# Node  136  already present
# 138
# Inserted node  156
# Adding  136 --> 156
# Node  325  already present
# 61
# Node  104  already present
# 153
# Adding  325 --> 104
# Node  211  already present
# 22
# Node  325  already present
# 61
# Adding  211 --> 325
# Node  304  already present
# 7
# Node  158  already present
# 98
# Adding  304 --> 158
# Node  254  already present
# 36
# Node  302  already present
# 100
# Adding  254 --> 302
# Node  92  already present
# 162
# Node  242  already present
# 80
# Adding  92 --> 242
# Node  30  already present
# 160
# Inserted node  303
# Adding  30 --> 303
# Node  274  already present
# 68
# Node  188  already present
# 43
# Adding  274 --> 188
# Node  28  already present
# 78
# Node  310  already present
# 158
# Adding  28 --> 310
# Node  271  already present
# 6
# Node  30  already present
# 160
# Adding  271 --> 30
# Inserted node  286
# Inserted node  81
# Adding  286 --> 81
# Node  144  already present
# 117
# Node  326  already present
# 132
# Adding  144 --> 326
# Node  265  already present
# 93
# Node  56  already present
# 35
# Adding  265 --> 56
# Node  249  already present
# 177
# Node  57  already present
# 53
# Adding  249 --> 57
# Node  341  already present
# 89
# Node  186  already present
# 1
# Adding  341 --> 186
# Inserted node  174
# Inserted node  293
# Adding  174 --> 293
# Inserted node  33
# Inserted node  42
# Adding  33 --> 42
# Node  312  already present
# 79
# Node  28  already present
# 78
# Adding  312 --> 28
# Node  199  already present
# 23
# Node  212  already present
# 167
# Adding  199 --> 212
# Node  9  already present
# 9
# Node  323  already present
# 51
# Adding  9 --> 323
# Node  168  already present
# 87
# Inserted node  347
# Adding  168 --> 347
# Node  67  already present
# 59
# Node  142  already present
# 106
# Adding  67 --> 142
# Node  1  already present
# 125
# Node  53  already present
# 30
# Adding  1 --> 53
# Node  115  already present
# 150
# Inserted node  2
# Adding  115 --> 2
# Node  333  already present
# 85
# Node  2  already present
# 197
# Adding  333 --> 2
# Node  332  already present
# 15
# Node  38  already present
# 99
# Adding  332 --> 38
# Node  291  already present
# 105
# Node  280  already present
# 20
# Adding  291 --> 280
# Node  119  already present
# 50
# Node  54  already present
# 102
# Adding  119 --> 54
# Node  271  already present
# 6
# Node  232  already present
# 109
# Adding  271 --> 232
# Node  135  already present
# 41
# Inserted node  281
# Adding  135 --> 281
# Node  258  already present
# 185
# Node  9  already present
# 9
# Adding  258 --> 9
# Node  285  already present
# 3
# Node  200  already present
# 54
# Adding  285 --> 200
# Node  330  already present
# 173
# Node  94  already present
# 124
# Adding  330 --> 94
# Inserted node  263
# Node  175  already present
# 33
# Adding  263 --> 175
# Node  212  already present
# 167
# Node  304  already present
# 7
# Adding  212 --> 304
# Node  238  already present
# 92
# Node  342  already present
# 121
# Adding  238 --> 342
# Node  284  already present
# 146
# Node  159  already present
# 127
# Adding  284 --> 159
# Node  111  already present
# 156
# Inserted node  279
# Adding  111 --> 279
# Node  141  already present
# 94
# Node  172  already present
# 28
# Adding  141 --> 172
# Node  66  already present
# 136
# Node  21  already present
# 70
# Adding  66 --> 21
# Node  313  already present
# 56
# Node  203  already present
# 107
# Adding  313 --> 203
# Node  84  already present
# 24
# Inserted node  51
# Adding  84 --> 51
# Node  139  already present
# 103
# Node  320  already present
# 142
# Adding  139 --> 320
# Node  25  already present
# 120
# Node  186  already present
# 1
# Adding  25 --> 186
# Node  252  already present
# 14
# Inserted node  338
# Adding  252 --> 338
# Node  200  already present
# 54
# Node  188  already present
# 43
# Adding  200 --> 188
# Node  59  already present
# 130
# Node  342  already present
# 121
# Adding  59 --> 342
# Inserted node  162
# Node  149  already present
# 128
# Adding  162 --> 149
# Node  304  already present
# 7
# Node  322  already present
# 29
# Adding  304 --> 322
# Node  185  already present
# 152
# Node  169  already present
# 74
# Adding  185 --> 169
# Node  252  already present
# 14
# Node  236  already present
# 0
# Adding  252 --> 236
# Node  25  already present
# 120
# Node  290  already present
# 119
# Adding  25 --> 290
# Node  56  already present
# 35
# Node  185  already present
# 152
# Adding  56 --> 185
# Node  158  already present
# 98
# Node  40  already present
# 164
# Adding  158 --> 40
# Node  238  already present
# 92
# Node  222  already present
# 161
# Adding  238 --> 222
# Node  56  already present
# 35
# Node  128  already present
# 90
# Adding  56 --> 128
# Node  199  already present
# 23
# Node  261  already present
# 115
# Adding  199 --> 261
# Node  271  already present
# 6
# Node  203  already present
# 107
# Adding  271 --> 203
# Node  63  already present
# 57
# Node  313  already present
# 56
# Adding  63 --> 313
# Node  62  already present
# 26
# Node  161  already present
# 135
# Adding  62 --> 161
# Node  302  already present
# 100
# Node  57  already present
# 53
# Adding  302 --> 57
# Inserted node  19
# Node  175  already present
# 33
# Adding  19 --> 175
# Node  98  already present
# 55
# Node  172  already present
# 28
# Adding  98 --> 172
# Node  28  already present
# 78
# Node  144  already present
# 117
# Adding  28 --> 144
# Node  249  already present
# 177
# Node  213  already present
# 13
# Adding  249 --> 213
# Node  239  already present
# 27
# Node  252  already present
# 14
# Adding  239 --> 252
# Node  332  already present
# 15
# Node  25  already present
# 120
# Adding  332 --> 25
# Node  265  already present
# 93
# Node  203  already present
# 107
# Adding  265 --> 203
# Node  303  already present
# 189
# Node  104  already present
# 153
# Adding  303 --> 104
# Node  339  already present
# 71
# Node  161  already present
# 135
# Adding  339 --> 161
# Node  119  already present
# 50
# Node  39  already present
# 178
# Adding  119 --> 39
# Node  239  already present
# 27
# Node  211  already present
# 22
# Adding  239 --> 211
# Node  313  already present
# 56
# Node  172  already present
# 28
# Adding  313 --> 172
# Node  200  already present
# 54
# Node  122  already present
# 2
# Adding  200 --> 122
# Node  104  already present
# 153
# Node  303  already present
# 189
# Adding  104 --> 303
# Inserted node  75
# Node  9  already present
# 9
# Adding  75 --> 9
# Node  137  already present
# 148
# Node  312  already present
# 79
# Adding  137 --> 312
# Node  272  already present
# 21
# Node  203  already present
# 107
# Adding  272 --> 203
# Inserted node  218
# Node  78  already present
# 95
# Adding  218 --> 78
# Node  261  already present
# 115
# Inserted node  268
# Adding  261 --> 268
# Inserted node  314
# Node  65  already present
# 17
# Adding  314 --> 65
# Node  57  already present
# 53
# Node  213  already present
# 13
# Adding  57 --> 213
# Node  21  already present
# 70
# Node  56  already present
# 35
# Adding  21 --> 56
# Node  7  already present
# 139
# Node  213  already present
# 13
# Adding  7 --> 213
# Node  139  already present
# 103
# Node  281  already present
# 198
# Adding  139 --> 281
# Inserted node  5
# Node  122  already present
# 2
# Adding  5 --> 122
# Node  55  already present
# 181
# Node  21  already present
# 70
# Adding  55 --> 21
# Node  80  already present
# 133
# Node  24  already present
# 4
# Adding  80 --> 24
# Inserted node  178
# Node  38  already present
# 99
# Adding  178 --> 38
# Node  186  already present
# 1
# Node  109  already present
# 104
# Adding  186 --> 109
# Node  304  already present
# 7
# Node  21  already present
# 70
# Adding  304 --> 21
# Inserted node  192
# Node  49  already present
# 141
# Adding  192 --> 49
# Node  203  already present
# 107
# Node  21  already present
# 70
# Adding  203 --> 21
# Node  285  already present
# 3
# Node  271  already present
# 6
# Adding  285 --> 271
# Node  122  already present
# 2
# Node  248  already present
# 112
# Adding  122 --> 248
# Node  104  already present
# 153
# Node  322  already present
# 29
# Adding  104 --> 322
# Node  312  already present
# 79
# Inserted node  243
# Adding  312 --> 243
# Node  302  already present
# 100
# Node  254  already present
# 36
# Adding  302 --> 254
# Node  236  already present
# 0
# Node  169  already present
# 74
# Adding  236 --> 169
# Node  304  already present
# 7
# Node  324  already present
# 154
# Adding  304 --> 324
# Node  266  already present
# 166
# Node  249  already present
# 177
# Adding  266 --> 249
# Node  3  already present
# 31
# Node  280  already present
# 20
# Adding  3 --> 280
# Node  243  already present
# 212
# Node  312  already present
# 79
# Adding  243 --> 312
# Node  211  already present
# 22
# Node  98  already present
# 55
# Adding  211 --> 98
# Inserted node  195
# Inserted node  181
# Adding  195 --> 181
# Inserted node  8
# Inserted node  245
# Adding  8 --> 245
# Node  297  already present
# 151
# Node  185  already present
# 152
# Adding  297 --> 185
# Node  113  already present
# 184
# Node  104  already present
# 153
# Adding  113 --> 104
# Node  10  already present
# 180
# Node  142  already present
# 106
# Adding  10 --> 142
# Inserted node  129
# Node  7  already present
# 139
# Adding  129 --> 7
# Node  56  already present
# 35
# Node  297  already present
# 151
# Adding  56 --> 297
# Node  248  already present
# 112
# Node  323  already present
# 51
# Adding  248 --> 323
# Node  273  already present
# 76
# Inserted node  328
# Adding  273 --> 328
# Node  115  already present
# 150
# Node  19  already present
# 204
# Adding  115 --> 19
# Node  36  already present
# 66
# Node  309  already present
# 172
# Adding  36 --> 309
# Node  129  already present
# 217
# Node  168  already present
# 87
# Adding  129 --> 168
# Node  242  already present
# 80
# Node  194  already present
# 37
# Adding  242 --> 194
# Node  343  already present
# 149
# Node  2  already present
# 197
# Adding  343 --> 2
# Node  21  already present
# 70
# Node  169  already present
# 74
# Adding  21 --> 169
# Node  226  already present
# 118
# Node  343  already present
# 149
# Adding  226 --> 343
# Node  40  already present
# 164
# Node  200  already present
# 54
# Adding  40 --> 200
# Node  172  already present
# 28
# Inserted node  331
# Adding  172 --> 331
# Node  326  already present
# 132
# Node  343  already present
# 149
# Adding  326 --> 343
# Node  134  already present
# 63
# Node  26  already present
# 19
# Adding  134 --> 26
# Node  332  already present
# 15
# Node  329  already present
# 11
# Adding  332 --> 329
# Node  3  already present
# 31
# Node  200  already present
# 54
# Adding  3 --> 200
# Node  331  already present
# 219
# Node  109  already present
# 104
# Adding  331 --> 109
# Inserted node  150
# Node  128  already present
# 90
# Adding  150 --> 128
# Inserted node  101
# Node  299  already present
# 47
# Adding  101 --> 299
# Node  203  already present
# 107
# Node  59  already present
# 130
# Adding  203 --> 59
# Node  231  already present
# 38
# Node  315  already present
# 49
# Adding  231 --> 315
# Node  265  already present
# 93
# Node  199  already present
# 23
# Adding  265 --> 199
# Inserted node  99
# Inserted node  296
# Adding  99 --> 296
# Node  322  already present
# 29
# Node  290  already present
# 119
# Adding  322 --> 290
# Node  296  already present
# 223
# Inserted node  102
# Adding  296 --> 102
# Node  118  already present
# 60
# Node  261  already present
# 115
# Adding  118 --> 261
# Node  238  already present
# 92
# Node  56  already present
# 35
# Adding  238 --> 56
# Node  117  already present
# 39
# Node  231  already present
# 38
# Adding  117 --> 231
# Node  312  already present
# 79
# Node  149  already present
# 128
# Adding  312 --> 149
# Node  304  already present
# 7
# Node  308  already present
# 88
# Adding  304 --> 308
# Node  105  already present
# 108
# Node  277  already present
# 62
# Adding  105 --> 277
# Node  204  already present
# 12
# Node  196  already present
# 187
# Adding  204 --> 196
# Node  315  already present
# 49
# Node  303  already present
# 189
# Adding  315 --> 303
# Node  284  already present
# 146
# Node  21  already present
# 70
# Adding  284 --> 21
# Node  239  already present
# 27
# Node  21  already present
# 70
# Adding  239 --> 21
# Node  312  already present
# 79
# Node  326  already present
# 132
# Adding  312 --> 326
# Node  277  already present
# 62
# Node  161  already present
# 135
# Adding  277 --> 161
# Node  340  already present
# 169
# Node  213  already present
# 13
# Adding  340 --> 213
# Node  98  already present
# 55
# Node  223  already present
# 67
# Adding  98 --> 223
# Node  172  already present
# 28
# Node  277  already present
# 62
# Adding  172 --> 277
# Node  128  already present
# 90
# Node  104  already present
# 153
# Adding  128 --> 104
# Node  313  already present
# 56
# Node  222  already present
# 161
# Adding  313 --> 222
# Node  98  already present
# 55
# Node  331  already present
# 219
# Adding  98 --> 331
# Node  299  already present
# 47
# Node  194  already present
# 37
# Adding  299 --> 194
# Node  122  already present
# 2
# Node  141  already present
# 94
# Adding  122 --> 141
# Node  324  already present
# 154
# Node  217  already present
# 111
# Adding  324 --> 217
# Node  291  already present
# 105
# Node  25  already present
# 120
# Adding  291 --> 25
# Node  13  already present
# 129
# Node  188  already present
# 43
# Adding  13 --> 188
# Node  104  already present
# 153
# Inserted node  318
# Adding  104 --> 318
# Node  261  already present
# 115
# Node  65  already present
# 17
# Adding  261 --> 65
# Node  265  already present
# 93
# Node  128  already present
# 90
# Adding  265 --> 128
# Inserted node  163
# Inserted node  173
# Adding  163 --> 173
# Node  116  already present
# 45
# Node  14  already present
# 157
# Adding  116 --> 14
# Node  92  already present
# 162
# Node  1  already present
# 125
# Adding  92 --> 1
# Node  26  already present
# 19
# Node  3  already present
# 31
# Adding  26 --> 3
# Inserted node  165
# Inserted node  121
# Adding  165 --> 121
# Node  3  already present
# 31
# Node  25  already present
# 120
# Adding  3 --> 25
# Node  149  already present
# 128
# Node  226  already present
# 118
# Adding  149 --> 226
# Node  328  already present
# 218
# Inserted node  306
# Adding  328 --> 306
# Node  172  already present
# 28
# Node  141  already present
# 94
# Adding  172 --> 141
# Node  303  already present
# 189
# Node  315  already present
# 49
# Adding  303 --> 315
# Node  56  already present
# 35
# Node  239  already present
# 27
# Adding  56 --> 239
# Node  122  already present
# 2
# Node  274  already present
# 68
# Adding  122 --> 274
# Node  46  already present
# 34
# Inserted node  177
# Adding  46 --> 177
# Node  249  already present
# 177
# Inserted node  180
# Adding  249 --> 180
# Node  73  already present
# 46
# Node  1  already present
# 125
# Adding  73 --> 1
# Node  272  already present
# 21
# Node  346  already present
# 5
# Adding  272 --> 346
# Node  53  already present
# 30
# Node  48  already present
# 52
# Adding  53 --> 48
# Node  199  already present
# 23
# Node  119  already present
# 50
# Adding  199 --> 119
# Node  248  already present
# 112
# Node  38  already present
# 99
# Adding  248 --> 38
# Node  24  already present
# 4
# Node  187  already present
# 134
# Adding  24 --> 187
# Node  196  already present
# 187
# Node  67  already present
# 59
# Adding  196 --> 67
# Node  304  already present
# 7
# Node  172  already present
# 28
# Adding  304 --> 172
# Inserted node  87
# Node  136  already present
# 138
# Adding  87 --> 136
# Node  323  already present
# 51
# Node  141  already present
# 94
# Adding  323 --> 141
# Node  323  already present
# 51
# Node  62  already present
# 26
# Adding  323 --> 62
# Inserted node  189
# Node  217  already present
# 111
# Adding  189 --> 217
# Node  280  already present
# 20
# Node  236  already present
# 0
# Adding  280 --> 236
# Node  115  already present
# 150
# Node  137  already present
# 148
# Adding  115 --> 137
# Node  25  already present
# 120
# Node  276  already present
# 18
# Adding  25 --> 276
# Node  186  already present
# 1
# Node  55  already present
# 181
# Adding  186 --> 55
# Node  30  already present
# 160
# Node  56  already present
# 35
# Adding  30 --> 56
# Inserted node  60
# Node  285  already present
# 3
# Adding  60 --> 285
# Node  197  already present
# 73
# Node  127  already present
# 40
# Adding  197 --> 127
# Node  334  already present
# 91
# Node  26  already present
# 19
# Adding  334 --> 26
# Node  304  already present
# 7
# Node  170  already present
# 32
# Adding  304 --> 170
# Inserted node  259
# Node  8  already present
# 215
# Adding  259 --> 8
# Node  346  already present
# 5
# Node  184  already present
# 126
# Adding  346 --> 184
# Node  186  already present
# 1
# Node  199  already present
# 23
# Adding  186 --> 199
# Node  200  already present
# 54
# Node  39  already present
# 178
# Adding  200 --> 39
# Node  185  already present
# 152
# Node  344  already present
# 58
# Adding  185 --> 344
# Node  184  already present
# 126
# Node  329  already present
# 11
# Adding  184 --> 329
# Node  149  already present
# 128
# Node  162  already present
# 203
# Adding  149 --> 162
# Node  285  already present
# 3
# Node  213  already present
# 13
# Adding  285 --> 213
# Node  185  already present
# 152
# Node  290  already present
# 119
# Adding  185 --> 290
# Node  13  already present
# 129
# Node  261  already present
# 115
# Adding  13 --> 261
# Node  204  already present
# 12
# Node  5  already present
# 209
# Adding  204 --> 5
# Node  109  already present
# 104
# Node  26  already present
# 19
# Adding  109 --> 26
# Node  169  already present
# 74
# Node  40  already present
# 164
# Adding  169 --> 40
# Node  194  already present
# 37
# Node  196  already present
# 187
# Adding  194 --> 196
# Node  85  already present
# 143
# Node  156  already present
# 188
# Adding  85 --> 156
# Node  67  already present
# 59
# Node  55  already present
# 181
# Adding  67 --> 55
# Node  98  already present
# 55
# Node  285  already present
# 3
# Adding  98 --> 285
# Node  123  already present
# 145
# Node  342  already present
# 121
# Adding  123 --> 342
# Node  118  already present
# 60
# Node  283  already present
# 116
# Adding  118 --> 283
# Inserted node  45
# Node  67  already present
# 59
# Adding  45 --> 67
# Node  80  already present
# 133
# Node  48  already present
# 52
# Adding  80 --> 48
# Node  162  already present
# 203
# Node  343  already present
# 149
# Adding  162 --> 343
# Node  272  already present
# 21
# Node  21  already present
# 70
# Adding  272 --> 21
# Node  271  already present
# 6
# Node  133  already present
# 25
# Adding  271 --> 133
# Node  67  already present
# 59
# Node  297  already present
# 151
# Adding  67 --> 297
# Node  13  already present
# 129
# Node  118  already present
# 60
# Adding  13 --> 118
# Node  115  already present
# 150
# Node  28  already present
# 78
# Adding  115 --> 28
# Node  230  already present
# 174
# Node  23  already present
# 44
# Adding  230 --> 23
# Inserted node  58
# Inserted node  269
# Adding  58 --> 269
# Node  46  already present
# 34
# Node  175  already present
# 33
# Adding  46 --> 175
# Node  25  already present
# 120
# Node  169  already present
# 74
# Adding  25 --> 169
# Node  80  already present
# 133
# Node  57  already present
# 53
# Adding  80 --> 57
# Node  135  already present
# 41
# Node  197  already present
# 73
# Adding  135 --> 197
# Node  203  already present
# 107
# Node  161  already present
# 135
# Adding  203 --> 161
# Node  113  already present
# 184
# Node  261  already present
# 115
# Adding  113 --> 261
# Node  116  already present
# 45
# Node  23  already present
# 44
# Adding  116 --> 23
# Node  275  already present
# 75
# Node  218  already present
# 206
# Adding  275 --> 218
# Node  285  already present
# 3
# Node  170  already present
# 32
# Adding  285 --> 170
# Node  314  already present
# 208
# Node  199  already present
# 23
# Adding  314 --> 199
# Node  279  already present
# 200
# Node  111  already present
# 156
# Adding  279 --> 111
# Node  126  already present
# 113
# Node  48  already present
# 52
# Adding  126 --> 48
# Node  36  already present
# 66
# Node  320  already present
# 142
# Adding  36 --> 320
# Node  137  already present
# 148
# Inserted node  167
# Adding  137 --> 167
# Node  140  already present
# 147
# Node  326  already present
# 132
# Adding  140 --> 326
# Node  130  already present
# 10
# Node  48  already present
# 52
# Adding  130 --> 48
# Node  302  already present
# 100
# Node  94  already present
# 124
# Adding  302 --> 94
# Node  315  already present
# 49
# Node  80  already present
# 133
# Adding  315 --> 80
# Node  101  already present
# 221
# Node  80  already present
# 133
# Adding  101 --> 80
# Node  23  already present
# 44
# Inserted node  227
# Adding  23 --> 227
# Node  92  already present
# 162
# Node  194  already present
# 37
# Adding  92 --> 194
# Node  2  already present
# 197
# Node  20  already present
# 82
# Adding  2 --> 20
# Node  72  already present
# 163
# Node  252  already present
# 14
# Adding  72 --> 252
# Node  323  already present
# 51
# Inserted node  96
# Adding  323 --> 96
# Inserted node  91
# Node  8  already present
# 215
# Adding  91 --> 8
# Inserted node  143
# Node  177  already present
# 231
# Adding  143 --> 177
# Node  200  already present
# 54
# Node  30  already present
# 160
# Adding  200 --> 30
# Node  257  already present
# 186
# Node  26  already present
# 19
# Adding  257 --> 26
# Node  331  already present
# 219
# Node  324  already present
# 154
# Adding  331 --> 324
# Node  142  already present
# 106
# Node  322  already present
# 29
# Adding  142 --> 322
# Node  188  already present
# 43
# Node  104  already present
# 153
# Adding  188 --> 104
# Node  239  already present
# 27
# Node  276  already present
# 18
# Adding  239 --> 276
# Node  23  already present
# 44
# Inserted node  61
# Adding  23 --> 61
# Node  325  already present
# 61
# Node  21  already present
# 70
# Adding  325 --> 21
# Node  204  already present
# 12
# Node  94  already present
# 124
# Adding  204 --> 94
# Node  346  already present
# 5
# Node  194  already present
# 37
# Adding  346 --> 194
# Node  223  already present
# 67
# Node  186  already present
# 1
# Adding  223 --> 186
# Node  56  already present
# 35
# Node  252  already present
# 14
# Adding  56 --> 252
# Node  113  already present
# 184
# Node  142  already present
# 106
# Adding  113 --> 142
# Node  26  already present
# 19
# Node  21  already present
# 70
# Adding  26 --> 21
# Node  285  already present
# 3
# Node  323  already present
# 51
# Adding  285 --> 323
# Node  290  already present
# 119
# Node  176  already present
# 8
# Adding  290 --> 176
# Inserted node  93
# Node  167  already present
# 240
# Adding  93 --> 167
# Node  276  already present
# 18
# Node  122  already present
# 2
# Adding  276 --> 122
# Node  96  already present
# 242
# Node  133  already present
# 25
# Adding  96 --> 133
# Inserted node  41
# Node  243  already present
# 212
# Adding  41 --> 243
# Node  188  already present
# 43
# Node  304  already present
# 7
# Adding  188 --> 304
# Node  203  already present
# 107
# Node  313  already present
# 56
# Adding  203 --> 313
# Node  200  already present
# 54
# Node  170  already present
# 32
# Adding  200 --> 170
# Node  232  already present
# 109
# Node  200  already present
# 54
# Adding  232 --> 200
# Inserted node  235
# Node  5  already present
# 209
# Adding  235 --> 5
# Inserted node  6
# Inserted node  89
# Adding  6 --> 89
# Node  171  already present
# 155
# Inserted node  107
# Adding  171 --> 107
# Node  257  already present
# 186
# Node  169  already present
# 74
# Adding  257 --> 169
# Node  224  already present
# 114
# Node  232  already present
# 109
# Adding  224 --> 232
# Node  271  already present
# 6
# Inserted node  79
# Adding  271 --> 79
# Node  187  already present
# 134
# Node  24  already present
# 4
# Adding  187 --> 24
# Node  141  already present
# 94
# Node  67  already present
# 59
# Adding  141 --> 67
# Node  113  already present
# 184
# Node  66  already present
# 136
# Adding  113 --> 66
# Node  56  already present
# 35
# Node  103  already present
# 42
# Adding  56 --> 103
# Node  59  already present
# 130
# Node  271  already present
# 6
# Adding  59 --> 271
# Node  40  already present
# 164
# Node  213  already present
# 13
# Adding  40 --> 213
# Node  158  already present
# 98
# Node  26  already present
# 19
# Adding  158 --> 26
# Node  211  already present
# 22
# Node  82  already present
# 16
# Adding  211 --> 82
# Node  285  already present
# 3
# Inserted node  208
# Adding  285 --> 208
# Node  119  already present
# 50
# Node  285  already present
# 3
# Adding  119 --> 285
# Node  26  already present
# 19
# Node  9  already present
# 9
# Adding  26 --> 9
# Node  40  already present
# 164
# Node  133  already present
# 25
# Adding  40 --> 133
# Node  143  already present
# 244
# Node  175  already present
# 33
# Adding  143 --> 175
# Node  56  already present
# 35
# Inserted node  132
# Adding  56 --> 132
# Node  45  already present
# 237
# Inserted node  221
# Adding  45 --> 221
# Node  212  already present
# 167
# Node  344  already present
# 58
# Adding  212 --> 344
# Node  285  already present
# 3
# Node  315  already present
# 49
# Adding  285 --> 315
# Inserted node  301
# Node  324  already present
# 154
# Adding  301 --> 324
# Node  21  already present
# 70
# Node  170  already present
# 32
# Adding  21 --> 170
# Node  326  already present
# 132
# Node  214  already present
# 81
# Adding  326 --> 214
# Node  281  already present
# 198
# Node  159  already present
# 127
# Adding  281 --> 159
# Node  281  already present
# 198
# Node  251  already present
# 179
# Adding  281 --> 251
# Node  109  already present
# 104
# Node  67  already present
# 59
# Adding  109 --> 67
# Node  25  already present
# 120
# Node  232  already present
# 109
# Adding  25 --> 232
# Node  59  already present
# 130
# Node  56  already present
# 35
# Adding  59 --> 56
# Node  92  already present
# 162
# Node  180  already present
# 232
# Adding  92 --> 180
# Node  122  already present
# 2
# Node  284  already present
# 146
# Adding  122 --> 284
# Node  322  already present
# 29
# Node  48  already present
# 52
# Adding  322 --> 48
# Node  277  already present
# 62
# Node  308  already present
# 88
# Adding  277 --> 308
# Node  290  already present
# 119
# Node  323  already present
# 51
# Adding  290 --> 323
# Node  167  already present
# 240
# Node  93  already present
# 246
# Adding  167 --> 93
# Inserted node  250
# Node  59  already present
# 130
# Adding  250 --> 59
# Inserted node  106
# Inserted node  29
# Adding  106 --> 29
# Node  274  already present
# 68
# Node  341  already present
# 89
# Adding  274 --> 341
# Node  249  already present
# 177
# Node  302  already present
# 100
# Adding  249 --> 302
# Node  118  already present
# 60
# Node  239  already present
# 27
# Adding  118 --> 239
# Node  111  already present
# 156
# Inserted node  337
# Adding  111 --> 337
# Node  252  already present
# 14
# Node  109  already present
# 104
# Adding  252 --> 109
# Node  56  already present
# 35
# Node  55  already present
# 181
# Adding  56 --> 55
# Node  80  already present
# 133
# Node  266  already present
# 166
# Adding  80 --> 266
# Node  252  already present
# 14
# Node  134  already present
# 63
# Adding  252 --> 134
# Node  104  already present
# 153
# Node  67  already present
# 59
# Adding  104 --> 67
# Node  94  already present
# 124
# Node  346  already present
# 5
# Adding  94 --> 346
# Node  141  already present
# 94
# Node  280  already present
# 20
# Adding  141 --> 280
# Node  325  already present
# 61
# Node  161  already present
# 135
# Adding  325 --> 161
# Node  322  already present
# 29
# Node  203  already present
# 107
# Adding  322 --> 203
# Node  96  already present
# 242
# Node  274  already present
# 68
# Adding  96 --> 274
# Node  158  already present
# 98
# Node  315  already present
# 49
# Adding  158 --> 315
# Node  199  already present
# 23
# Node  98  already present
# 55
# Adding  199 --> 98
# Node  134  already present
# 63
# Node  132  already present
# 254
# Adding  134 --> 132
# Node  280  already present
# 20
# Node  98  already present
# 55
# Adding  280 --> 98
# Node  254  already present
# 36
# Node  187  already present
# 134
# Adding  254 --> 187
# Node  329  already present
# 11
# Node  269  already present
# 239
# Adding  329 --> 269
# Node  297  already present
# 151
# Node  21  already present
# 70
# Adding  297 --> 21
# Inserted node  100
# Node  150  already present
# 220
# Adding  100 --> 150
# Inserted node  110
# Inserted node  264
# Adding  110 --> 264
# Node  266  already present
# 166
# Node  330  already present
# 173
# Adding  266 --> 330
# Node  171  already present
# 155
# Node  150  already present
# 220
# Adding  171 --> 150
# Node  322  already present
# 29
# Node  45  already present
# 237
# Adding  322 --> 45
# Node  72  already present
# 163
# Node  165  already present
# 228
# Adding  72 --> 165
# Node  344  already present
# 58
# Node  257  already present
# 186
# Adding  344 --> 257
# Node  184  already present
# 126
# Node  21  already present
# 70
# Adding  184 --> 21
# Node  119  already present
# 50
# Node  332  already present
# 15
# Adding  119 --> 332
# Node  257  already present
# 186
# Node  236  already present
# 0
# Adding  257 --> 236
# Node  277  already present
# 62
# Node  324  already present
# 154
# Adding  277 --> 324
# Node  332  already present
# 15
# Node  248  already present
# 112
# Adding  332 --> 248
# Node  329  already present
# 11
# Node  119  already present
# 50
# Adding  329 --> 119
# Inserted node  225
# Inserted node  86
# Adding  225 --> 86
# Node  232  already present
# 109
# Node  56  already present
# 35
# Adding  232 --> 56
# Node  291  already present
# 105
# Node  224  already present
# 114
# Adding  291 --> 224
# Node  53  already present
# 30
# Node  196  already present
# 187
# Adding  53 --> 196
# Node  315  already present
# 49
# Node  213  already present
# 13
# Adding  315 --> 213
# Node  322  already present
# 29
# Node  136  already present
# 138
# Adding  322 --> 136
# Node  181  already present
# 214
# Inserted node  152
# Adding  181 --> 152
# Node  141  already present
# 94
# Node  257  already present
# 186
# Adding  141 --> 257
# Node  180  already present
# 232
# Node  80  already present
# 133
# Adding  180 --> 80
# Node  26  already present
# 19
# Node  199  already present
# 23
# Adding  26 --> 199
# Node  45  already present
# 237
# Node  104  already present
# 153
# Adding  45 --> 104
# Node  332  already present
# 15
# Node  67  already present
# 59
# Adding  332 --> 67
# Node  303  already present
# 189
# Node  45  already present
# 237
# Adding  303 --> 45
# Node  250  already present
# 257
# Node  252  already present
# 14
# Adding  250 --> 252
# Node  3  already present
# 31
# Node  26  already present
# 19
# Adding  3 --> 26
# Node  98  already present
# 55
# Inserted node  148
# Adding  98 --> 148
# Node  185  already present
# 152
# Node  55  already present
# 181
# Adding  185 --> 55
# Node  172  already present
# 28
# Node  239  already present
# 27
# Adding  172 --> 239
# Inserted node  295
# Node  239  already present
# 27
# Adding  295 --> 239
# Node  325  already present
# 61
# Node  98  already present
# 55
# Adding  325 --> 98
# Node  252  already present
# 14
# Node  113  already present
# 184
# Adding  252 --> 113
# Node  323  already present
# 51
# Node  119  already present
# 50
# Adding  323 --> 119
# Node  188  already present
# 43
# Node  315  already present
# 49
# Adding  188 --> 315
# Node  55  already present
# 181
# Node  203  already present
# 107
# Adding  55 --> 203
# Node  137  already present
# 148
# Node  111  already present
# 156
# Adding  137 --> 111
# Node  224  already present
# 114
# Node  200  already present
# 54
# Adding  224 --> 200
# Node  194  already present
# 37
# Node  80  already present
# 133
# Adding  194 --> 80
# Node  295  already present
# 268
# Node  104  already present
# 153
# Adding  295 --> 104
# Node  17  already present
# 131
# Node  140  already present
# 147
# Adding  17 --> 140
# Node  266  already present
# 166
# Node  302  already present
# 100
# Adding  266 --> 302
# Node  232  already present
# 109
# Node  212  already present
# 167
# Adding  232 --> 212
# Node  249  already present
# 177
# Node  24  already present
# 4
# Adding  249 --> 24
# Node  200  already present
# 54
# Node  323  already present
# 51
# Adding  200 --> 323
# Node  323  already present
# 51
# Node  122  already present
# 2
# Adding  323 --> 122
# Node  203  already present
# 107
# Node  65  already present
# 17
# Adding  203 --> 65
# Node  259  already present
# 236
# Inserted node  201
# Adding  259 --> 201
# Node  161  already present
# 135
# Node  56  already present
# 35
# Adding  161 --> 56
# Node  119  already present
# 50
# Node  252  already present
# 14
# Adding  119 --> 252
# Node  238  already present
# 92
# Node  82  already present
# 16
# Adding  238 --> 82
# Node  197  already present
# 73
# Node  251  already present
# 179
# Adding  197 --> 251
# Node  105  already present
# 108
# Node  272  already present
# 21
# Adding  105 --> 272
# Node  291  already present
# 105
# ...
# r= 94
# len of es= 987
# r= 605
# len of es= 986
# r= 625
# len of es= 985
# r= 497
# len of es= 984
# r= 332
# len of es= 983
# r= 189
# len of es= 982
# r= 852
# len of es= 981
# r= 131
# len of es= 980
# r= 948
# len of es= 979
# r= 754
# len of es= 978
# r= 154
# len of es= 977
# r= 910
# len of es= 976
# r= 918
# len of es= 975
# r= 97
# len of es= 974
# r= 837
# len of es= 973
# r= 790
# len of es= 972
# r= 271
# len of es= 971
# r= 264
# len of es= 970
# r= 671
# len of es= 969
# r= 319
# len of es= 968
# r= 179
# len of es= 967
# r= 475
# len of es= 966
# r= 683
# len of es= 965
# r= 883
# len of es= 964
# r= 366
# len of es= 963
# r= 625
# len of es= 962
# r= 739
# len of es= 961
# r= 590
# len of es= 960
# r= 671
# len of es= 959
# r= 615
# len of es= 958
# r= 74
# len of es= 957
# r= 141
# len of es= 956
# r= 908
# len of es= 955
# r= 654
# len of es= 954
# r= 275
# len of es= 953
# r= 931
# len of es= 952
# r= 68
# len of es= 951
# r= 383
# len of es= 950
# r= 811
# len of es= 949
# r= 265
# len of es= 948
# r= 66
# len of es= 947
# r= 370
# len of es= 946
# r= 148
# len of es= 945
# r= 677
# len of es= 944
# r= 606
# len of es= 943
# r= 723
# len of es= 942
# r= 698
# len of es= 941
# r= 40
# len of es= 940
# r= 856
# len of es= 939
# r= 415
# len of es= 938
# r= 128
# len of es= 937
# r= 561
# len of es= 936
# r= 884
# len of es= 935
# r= 480
# len of es= 934
# r= 566
# len of es= 933
# r= 710
# len of es= 932
# r= 755
# len of es= 931
# r= 41
# len of es= 930
# r= 219
# len of es= 929
# r= 177
# len of es= 928
# r= 477
# len of es= 927
# r= 149
# len of es= 926
# r= 171
# len of es= 925
# r= 204
# len of es= 924
# r= 614
# len of es= 923
# r= 280
# len of es= 922
# r= 702
# len of es= 921
# r= 337
# len of es= 920
# r= 571
# len of es= 919
# r= 882
# len of es= 918
# r= 3
# len of es= 917
# r= 594
# len of es= 916
# r= 641
# len of es= 915
# r= 48
# len of es= 914
# r= 573
# len of es= 913
# r= 237
# len of es= 912
# r= 419
# len of es= 911
# r= 845
# len of es= 910
# r= 346
# len of es= 909
# r= 711
# len of es= 908
# r= 457
# len of es= 907
# r= 801
# len of es= 906
# r= 543
# len of es= 905
# r= 821
# len of es= 904
# r= 108
# len of es= 903
# r= 859
# len of es= 902
# r= 282
# len of es= 901
# r= 113
# len of es= 900
# r= 283
# len of es= 899
# r= 345
# len of es= 898
# r= 10
# len of es= 897
# r= 694
# len of es= 896
# r= 99
# len of es= 895
# r= 231
# len of es= 894
# r= 891
# len of es= 893
# r= 728
# len of es= 892
# r= 54
# len of es= 891
# r= 212
# len of es= 890
# r= 782
# len of es= 889
# r= 687
# len of es= 888
# r= 475
# len of es= 887
# r= 256
# len of es= 886
# r= 674
# len of es= 885
# r= 450
# len of es= 884
# r= 146
# len of es= 883
# r= 704
# len of es= 882
# r= 596
# len of es= 881
# r= 672
# len of es= 880
# r= 387
# len of es= 879
# r= 630
# len of es= 878
# r= 410
# len of es= 877
# r= 74
# len of es= 876
# r= 254
# len of es= 875
# r= 652
# len of es= 874
# r= 828
# len of es= 873
# r= 54
# len of es= 872
# r= 77
# len of es= 871
# r= 870
# len of es= 870
# r= 104
# len of es= 869
# r= 762
# len of es= 868
# r= 748
# len of es= 867
# r= 314
# len of es= 866
# r= 104
# len of es= 865
# r= 840
# len of es= 864
# r= 467
# len of es= 863
# r= 304
# len of es= 862
# r= 295
# len of es= 861
# r= 755
# len of es= 860
# r= 117
# len of es= 859
# r= 684
# len of es= 858
# r= 45
# len of es= 857
# r= 377
# len of es= 856
# r= 560
# len of es= 855
# r= 126
# len of es= 854
# r= 851
# len of es= 853
# r= 823
# len of es= 852
# r= 593
# len of es= 851
# r= 489
# len of es= 850
# r= 368
# len of es= 849
# r= 81
# len of es= 848
# r= 523
# len of es= 847
# r= 505
# len of es= 846
# r= 33
# len of es= 845
# r= 292
# len of es= 844
# r= 485
# len of es= 843
# r= 54
# len of es= 842
# r= 470
# len of es= 841
# r= 124
# len of es= 840
# r= 714
# len of es= 839
# r= 65
# len of es= 838
# r= 161
# len of es= 837
# r= 9
# len of es= 836
# r= 370
# len of es= 835
# r= 592
# len of es= 834
# r= 518
# len of es= 833
# r= 406
# len of es= 832
# r= 482
# len of es= 831
# r= 65
# len of es= 830
# r= 728
# len of es= 829
# r= 417
# len of es= 828
# r= 210
# len of es= 827
# r= 161
# len of es= 826
# r= 192
# len of es= 825
# r= 730
# len of es= 824
# r= 714
# len of es= 823
# r= 815
# len of es= 822
# r= 273
# len of es= 821
# r= 807
# len of es= 820
# r= 499
# len of es= 819
# r= 249
# len of es= 818
# r= 244
# len of es= 817
# r= 162
# len of es= 816
# r= 283
# len of es= 815
# r= 107
# len of es= 814
# r= 661
# len of es= 813
# r= 173
# len of es= 812
# r= 388
# len of es= 811
# r= 677
# len of es= 810
# r= 340
# len of es= 809
# r= 12
# len of es= 808
# r= 689
# len of es= 807
# r= 307
# len of es= 806
# r= 43
# len of es= 805
# r= 439
# len of es= 804
# r= 396
# len of es= 803
# r= 73
# len of es= 802
# r= 344
# len of es= 801
# r= 325
# len of es= 800
# r= 114
# len of es= 799
# r= 451
# len of es= 798
# r= 657
# len of es= 797
# r= 182
# len of es= 796
# r= 404
# len of es= 795
# r= 514
# len of es= 794
# r= 707
# len of es= 793
# r= 719
# len of es= 792
# r= 29
# len of es= 791
# r= 187
# len of es= 790
# r= 531
# len of es= 789
# r= 384
# len of es= 788
# r= 569
# len of es= 787
# r= 137
# len of es= 786
# r= 565
# len of es= 785
# r= 420
# len of es= 784
# r= 54
# len of es= 783
# r= 776
# len of es= 782
# r= 318
# len of es= 781
# r= 213
# len of es= 780
# r= 775
# len of es= 779
# r= 230
# len of es= 778
# r= 459
# len of es= 777
# r= 387
# len of es= 776
# r= 583
# len of es= 775
# r= 219
# len of es= 774
# r= 222
# len of es= 773
# r= 195
# len of es= 772
# r= 610
# len of es= 771
# r= 397
# len of es= 770
# r= 718
# len of es= 769
# r= 764
# len of es= 768
# r= 412
# len of es= 767
# r= 420
# len of es= 766
# r= 450
# len of es= 765
# r= 5
# len of es= 764
# r= 521
# len of es= 763
# r= 63
# len of es= 762
# r= 203
# len of es= 761
# r= 185
# len of es= 760
# r= 333
# len of es= 759
# r= 175
# len of es= 758
# r= 49
# len of es= 757
# r= 26
# len of es= 756
# r= 583
# len of es= 755
# r= 114
# len of es= 754
# r= 100
# len of es= 753
# r= 376
# len of es= 752
# r= 4
# len of es= 751
# r= 282
# len of es= 750
# r= 580
# len of es= 749
# r= 544
# len of es= 748
# r= 39
# len of es= 747
# r= 86
# len of es= 746
# r= 520
# len of es= 745
# r= 603
# len of es= 744
# r= 395
# len of es= 743
# r= 606
# len of es= 742
# r= 198
# len of es= 741
# r= 681
# len of es= 740
# r= 584
# len of es= 739
# r= 651
# len of es= 738
# r= 527
# len of es= 737
# r= 672
# len of es= 736
# r= 221
# len of es= 735
# r= 371
# len of es= 734
# r= 233
# len of es= 733
# r= 293
# len of es= 732
# r= 393
# len of es= 731
# r= 704
# len of es= 730
# r= 164
# len of es= 729
# r= 547
# len of es= 728
# r= 140
# len of es= 727
# r= 146
# len of es= 726
# r= 138
# len of es= 725
# r= 38
# len of es= 724
# r= 36
# len of es= 723
# r= 255
# len of es= 722
# r= 212
# len of es= 721
# r= 283
# len of es= 720
# r= 443
# len of es= 719
# r= 307
# len of es= 718
# r= 608
# len of es= 717
# r= 701
# len of es= 716
# r= 99
# len of es= 715
# r= 514
# len of es= 714
# r= 628
# len of es= 713
# r= 520
# len of es= 712
# r= 237
# len of es= 711
# r= 692
# len of es= 710
# r= 342
# len of es= 709
# r= 304
# len of es= 708
# r= 86
# len of es= 707
# r= 211
# len of es= 706
# r= 61
# len of es= 705
# r= 680
# len of es= 704
# r= 366
# len of es= 703
# r= 552
# len of es= 702
# r= 504
# len of es= 701
# r= 640
# len of es= 700
# r= 427
# len of es= 699
# r= 111
# len of es= 698
# r= 5
# len of es= 697
# r= 248
# len of es= 696
# r= 140
# len of es= 695
# r= 268
# len of es= 694
# r= 299
# len of es= 693
# r= 110
# len of es= 692
# r= 465
# len of es= 691
# r= 222
# len of es= 690
# r= 477
# len of es= 689
# r= 221
# len of es= 688
# r= 6
# len of es= 687
# r= 491
# len of es= 686
# r= 325
# len of es= 685
# r= 451
# len of es= 684
# r= 4
# len of es= 683
# r= 606
# len of es= 682
# r= 581
# len of es= 681
# r= 357
# len of es= 680
# r= 630
# len of es= 679
# r= 656
# len of es= 678
# r= 51
# len of es= 677
# r= 216
# len of es= 676
# r= 265
# len of es= 675
# r= 496
# len of es= 674
# r= 573
# len of es= 673
# r= 553
# len of es= 672
# r= 563
# len of es= 671
# r= 445
# len of es= 670
# r= 284
# len of es= 669
# r= 114
# len of es= 668
# r= 438
# len of es= 667
# r= 121
# len of es= 666
# r= 280
# len of es= 665
# r= 603
# len of es= 664
# r= 542
# len of es= 663
# r= 387
# len of es= 662
# r= 389
# len of es= 661
# r= 80
# len of es= 660
# r= 151
# len of es= 659
# r= 38
# len of es= 658
# r= 466
# len of es= 657
# r= 136
# len of es= 656
# r= 639
# len of es= 655
# r= 80
# len of es= 654
# r= 15
# len of es= 653
# r= 519
# len of es= 652
# r= 199
# len of es= 651
# r= 579
# len of es= 650
# r= 616
# len of es= 649
# r= 18
# len of es= 648
# r= 197
# len of es= 647
# r= 134
# len of es= 646
# r= 639
# len of es= 645
# r= 7
# len of es= 644
# r= 510
# len of es= 643
# r= 441
# len of es= 642
# r= 401
# len of es= 641
# r= 501
# len of es= 640
# r= 591
# len of es= 639
# r= 539
# len of es= 638
# r= 613
# len of es= 637
# r= 256
# len of es= 636
# r= 298
# len of es= 635
# r= 527
# len of es= 634
# r= 532
# len of es= 633
# r= 220
# len of es= 632
# r= 590
# len of es= 631
# len of es= 631
# r= 335
# len of es= 630
# r= 346
# len of es= 629
# r= 576
# len of es= 628
# r= 447
# len of es= 627
# r= 619
# len of es= 626
# r= 377
# len of es= 625
# r= 380
# len of es= 624
# r= 205
# len of es= 623
# r= 138
# len of es= 622
# r= 25
# len of es= 621
# r= 375
# len of es= 620
# r= 175
# len of es= 619
# r= 142
# len of es= 618
# r= 94
# len of es= 617
# r= 78
# len of es= 616
# r= 104
# len of es= 615
# r= 110
# len of es= 614
# r= 157
# len of es= 613
# r= 257
# len of es= 612
# r= 104
# len of es= 611
# r= 600
# len of es= 610
# r= 62
# len of es= 609
# r= 108
# len of es= 608
# r= 331
# len of es= 607
# r= 418
# len of es= 606
# r= 218
# len of es= 605
# r= 353
# len of es= 604
# r= 124
# len of es= 603
# r= 501
# len of es= 602
# r= 551
# len of es= 601
# r= 317
# len of es= 600
# r= 318
# len of es= 599
# r= 223
# len of es= 598
# r= 122
# len of es= 597
# r= 21
# len of es= 596
# r= 568
# len of es= 595
# r= 522
# len of es= 594
# r= 308
# len of es= 593
# r= 322
# len of es= 592
# r= 448
# len of es= 591
# r= 112
# len of es= 590
# r= 194
# len of es= 589
# r= 186
# len of es= 588
# r= 540
# len of es= 587
# r= 267
# len of es= 586
# r= 199
# len of es= 585
# r= 410
# len of es= 584
# r= 245
# len of es= 583
# r= 0
# len of es= 582
# r= 556
# len of es= 581
# r= 98
# len of es= 580
# r= 525
# len of es= 579
# r= 173
# len of es= 578
# r= 87
# len of es= 577
# r= 438
# len of es= 576
# r= 417
# len of es= 575
# r= 490
# len of es= 574
# r= 267
# len of es= 573
# r= 281
# len of es= 572
# r= 154
# len of es= 571
# r= 17
# len of es= 570
# r= 224
# len of es= 569
# r= 380
# len of es= 568
# r= 338
# len of es= 567
# r= 413
# len of es= 566
# r= 301
# len of es= 565
# r= 35
# len of es= 564
# r= 466
# len of es= 563
# r= 488
# len of es= 562
# r= 438
# len of es= 561
# r= 340
# len of es= 560
# r= 43
# len of es= 559
# r= 166
# len of es= 558
# r= 370
# len of es= 557
# r= 268
# len of es= 556
# r= 36
# len of es= 555
# r= 166
# len of es= 554
# r= 39
# len of es= 553
# r= 252
# len of es= 552
# r= 300
# len of es= 551
# r= 108
# len of es= 550
# r= 55
# len of es= 549
# r= 160
# len of es= 548
# r= 171
# len of es= 547
# r= 526
# len of es= 546
# r= 390
# len of es= 545
# r= 477
# len of es= 544
# r= 331
# len of es= 543
# r= 271
# len of es= 542
# r= 267
# len of es= 541
# r= 31
# len of es= 540
# r= 295
# len of es= 539
# r= 118
# len of es= 538
# r= 119
# len of es= 537
# r= 280
# len of es= 536
# r= 168
# len of es= 535
# r= 525
# len of es= 534
# r= 269
# len of es= 533
# r= 99
# len of es= 532
# r= 353
# len of es= 531
# r= 86
# len of es= 530
# r= 44
# len of es= 529
# r= 76
# len of es= 528
# r= 108
# len of es= 527
# r= 203
# len of es= 526
# r= 339
# len of es= 525
# r= 75
# len of es= 524
# r= 207
# len of es= 523
# r= 487
# len of es= 522
# r= 3
# len of es= 521
# r= 392
# len of es= 520
# r= 262
# len of es= 519
# r= 115
# len of es= 518
# r= 136
# len of es= 517
# r= 203
# len of es= 516
# r= 165
# len of es= 515
# r= 446
# len of es= 514
# r= 185
# len of es= 513
# r= 294
# len of es= 512
# r= 277
# len of es= 511
# r= 365
# len of es= 510
# r= 121
# len of es= 509
# r= 258
# len of es= 508
# r= 374
# len of es= 507
# r= 397
# len of es= 506
# r= 250
# len of es= 505
# r= 167
# len of es= 504
# r= 245
# len of es= 503
# r= 65
# len of es= 502
# r= 179
# len of es= 501
# r= 108
# len of es= 500
# r= 209
# len of es= 499
# r= 221
# len of es= 498
# r= 328
# len of es= 497
# r= 346
# len of es= 496
# r= 245
# len of es= 495
# r= 159
# len of es= 494
# r= 75
# len of es= 493
# r= 150
# len of es= 492
# r= 206
# len of es= 491
# r= 454
# len of es= 490
# r= 74
# len of es= 489
# r= 153
# len of es= 488
# r= 237
# len of es= 487
# r= 267
# len of es= 486
# r= 437
# len of es= 485
# r= 158
# len of es= 484
# r= 260
# len of es= 483
# r= 374
# len of es= 482
# r= 416
# len of es= 481
# r= 80
# len of es= 480
# r= 292
# len of es= 479
# r= 430
# len of es= 478
# r= 450
# len of es= 477
# r= 200
# len of es= 476
# r= 185
# len of es= 475
# r= 208
# len of es= 474
# r= 422
# len of es= 473
# r= 16
# len of es= 472
# r= 352
# len of es= 471
# r= 381
# len of es= 470
# r= 402
# len of es= 469
# r= 327
# len of es= 468
# r= 264
# len of es= 467
# r= 14
# len of es= 466
# r= 386
# len of es= 465
# r= 340
# len of es= 464
# r= 204
# len of es= 463
# r= 354
# len of es= 462
# r= 33
# len of es= 461
# r= 363
# len of es= 460
# r= 394
# len of es= 459
# r= 220
# len of es= 458
# r= 57
# len of es= 457
# r= 211
# len of es= 456
# r= 32
# len of es= 455
# r= 67
# len of es= 454
# r= 265
# len of es= 453
# r= 298
# len of es= 452
# r= 437
# len of es= 451
# r= 409
# len of es= 450
# r= 99
# len of es= 449
# r= 409
# len of es= 448
# r= 40
# len of es= 447
# r= 62
# len of es= 446
# r= 213
# len of es= 445
# r= 288
# len of es= 444
# r= 198
# len of es= 443
# r= 338
# len of es= 442
# r= 92
# len of es= 441
# r= 163
# len of es= 440
# r= 426
# len of es= 439
# r= 258
# len of es= 438
# r= 327
# len of es= 437
# r= 390
# len of es= 436
# r= 280
# len of es= 435
# r= 350
# len of es= 434
# r= 392
# len of es= 433
# r= 96
# len of es= 432
# r= 209
# len of es= 431
# r= 338
# len of es= 430
# r= 297
# len of es= 429
# r= 369
# len of es= 428
# r= 310
# len of es= 427
# r= 287
# len of es= 426
# r= 233
# len of es= 425
# r= 6
# len of es= 424
# r= 410
# len of es= 423
# r= 384
# len of es= 422
# r= 119
# len of es= 421
# r= 266
# len of es= 420
# r= 35
# len of es= 419
# r= 377
# len of es= 418
# r= 289
# len of es= 417
# r= 258
# len of es= 416
# r= 375
# len of es= 415
# r= 310
# len of es= 414
# r= 194
# len of es= 413
# r= 174
# len of es= 412
# r= 345
# len of es= 411
# r= 406
# len of es= 410
# r= 251
# len of es= 409
# r= 405
# len of es= 408
# r= 69
# len of es= 407
# r= 322
# len of es= 406
# r= 80
# len of es= 405
# r= 140
# len of es= 404
# r= 282
# len of es= 403
# r= 145
# len of es= 402
# r= 314
# len of es= 401
# r= 129
# len of es= 400
# r= 106
# len of es= 399
# r= 57
# len of es= 398
# r= 376
# len of es= 397
# r= 183
# len of es= 396
# r= 94
# len of es= 395
# r= 112
# len of es= 394
# r= 47
# len of es= 393
# r= 77
# len of es= 392
# r= 167
# len of es= 391
# r= 113
# len of es= 390
# r= 44
# len of es= 389
# r= 351
# len of es= 388
# r= 161
# len of es= 387
# r= 139
# len of es= 386
# r= 1
# len of es= 385
# r= 13
# len of es= 384
# r= 163
# len of es= 383
# r= 60
# len of es= 382
# r= 207
# len of es= 381
# r= 70
# len of es= 380
# r= 181
# len of es= 379
# r= 6
# len of es= 378
# r= 9
# len of es= 377
# r= 22
# len of es= 376
# r= 239
# len of es= 375
# r= 31
# len of es= 374
# r= 309
# len of es= 373
# r= 106
# len of es= 372
# r= 215
# len of es= 371
# r= 251
# len of es= 370
# r= 350
# len of es= 369
# r= 23
# len of es= 368
# r= 254
# len of es= 367
# r= 192
# len of es= 366
# r= 265
# len of es= 365
# r= 207
# len of es= 364
# r= 324
# len of es= 363
# r= 7
# len of es= 362
# r= 226
# len of es= 361
# r= 269
# len of es= 360
# r= 342
# len of es= 359
# r= 101
# len of es= 358
# r= 190
# len of es= 357
# r= 344
# len of es= 356
# r= 330
# len of es= 355
# r= 60
# len of es= 354
# r= 78
# len of es= 353
# r= 101
# len of es= 352
# r= 91
# len of es= 351
# r= 8
# len of es= 350
# r= 135
# len of es= 349
# r= 149
# len of es= 348
# r= 3
# len of es= 347
# r= 272
# len of es= 346
# r= 24
# len of es= 345
# r= 297
# len of es= 344
# r= 44
# len of es= 343
# r= 302
# len of es= 342
# r= 218
# len of es= 341
# r= 158
# len of es= 340
# r= 50
# len of es= 339
# r= 19
# len of es= 338
# r= 323
# len of es= 337
# r= 104
# len of es= 336
# r= 62
# len of es= 335
# r= 102
# len of es= 334
# r= 303
# len of es= 333
# r= 290
# len of es= 332
# r= 289
# len of es= 331
# r= 308
# len of es= 330
# r= 185
# len of es= 329
# r= 297
# len of es= 328
# r= 291
# len of es= 327
# r= 3
# len of es= 326
# r= 289
# len of es= 325
# r= 141
# len of es= 324
# r= 256
# len of es= 323
# r= 218
# len of es= 322
# r= 164
# len of es= 321
# r= 238
# len of es= 320
# r= 205
# len of es= 319
# r= 315
# len of es= 318
# r= 214
# len of es= 317
# r= 163
# len of es= 316
# r= 114
# len of es= 315
# r= 16
# len of es= 314
# r= 67
# len of es= 313
# r= 133
# len of es= 312
# r= 297
# len of es= 311
# r= 219
# len of es= 310
# r= 230
# len of es= 309
# r= 91
# len of es= 308
# r= 7
# len of es= 307
# r= 7
# len of es= 306
# r= 121
# len of es= 305
# r= 245
# len of es= 304
# r= 121
# len of es= 303
# r= 170
# len of es= 302
# r= 74
# len of es= 301
# r= 228
# len of es= 300
# r= 189
# len of es= 299
# r= 180
# len of es= 298
# r= 213
# len of es= 297
# r= 20
# len of es= 296
# r= 196
# len of es= 295
# r= 187
# len of es= 294
# r= 1
# len of es= 293
# r= 19
# len of es= 292
# r= 56
# len of es= 291
# r= 259
# len of es= 290
# r= 238
# len of es= 289
# r= 55
# len of es= 288
# r= 149
# len of es= 287
# r= 17
# len of es= 286
# r= 273
# len of es= 285
# r= 66
# len of es= 284
# r= 4
# len of es= 283
# r= 145
# len of es= 282
# r= 273
# len of es= 281
# r= 216
# len of es= 280
# r= 181
# len of es= 279
# r= 199
# len of es= 278
# r= 39
# len of es= 277
# r= 129
# len of es= 276
# r= 114
# len of es= 275
# r= 69
# len of es= 274
# r= 149
# len of es= 273
# r= 73
# len of es= 272
# r= 262
# len of es= 271
# r= 134
# len of es= 270
# r= 147
# len of es= 269
# r= 6
# len of es= 268
# r= 84
# len of es= 267
# r= 172
# len of es= 266
# r= 125
# len of es= 265
# r= 19
# len of es= 264
# r= 18
# len of es= 263
# r= 202
# len of es= 262
# r= 221
# len of es= 261
# r= 30
# len of es= 260
# r= 239
# len of es= 259
# r= 254
# len of es= 258
# r= 139
# len of es= 257
# r= 229
# len of es= 256
# r= 145
# len of es= 255
# r= 57

# %%
print(train_num,test_num,valid_num)
# Out:
# 1259 629 377

# %% [markdown]
# ## But ML requires all the types data, generated datasets have edges(1), but we need no edge vertices (0) for training

# %%
mat=g.get_adjacency()

pool_of_empty=list()
count=0
for i,entireNode in enumerate(mat):
    for j,eachVal in enumerate(entireNode):
        if(eachVal==0 and i!=j):
            count+=1;
            pool_of_empty.append((i,j))
print('count=',count)
